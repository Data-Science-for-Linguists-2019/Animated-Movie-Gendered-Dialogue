# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\Disney_1938_2016.csv')

# %%
data_sample = data.sample(20)

# %%
data_sample
# Out:
#       Unnamed: 0 Disney_Period Gender                      Movie Role Song  \
# 2180        2180           MID    NaN       Beauty and the Beast  NaN  NaN
# 3649        3649           MID    NaN                 Pocahontas  NaN  NaN
# 2567        2567           MID    NaN                    Aladdin  NaN  NaN
# 3455        3455           MID    NaN                 Pocahontas  NaN  NaN
# 4949        4949          LATE    NaN  The Princess and the Frog  NaN  NaN
# 6845        6845          LATE      f                      Moana    N    D
# 2471        2471           MID    NaN       Beauty and the Beast  NaN  NaN
# 1782        1782           MID    NaN       Beauty and the Beast  NaN  NaN
# 6230        6230          LATE    NaN                     Frozen  NaN  NaN
# 6530        6530          LATE    NaN                     Frozen  NaN  NaN
# 111          111         EARLY    NaN                 Snow White  NaN  NaN
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0 Disney_Period Gender  Movie Role Song          Speaker  \
# 7173        7173          LATE      m  Moana  ANT    D              tui
# 7174        7174          LATE      m  Moana    N    D  male villager 8
# 7175        7175          LATE      f  Moana    N    D  female villager
# 7176        7176          LATE      f  Moana  PRO    D            moana
# 7177        7177          LATE      n  Moana    N    S           chorus
#
#      Speaker_Status Start_Scene  \
# 7173          NON-P         NaN
# 7174          NON-P         NaN
# 7175          NON-P         NaN
# 7176       PRINCESS         NaN
# 7177          NON-P         NaN
#
#                                                    Text  UTTERANCE_NUMBER  \
# 7173                                      it suits you.               378
# 7174                                        she's back!               379
# 7175                                             moana!               380
# ...

# %%
data_sample = data_sample.append(data.tail())

# %%
data_sample.to_csv('Data_sample.csv')
