# %% [markdown]
# # Revisiting Messy Data
# So, on a quick preliminary look, I found that the movies Frozen and Tangled looked pretty messy. How messy are they really?

# %%
import pandas as pd
import numpy as np

# %%
disney = pd.read_csv(r"C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\Disney_1938_2016.csv")

# %%
disney.head()
# Out:
#    Unnamed: 0 Disney_Period Gender       Movie Role Song Speaker  \
# 0           0         EARLY    NaN  Snow White  NaN  NaN   queen
# 1           1         EARLY    NaN  Snow White  NaN  NaN  mirror
# 2           2         EARLY    NaN  Snow White  NaN  NaN   queen
# 3           3         EARLY    NaN  Snow White  NaN  NaN  mirror
# 4           4         EARLY    NaN  Snow White  NaN  NaN   queen
#
#   Speaker_Status Start_Scene  \
# 0          NON-P         NaN
# 1          NON-P         NaN
# 2          NON-P         NaN
# 3          NON-P         NaN
# 4          NON-P         NaN
#
#                                                 Text  UTTERANCE_NUMBER  Year
# 0  slave in the magic mirror come from the farthe...                 1  1937
# 1                what wouldst thou know, my queen ?                  2  1937
# 2  magic mirror on the wall, who is the fairest o...                 3  1937
# 3  famed is thy beauty, majesty. but hold, a love...                 4  1937
# 4                   alas for her ! reveal her name.                  5  1937

# %%
disney = disney.drop(columns="Unnamed: 0")

# %%
disney.Movie.value_counts()
# Out:
# Frozen                       988
# Aladdin                      842
# Beauty and the Beast         772
# The Princess and the Frog    676
# Pocahontas                   638
# Mulan                        554
# Cinderella                   497
# Sleeping Beauty              462
# Brave                        411
# The Little Mermaid           397
# Moana                        382
# Snow White                   366
# Tangled                      193
# Name: Movie, dtype: int64

# %%
frozen = disney[disney.Movie == "Frozen"]

# %%
frozen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 988 entries, 5808 to 6795
# Data columns (total 11 columns):
# Disney_Period       988 non-null object
# Gender              0 non-null object
# Movie               988 non-null object
# Role                0 non-null object
# Song                0 non-null object
# Speaker             988 non-null object
# Speaker_Status      988 non-null object
# Start_Scene         0 non-null object
# Text                988 non-null object
# UTTERANCE_NUMBER    988 non-null int64
# Year                988 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 57.9+ KB

# %%
frozen_lines = frozen[["Speaker", "Text"]]

# %%
frozen_lines.head()
# Out:
#               Speaker                                               Text
# 5808  ice harvesters   born of cold and winter air and mountain rain ...
# 5809  ice harvesters   , and his reindeer calf, sven, share a carrot ...
# 5810  ice harvesters   ice harvesters hup! ho! watch your step! let i...
# 5811  ice harvesters   ice harvesters stronger than one, stronger tha...
# 5812  ice harvesters   ice harvesters born of cold and winter air and...

# %%
frozen_lines
# Out:
#                 Speaker                                               Text
# 5808    ice harvesters   born of cold and winter air and mountain rain ...
# 5809    ice harvesters   , and his reindeer calf, sven, share a carrot ...
# 5810    ice harvesters   ice harvesters hup! ho! watch your step! let i...
# 5811    ice harvesters   ice harvesters stronger than one, stronger tha...
# 5812    ice harvesters   ice harvesters born of cold and winter air and...
# 5813    ice harvesters   ice harvesters this icy force both foul and fa...
# 5814    ice harvesters              ext. the kingdom of arendelle — night
# 5815               elsa  sleeps in her bed. her little sister anna: (5)...
# 5816               anna  elsa. psst. elsa! psst. elsa doesn't stir. ann...
# 5817               anna                        wake up. wake up. wake up.
# 5818               elsa                           anna, go back to sleep.
# 5819               anna  i just can't. the sky's awake, so i'm awake, s...
# 5820               elsa                           ...go play by yourself.
# 5821               anna                   do you want to build a snowman?
# 5822               anna               come on, come on, come on, come on.
# 5823               anna  the girls sneak into the ballroom. elsa shuts ...
# 5824               anna                       do the magic! do the magic!
# 5825               anna                                  this is amazing!
# 5826               elsa                                       watch this!
# 5827               elsa                hi, i'm olaf and i like warm hugs.
# 5828               anna                                 i love you, olaf.
# 5829               anna                                         catch me!
# 5830               elsa                                           gotcha!
# 5831               anna                                     again! again!
# 5832               elsa                                        slow down!
# 5833               elsa                                       mama! papa!
# 5834               elsa  the parents burst through the frozen door. gas...
# 5835              king   elsa, what have you done? this is getting out ...
# 5836             queen                                              anna!
# 5837               elsa              it was an accident. i'm sorry, anna.
# ...                 ...                                                ...
# 6766              hans   it's a beautiful summer day. the mighty ships ...
# 6767  french dignitary   i will return this scoundrel to his country. w...
# 6768               kai                     arendelle thanks you, my lord.
# 6769              duke   this is unacceptable. i am innocent. i'm a vic...
# 6770              duke   ow! my neck hurts. is there a doctor i could.....
# 6771               kai                   i have a message from the queen.
# 6772               kai   arendelle will henceforth and forever no longe...
# 6773              duke                           weselton. it's weselton!
# 6774               anna               come on. come on. come on. come on!
# 6775           kristoff                                             pole.
# 6776               anna                                      oops. sorry.
# 6777               anna                          okay. okay. here we are.
# 6778               anna                                 i owe you a sled.
# 6779          kristoff                                   are you serious?
# 6780               anna                   yes. and it's the latest model.
# 6781           kristoff                        no. i can't accept this...
# 6782               anna  you have to. no returns. no exchanges. queen's...
# 6783          kristoff                          what? that's not a thing.
# 6784               anna  sure it is. and it even has a cup holder.... d...
# 6785           kristoff                                          like it?
# 6786           kristoff          kristoff i love it.... i could kiss you!
# 6787           kristoff  ...i could. i mean i'd like to. i'd... may i? ...
# 6788               anna                                           we may.
# 6789               elsa                                    are you ready?
# 6790               anna                            i like the open gates.
# 6791               elsa                  we are never closing them again.
# 6792               elsa                              form on anna's boots.
# 6793               anna  what? oh, elsa, they're beautiful, but you kno...
# 6794          kristoff                 look out. reindeer coming through!
# 6795              olaf    that's it. glide and pivot and glide and pivot.
#
# [988 rows x 2 columns]

# %%
frozen_lines.reset_index(inplace=True, drop=True)

# %%
frozen_lines
# Out:
#                Speaker                                               Text
# 0      ice harvesters   born of cold and winter air and mountain rain ...
# 1      ice harvesters   , and his reindeer calf, sven, share a carrot ...
# 2      ice harvesters   ice harvesters hup! ho! watch your step! let i...
# 3      ice harvesters   ice harvesters stronger than one, stronger tha...
# 4      ice harvesters   ice harvesters born of cold and winter air and...
# 5      ice harvesters   ice harvesters this icy force both foul and fa...
# 6      ice harvesters              ext. the kingdom of arendelle — night
# 7                 elsa  sleeps in her bed. her little sister anna: (5)...
# 8                 anna  elsa. psst. elsa! psst. elsa doesn't stir. ann...
# 9                 anna                        wake up. wake up. wake up.
# 10                elsa                           anna, go back to sleep.
# 11                anna  i just can't. the sky's awake, so i'm awake, s...
# 12                elsa                           ...go play by yourself.
# 13                anna                   do you want to build a snowman?
# 14                anna               come on, come on, come on, come on.
# 15                anna  the girls sneak into the ballroom. elsa shuts ...
# 16                anna                       do the magic! do the magic!
# 17                anna                                  this is amazing!
# 18                elsa                                       watch this!
# 19                elsa                hi, i'm olaf and i like warm hugs.
# 20                anna                                 i love you, olaf.
# 21                anna                                         catch me!
# 22                elsa                                           gotcha!
# 23                anna                                     again! again!
# 24                elsa                                        slow down!
# 25                elsa                                       mama! papa!
# 26                elsa  the parents burst through the frozen door. gas...
# 27               king   elsa, what have you done? this is getting out ...
# 28              queen                                              anna!
# 29                elsa              it was an accident. i'm sorry, anna.
# ..                 ...                                                ...
# 958              hans   it's a beautiful summer day. the mighty ships ...
# 959  french dignitary   i will return this scoundrel to his country. w...
# 960               kai                     arendelle thanks you, my lord.
# 961              duke   this is unacceptable. i am innocent. i'm a vic...
# 962              duke   ow! my neck hurts. is there a doctor i could.....
# 963               kai                   i have a message from the queen.
# 964               kai   arendelle will henceforth and forever no longe...
# 965              duke                           weselton. it's weselton!
# 966               anna               come on. come on. come on. come on!
# 967           kristoff                                             pole.
# 968               anna                                      oops. sorry.
# 969               anna                          okay. okay. here we are.
# 970               anna                                 i owe you a sled.
# 971          kristoff                                   are you serious?
# 972               anna                   yes. and it's the latest model.
# 973           kristoff                        no. i can't accept this...
# 974               anna  you have to. no returns. no exchanges. queen's...
# 975          kristoff                          what? that's not a thing.
# 976               anna  sure it is. and it even has a cup holder.... d...
# 977           kristoff                                          like it?
# 978           kristoff          kristoff i love it.... i could kiss you!
# 979           kristoff  ...i could. i mean i'd like to. i'd... may i? ...
# 980               anna                                           we may.
# 981               elsa                                    are you ready?
# 982               anna                            i like the open gates.
# 983               elsa                  we are never closing them again.
# 984               elsa                              form on anna's boots.
# 985               anna  what? oh, elsa, they're beautiful, but you kno...
# 986          kristoff                 look out. reindeer coming through!
# 987              olaf    that's it. glide and pivot and glide and pivot.
#
# [988 rows x 2 columns]

# %%
frozen_lines.Text.iloc[958] #not a line
# Out:
# "it's a beautiful summer day. the mighty ships have been repaired and are sailing away. on one of the ships, hans is thrown into a brig."

# %% [markdown]
# So, a lot of stage commands have been unnecessarily added.

# %%
frozen_lines.Text.iloc[0] #again, lines mixed in with commands
# Out:
# 'born of cold and winter air and mountain rain combining, this icy force both foul and fair has a frozen heart worth mining. the men drag giant ice blocks through channels of water. ice harvesters cut through the heart, cold and clear. strike for love and strike for fear. see the beauty sharp and sheer. split the ice apart! and break the frozen heart. hup! ho! watch your step! let it go! '

# %%
import re

# %%
for line in frozen_lines.head().itertuples():
    print(line[0])
    print(line[1])
    print(line[2])
    print('\n')
# Out:
# 0
# ice harvesters
# born of cold and winter air and mountain rain combining, this icy force both foul and fair has a frozen heart worth mining. the men drag giant ice blocks through channels of water. ice harvesters cut through the heart, cold and clear. strike for love and strike for fear. see the beauty sharp and sheer. split the ice apart! and break the frozen heart. hup! ho! watch your step! let it go!
#
#
# 1
# ice harvesters
# , and his reindeer calf, sven, share a carrot as they try to keep up with the men.
#
#
# 2
# ice harvesters
# ice harvesters hup! ho! watch your step! let it go! kristoff struggles to get a block of ice out of the water. he fails, ends up soaked. sven licks his wet cheek. ice harvesters beautiful! powerful! dangerous! cold! ice has a magic can't be controlled.
#
#
# 3
# ice harvesters
# ice harvesters stronger than one, stronger than ten stronger than a hundred men!
#
#
# 4
# ice harvesters
# ice harvesters born of cold and winter air and mountain rain combining

# %%
frozen_lines.Speaker = frozen_lines.Speaker.map(lambda x: x.strip())

# %%
frozen_lines.Text = frozen_lines.Text.map(lambda x: x.strip())

# %%
for line in frozen_lines.itertuples():
    if line[2].startswith(line[1]):
        print(line)
        print('\n')
# Out:
# Pandas(Index=2, Speaker='ice harvesters', Text="ice harvesters hup! ho! watch your step! let it go! kristoff struggles to get a block of ice out of the water. he fails, ends up soaked. sven licks his wet cheek. ice harvesters beautiful! powerful! dangerous! cold! ice has a magic can't be controlled.")
#
#
# Pandas(Index=3, Speaker='ice harvesters', Text='ice harvesters stronger than one, stronger than ten stronger than a hundred men!')
#
#
# Pandas(Index=4, Speaker='ice harvesters', Text='ice harvesters born of cold and winter air and mountain rain combining')
#
#
# Pandas(Index=5, Speaker='ice harvesters', Text="ice harvesters this icy force both foul and fair has a frozen heart worth mining. cut through the heart, cold and clear. in the dark, kristoff and sven finally manage to get a single block of ice out of the water. ice harvesters strike for love and strike for fear. there's beauty and there's danger here. split the ice apart! beware the frozen heart.")
#
#
# Pandas(Index=37, Speaker='bulda', Text="bulda cuties. i'm gonna keep you.")
#
#
# Pandas(Index=44, Speaker='grand pabbie', Text='grand pabbie she will be okay.')
#
#
# Pandas(Index=48, Speaker='pabbie', Text='pabbie there is beauty in your magic.... but also great danger.')
#
#
# Pandas(Index=49, Speaker='pabbie', Text='pabbie')
#
#
# Pandas(Index=51, Speaker='pabbie', Text='pabbie fear will be your enemy.')
#
#
# Pandas(Index=64, Speaker='king', Text="king see? you're good....")
#
#
# Pandas(Index=88, Speaker='kristoff', Text='kristoff')
#
#
# Pandas(Index=91, Speaker='kristoff', Text='kristoff hey, hey, hey! share!')
#
#
# Pandas(Index=137, Speaker='hans', Text='hans')
#
#
# Pandas(Index=154, Speaker='bishop', Text='bishop')
#
#
# Pandas(Index=156, Speaker='bishop', Text='bishop ...queen elsa of arendelle.')
#
#
# Pandas(Index=159, Speaker='kai', Text='kai princess anna of arendelle!')
#
#
# Pandas(Index=172, Speaker='duke', Text='duke')
#
#
# Pandas(Index=187, Speaker='duke', Text='duke')
#
#
# Pandas(Index=217, Speaker='both', Text='both love is an open door! love is an open door!')
#
#
# Pandas(Index=218, Speaker='both', Text='both love is an open door')
#
#
# Pandas(Index=226, Speaker='both', Text='both our mental synchronization can have but one explanation,')
#
#
# Pandas(Index=230, Speaker='both', Text='both door! love is an open door!')
#
#
# Pandas(Index=231, Speaker='both', Text='both life can be so much more')
#
#
# Pandas(Index=332, Speaker='oaken', Text='oaken you and this fellow.... hoo hoo. big summer blow out.')
#
#
# Pandas(Index=356, Speaker='kristoff', Text="kristoff but i did find us a place to sleep. and it's free.")
#
#
# Pandas(Index=374, Speaker='kristoff', Text='kristoff ugh!')
#
#
# Pandas(Index=380, Speaker='kristoff', Text='kristoff this is fresh lacquer. seriously, were you raised in a barn?')
#
#
# Pandas(Index=413, Speaker='kristoff', Text='kristoff sven, go. go! sven takes off.')
#
#
# Pandas(Index=435, Speaker='kristoff', Text='kristoff')
#
#
# Pandas(Index=437, Speaker='kristoff', Text='kristoff uhoh. no, no, no.')
#
#
# Pandas(Index=438, Speaker='kristoff', Text='kristoff ah! no, no, no!')
#
#
# Pandas(Index=445, Speaker='kristoff', Text='kristoff')
#
#
# Pandas(Index=478, Speaker='olaf', Text='olaf what? hey! whoa.')
#
#
# Pandas(Index=489, Speaker='olaf', Text="olaf ha. aw, look at him tryin' to kiss my nose.")
#
#
# Pandas(Index=507, Speaker='olaf', Text='olaf when life gets rough i like to hold on to my dream / of relaxing in the summer sun just letting off steam!')
#
#
# Pandas(Index=508, Speaker='olaf', Text="olaf oh the sky will be blue / and you guys'll be there too / when i finally do what frozen things do in")
#
#
# Pandas(Index=521, Speaker='hans', Text='hans here. pass these out.')
#
#
# Pandas(Index=540, Speaker='olaf', Text="olaf oh, look at that. i've been impaled. he laughs it off. ext. steep mountain face — day")
#
#
# Pandas(Index=547, Speaker='kristoff', Text="kristoff i wouldn't put my foot there.")
#
#
# Pandas(Index=567, Speaker='kristoff', Text='kristoff you stay right here, buddy.')
#
#
# Pandas(Index=568, Speaker='kristoff', Text='kristoff ...flawless.')
#
#
# Pandas(Index=582, Speaker='olaf', Text='olaf one...two...')
#
#
# Pandas(Index=583, Speaker='olaf', Text='olaf and kristoff three...four...')
#
#
# Pandas(Index=654, Speaker='olaf', Text='olaf no, no, not you guys.')
#
#
# Pandas(Index=655, Speaker='olaf', Text='olaf')
#
#
# Pandas(Index=668, Speaker='kristoff', Text='kristoff okay, anna. on three.')
#
#
# Pandas(Index=677, Speaker='olaf', Text="olaf there we go. hey, anna! sven! where'd ya guys go? we totally lost marshmallow back there!")
#
#
# Pandas(Index=678, Speaker='olaf', Text='olaf')
#
#
# Pandas(Index=680, Speaker='olaf', Text='olaf')
#
#
# Pandas(Index=695, Speaker='olaf', Text='olaf oh, that feels better.')
#
#
# Pandas(Index=697, Speaker='olaf', Text='olaf he found us.')
#
#
# Pandas(Index=700, Speaker='kristoff', Text='kristoff here.')
#
#
# Pandas(Index=706, Speaker='kristoff', Text="kristoff i mean, it's fine. ah...i'm good. ha. i've got a thick skull.")
#
#
# Pandas(Index=741, Speaker='kristoff', Text='kristoff meet my family.')
#
#
# Pandas(Index=753, Speaker='olaf', Text='olaf wait? kristoff?')
#
#
# Pandas(Index=781, Speaker='kristoff', Text="kristoff she's as cold as ice.")
#
#
# Pandas(Index=785, Speaker='grand pabbie', Text='grand pabbie anna, your life is in danger. there is ice in your heart, put there by your sister. if not removed, to solid ice will you freeze, forever.')
#
#
# Pandas(Index=794, Speaker='kristoff', Text='kristoff come on, olaf!')
#
#
# Pandas(Index=811, Speaker='hans', Text='hans if you would just stop the winter, bring back summer...please.')
#
#
# Pandas(Index=820, Speaker='olaf', Text='olaf')
#
#
# Pandas(Index=838, Speaker='hans', Text="hans you're so cold.")
#
#
# Pandas(Index=858, Speaker='hans', Text="hans i figured, after we married, i'd have to stage a little accident for elsa.")
#
#
# Pandas(Index=880, Speaker='kristoff', Text="kristoff hey, watch it. what's wrong with you?")
#
#
# Pandas(Index=881, Speaker='kristoff', Text='kristoff')
#
#
# Pandas(Index=883, Speaker='kristoff', Text='kristoff ah! stop it! put me down!')
#
#
# Pandas(Index=884, Speaker='kristoff', Text="kristoff no, sven! we're not going back! sven shakes his head, angrily. kristoff she's with her true love.")
#
#
# Pandas(Index=885, Speaker='kristoff', Text='kristoff anna.')
#
#
# Pandas(Index=891, Speaker='olaf', Text="olaf ooh! but don't touch it!")
#
#
# Pandas(Index=892, Speaker='olaf', Text="olaf so, where's hans? what happened to your kiss?")
#
#
# Pandas(Index=897, Speaker='olaf', Text='olaf ...do you happen to have any ideas?')
#
#
# Pandas(Index=900, Speaker='olaf', Text="olaf love is...putting someone else's needs before yours, like, you know, how kristoff brought you back here to hans and left you forever.")
#
#
# Pandas(Index=904, Speaker='olaf', Text='olaf just maybe not right this second.')
#
#
# Pandas(Index=905, Speaker='olaf', Text="olaf don't worry, i've got it!")
#
#
# Pandas(Index=906, Speaker='olaf', Text='olaf')
#
#
# Pandas(Index=908, Speaker='olaf', Text="olaf it's kristoff and sven! they're coming back this way.")
#
#
# Pandas(Index=916, Speaker='olaf', Text="olaf there's your act of true love, right there, riding across the fjords like a valiant, pungent reindeer king! come on!")
#
#
# Pandas(Index=934, Speaker='hans', Text='hans your sister is dead... because of you.')
#
#
# Pandas(Index=978, Speaker='kristoff', Text='kristoff i love it.... i could kiss you!')

# %%
#testing .replace()
test = "kristoff is a person kristoff kristoff"
test_new = test.replace('kristoff', 'nerd')
print(test_new)
# Out:
# nerd is a person nerd nerd

# %%
test_new_2 = test.replace('kristoff', 'nerd', 1)
print(test_new_2) #only replaces first instance
# Out:
# nerd is a person kristoff kristoff

# %%
test_new_2 = test.replace('kristoff ', '', 1)
print(test_new_2) #only replaces first instance
# Out:
# is a person kristoff kristoff

# %%
for line in frozen_lines.itertuples():
    if line[2].startswith(line[1]):
        frozen_lines.Text.iloc[line[0]] = line[2].replace(line[1]+' ', '', 1)
# Out:
# c:\users\cassi\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
frozen_lines.head()
# Out:
#           Speaker                                               Text
# 0  ice harvesters  born of cold and winter air and mountain rain ...
# 1  ice harvesters  , and his reindeer calf, sven, share a carrot ...
# 2  ice harvesters  hup! ho! watch your step! let it go! kristoff ...
# 3  ice harvesters  stronger than one, stronger than ten stronger ...
# 4  ice harvesters  born of cold and winter air and mountain rain ...

# %%
frozen_lines
# Out:
#               Speaker                                               Text
# 0      ice harvesters  born of cold and winter air and mountain rain ...
# 1      ice harvesters  , and his reindeer calf, sven, share a carrot ...
# 2      ice harvesters  hup! ho! watch your step! let it go! kristoff ...
# 3      ice harvesters  stronger than one, stronger than ten stronger ...
# 4      ice harvesters  born of cold and winter air and mountain rain ...
# 5      ice harvesters  this icy force both foul and fair has a frozen...
# 6      ice harvesters              ext. the kingdom of arendelle — night
# 7                elsa  sleeps in her bed. her little sister anna: (5)...
# 8                anna  elsa. psst. elsa! psst. elsa doesn't stir. ann...
# 9                anna                         wake up. wake up. wake up.
# 10               elsa                            anna, go back to sleep.
# 11               anna  i just can't. the sky's awake, so i'm awake, s...
# 12               elsa                            ...go play by yourself.
# 13               anna                    do you want to build a snowman?
# 14               anna                come on, come on, come on, come on.
# 15               anna  the girls sneak into the ballroom. elsa shuts ...
# 16               anna                        do the magic! do the magic!
# 17               anna                                   this is amazing!
# 18               elsa                                        watch this!
# 19               elsa                 hi, i'm olaf and i like warm hugs.
# 20               anna                                  i love you, olaf.
# 21               anna                                          catch me!
# 22               elsa                                            gotcha!
# 23               anna                                      again! again!
# 24               elsa                                         slow down!
# 25               elsa                                        mama! papa!
# 26               elsa  the parents burst through the frozen door. gas...
# 27               king  elsa, what have you done? this is getting out ...
# 28              queen                                              anna!
# 29               elsa               it was an accident. i'm sorry, anna.
# ..                ...                                                ...
# 958              hans  it's a beautiful summer day. the mighty ships ...
# 959  french dignitary  i will return this scoundrel to his country. w...
# 960               kai                     arendelle thanks you, my lord.
# 961              duke  this is unacceptable. i am innocent. i'm a vic...
# 962              duke  ow! my neck hurts. is there a doctor i could.....
# 963               kai                   i have a message from the queen.
# 964               kai  arendelle will henceforth and forever no longe...
# 965              duke                           weselton. it's weselton!
# 966              anna                come on. come on. come on. come on!
# 967          kristoff                                              pole.
# 968              anna                                       oops. sorry.
# 969              anna                           okay. okay. here we are.
# 970              anna                                  i owe you a sled.
# 971          kristoff                                   are you serious?
# 972              anna                    yes. and it's the latest model.
# 973          kristoff                         no. i can't accept this...
# 974              anna  you have to. no returns. no exchanges. queen's...
# 975          kristoff                          what? that's not a thing.
# 976              anna  sure it is. and it even has a cup holder.... d...
# 977          kristoff                                           like it?
# 978          kristoff                    i love it.... i could kiss you!
# 979          kristoff  ...i could. i mean i'd like to. i'd... may i? ...
# 980              anna                                            we may.
# 981              elsa                                     are you ready?
# 982              anna                             i like the open gates.
# 983              elsa                   we are never closing them again.
# 984              elsa                              form on anna's boots.
# 985              anna  what? oh, elsa, they're beautiful, but you kno...
# 986          kristoff                 look out. reindeer coming through!
# 987              olaf    that's it. glide and pivot and glide and pivot.
#
# [988 rows x 2 columns]

# %%
for line in frozen_lines.itertuples():
    not_line = re.findall(r'(^(the )?[a-z]+s )', line[2])
    if len(not_line) > 0:
        print(line[0], not_line)
        print(line[2])
        print('\n')
# Out:
# 5 [('this ', '')]
# this icy force both foul and fair has a frozen heart worth mining. cut through the heart, cold and clear. in the dark, kristoff and sven finally manage to get a single block of ice out of the water. ice harvesters strike for love and strike for fear. there's beauty and there's danger here. split the ice apart! beware the frozen heart.
#
#
# 7 [('sleeps ', '')]
# sleeps in her bed. her little sister anna: (5) pops up beside her.
#
#
# 15 [('the girls ', 'the ')]
# the girls sneak into the ballroom. elsa shuts the door.
#
#
# 17 [('this ', '')]
# this is amazing!
#
#
# 26 [('the parents ', 'the ')]
# the parents burst through the frozen door. gasp at the sight of the room.
#
#
# 63 [('the gloves ', 'the ')]
# the gloves will help.
#
#
# 139 [('princess ', '')]
# princess anna of arendelle.
#
#
# 159 [('princess ', '')]
# princess anna of arendelle!
#
#
# 358 [('reindeers ', '')]
# reindeers are better than people. sven, don't you think that's true? kristoff
#
#
# 380 [('this ', '')]
# this is fresh lacquer. seriously, were you raised in a barn?
#
#
# 401 [('picks ', '')]
# picks his nose?
#
#
# 488 [('makes ', '')]
# makes things easier for me.
#
#
# 523 [('princess ', '')]
# princess anna has given her orders and
#
#
# 528 [('princess ', '')]
# princess anna's horse. what happened to her? where is she?
#
#
# 543 [('says ', '')]
# says who?
#
#
# 656 [('this ', '')]
# this just got a whole lot harder.
#
#
# 657 [('this ', '')]
# this way! kristoff
#
#
# 718 [('does ', '')]
# does it look bad?
#
#
# 768 [('is ', '')]
# is it the way that he runs scared?
#
#
# 771 [('his ', '')]
# his isolation is confirmation of his desperation for healing hugs. so he's a bit of a fixer upper, but we know what to do. the way to fix up this fixer upper is to fix him up with you.
#
#
# 802 [('hans ', '')]
# hans is nearly crushed by marshmallow. he rolls away. jumps to his feet. and with agile might, he slices marshmallow's leg off with his sword. marshmallow stumbles back, off balance. and falls off over the cliff, but not before striking hans. hans goes over the edge.
#
#
# 803 [('hans ', '')]
# hans clings to the ice steps. his men help him up and they rush into the ice palace.
#
#
# 804 [('hans ', '')]
# hans and his men run in. see the destruction and the thugs near death.
#
#
# 853 [('as ', '')]
# as thirteenth in line in my own kingdom, i didn't stand a chance. i knew i'd have to marry into the throne somewhere
#
#
# 855 [('as ', '')]
# as heir, elsa was preferable, of course. but no one was getting anywhere with her. but you
#
#
# 870 [('princess ', '')]
# princess anna is...dead.
#
#
# 951 [('hands ', '')]
# hands down, this is the best day of my life...and quite possibly the last.
#
#
# 961 [('this ', '')]
# this is unacceptable. i am innocent. i'm a victim of fear. i've been traumatized.

# %% [markdown]
# So, this approach, to try and match action with words ending is s...not too efficient.

# %%
from html.parser import HTMLParser

# %%
from bs4 import BeautifulSoup

# %%
#okay, so I have these two things. Maybe I can make use of them?

# %% [markdown]
# ## A Look at Tangled

# %%
tangled = disney[disney.Movie == "Tangled"]

# %%
tangled_lines = tangled[["Speaker", "Text"]]

# %%
tangled_lines.reset_index(drop=True, inplace = True)

# %%
tangled_lines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 2 columns):
# Speaker    193 non-null object
# Text       193 non-null object
# dtypes: object(2)
# memory usage: 1.5+ KB

# %% [markdown]
# Hmmm, only 193 lines. Compared to the other movies, this is already suspicious

# %%
for line in tangled_lines.itertuples():
    print(line[1])
    print(line[2])
    print('\n')
# Out:
# flynn
# this is the story of how i died. don't worry, this is actually a very fun story and the truth is, it isn't even mine. this is the story of a girl named rapunzel and it starts with the sun now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. it had the ability to heal the sick and injured. oh, you see that old woman over there? you might want to remember her. she's kind of important. well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. the kingdom was ruled by a beloved king and queen. the sick queen and the queen, well, she was about to have a baby. she got sick. really, sick. she was running out of time, and that's when people usually start to look for a miracle. or in this case, a magic golden flower. ah, i told you she'd be important. you see, instead of sharing the sun's gift, this woman, mothe gothel, hoarded its healng power and used it to keep herself for hundreds of years, and all she had to do was to sing a special song.
#
#
# mother gothel
# flower, gleam and glow let your power shine make the clock reverse bring back what once was mine what once was mine
#
#
# flynn
# all right, you get the gist. she sings to it, she turns , creepy right?
#
#
# guards
# we've found it!
#
#
# flynn
# the magic of the golden flower healed the queen. a healthy baby girl, a princess was born, with beautiful golden hair. i'll give you a hint, that's rapunzel.
#
#
# flynn
# to celebrate her birth, the king and queen launched a flying lantern into the sky. and for that one moment, everything was perfect. and then that moment ended.
#
#
# mother gothel
# flower, gleam and glow let your power shine make the clock re
#
#
# flynn
# gothel broke into the castle, stole the child and just like that gone. the kingdom searched and searched, but they could not find the princess. for deep within the forest, in a hidden tower, gothel raised the child as her own.
#
#
# rapunzel
# heal what has been hurt change the fate design save what has been lost bring back what once was mine what once was mine
#
#
# flynn
# gothel had found her new magic flower, but this time she was determined to keep it hidden.
#
#
# rapunzel
# why can't i go outside?
#
#
# mother gothel
# the outside world is a dangerous place, filled with horrible, selfish people. you must stay here, where you're safe. do you understand, flower?
#
#
# rapunzel
# yes, mommy.
#
#
# flynn
# but the walls of that tower could not hide everything. each year, on her birthday, the king and queen released thousands of lanterns into the sky, in hope that one day, their lost princess would return.
#
#
# rapunzel
# ha! hmm, well, i guess pascal's not hiding out here...
#
#
# rapunzel
# gotcha! that's twentytwo for me. how about twenty three out of forty five?
#
#
# rapunzel
# okay, well, what do you wanna do?
#
#
# rapunzel
# yeah, i don't think so. i like it in here and so do you.
#
#
# rapunzel
# oh, come on, pascal, it's not so bad in there...
#
#
# 7 am, the usual morning lineup
# start on the chores and sweep 'til the floor's all clean polish and wax, do laundry, and mop and shine up
#
#
# sweep again, and by then it's like 7
# 15. and so i'll read a book or maybe two or three i'll add a few new paintings to my gallery i'll play guitar and knit and cook and basically just wonder when will my life begin? then after lunch it's puzzles and darts and baking papier mache, a bit of ballet and chess pottery and ventriloquy, candle making then i'll stretch, maybe sketch, take a climb, sew a dress! and i'll reread the books if i have time to spare i'll paint the walls some more, i'm sure there's room somewhere. and then i'll brush and brush, and brush and brush my hair stuck in the same place i've always been. and i'll keep wonderin' and wonderin' and wonderin' and wonderin' when will my life begin? tomorrow night, lights will appear just like they do on my birthday each year. what is it like out there where they glow? now that i'm older, mother might just let me go ...
#
#
# flynn
# wow! i could get used to view like this.
#
#
# stabbington
# rider! c'mon!
#
#
# flynn
# hold on. yup, i'm used to it. guys, i want a castle.
#
#
# stabbington
# we do this job. you can buy your own castle.
#
#
# flynn
# oh, hay fever?
#
#
# guard
# yea.
#
#
# guard
# huh? hey, wait! hey, wait!
#
#
# flynn
# can't you picture me in a castle of my own? 'cause i certainly can. all the things we've seen and it's only eight in the morning. gentlemen, this is a very big day!
#
#
# rapunzel
# this is it. this is a very big day, pascal. hmmm. i'm finally gonna do it. i'm gonna ask her.
#
#
# mother gothel
# rapunzel! let down you hair!
#
#
# rapunzel
# it's time.
#
#
# rapunzel
# i know, i know, come on, don't let her see you.
#
#
# mother gothel
# rapunzel, i'm not getting any er down here.
#
#
# rapunzel
# coming, mother
#
#
# rapunzel
# hi, welcome home, mother.
#
#
# mother gothel
# uh, rapunzel! how you manage to do that every single day without fail! it looks absolutely exhausting, darling.
#
#
# rapunzel
# oh, it's nothing.
#
#
# mother gothel
# then i don't know why it takes so long! ergh, ho ho ho ho, darling, i'm just teasing.
#
#
# rapunzel
# hm, he he he. alright, so, mother, as you know, tomorrow is a very big day
#
#
# mother gothel
# rapunzel, look in that mirror. you know what i see? i see a strong, confident, beautiful lady. oh, look, you're here too. er... ha ha ha ha, i'm just teasing! stop taking everything so seriously, agh.
#
#
# rapunzel
# okay, so mother, as i was saying, tomorrow
#
#
# mother gothel
# rapunzel, mother's feeling a little rundown. would you sing for me, dear? that'll do.
#
#
# rapunzel
# oh! of course, mother.
#
#
# rapunzel
# flower, gleam and glow let your power shine make the clock reverse
#
#
# mother gothel
# wait!
#
#
# rapunzel
# bring back what once was mine
#
#
# mother gothel
# wait!
#
#
# rapunzel
# heal what has been hurt change the fate design save what has been lost bring back what once was mine
#
#
# mother gothel
# rapunzel!
#
#
# rapunzel
# so, mother, earlier i was saying tomorrow's a pretty big day and you didn't really respond, so i'm just gonna tell you, it's my birthday! uh. tada!
#
#
# mother gothel
# no, no, no, can't be. i distinctly remember your birthday was last year.
#
#
# rapunzel
# that's the funny thing about birthdays–they're kind of an annual thing! uh, mother, i'm turning eighteen, and i wanted to ask, uh, what i really want for this birthday. . . actually what i really want for my birth–want for my birth–
#
#
# mother gothel
# okay, rapunzel, please, stop with the mumbling. you know how i feel about the mumbling–blahblahblahblah, it's very annoying, i'm just teasing, you're adorable, i love you so much, darling. agh.
#
#
# rapunzel
# ah, i want to see the floating lights.
#
#
# mother gothel
# uhhuh. what?
#
#
# rapunzel
# oh. well, i was hoping you would take me to see the floating lights.
#
#
# mother gothel
# oo. you mean the stars.
#
#
# rapunzel
# that's the thing. i've charted stars and they're always constant–but these–they appear every year on my birthday, mother–only on my birthday. and i can't help but feel like they're. . . they're meant for me. i need to see them, mother, and not just from my window. in person. i have to know what they are.
#
#
# mother gothel
# you want to go outside? why, rapunzel! look at you, as fragile as a flower still a little sapling, just a sprout you know why we stay up in this tower
#
#
# rapunzel
# i know but. . .
#
#
# mother gothel
# that's right, to keep you safe and sound, dear guess i always knew this day was coming knew that soon you'd want to leave the nest soon, but not yet
#
#
# rapunzel
# but–
#
#
# mother gothel
# shh! trust me, pet mother knows best
#
#
# mother gothel
# mother knows best listen to your mother
#
#
# rapunzel
# agh!
#
#
# mother gothel
# it's a scary world out there mother knows best one way or another something will go wrong, i swear ruffians, thugs, poison ivy, quicksand cannibals and snakes. . . the plague!
#
#
# rapunzel
# no!
#
#
# mother gothel
# yes!
#
#
# rapunzel
# but–
#
#
# mother gothel
# also large bugs
#
#
# rapunzel
# ah!
#
#
# mother gothel
# men with pointy teeth, and stop, no more, you'll just upset me mother's right here, mother will protect you darling here's what i suggest skip the drama, stay with mama mother knows best ah, hahahaha. . . mother knows best take it from your mumsy on your own, you won't survive sloppy, underdressed, immature, clumsy please, they'll eat you up alive gullible, naive, positively grubby ditzy and a bit, well, hmm vague plus, i believe, gettin' kinda chubby i'm just saying 'cause i wuv you mother understands, mother's here to help you all i have is one request rapunzel?
#
#
# rapunzel
# yes?
#
#
# mother gothel
# don't ever ask to leave this tower again.
#
#
# rapunzel
# yes, mother.
#
#
# mother gothel
# uh, i love you very much, dear.
#
#
# rapunzel
# i love you more.
#
#
# mother gothel
# i love you most.
#
#
# mother gothel
# don't forget it, you'll regret it mother knows best!
#
#
# mother gothel
# rapunzel! i'll see you in a bit, my flower.
#
#
# rapunzel
# i'll be here.
#
#
# flynn
# uh, uh. . . agh! oh no. no no no no no no no no no no, this is bad, this is very, very bad, this is really bad. . . they just can't get my nose right!
#
#
# stabbington
# who cares?
#
#
# flynn
# well it's easy for you to say! you guys look amazing.
#
#
# flynn
# uh, all right, okay, give me a boost, and i'll pull you up.
#
#
# stabbington
# give us the satchel first.
#
#
# flynn
# uh? i just–i can't believe that after all we've been through together, you don't trust me? ouch.
#
#
# stabbington
# now help us up, pretty boy.
#
#
# flynn
# sorry, my hands are full.
#
#
# stabbington
# what? rider!
#
#
# captain
# retrieve that satchel at any cost!
#
#
# guards
# yes sir!
#
#
# captain
# we got him now, maximus!
#
#
# flynn
# ya, haha! –ooh!
#
#
# flynn
# ugh! come on, fleabag, forward!
#
#
# flynn
# no!
#
#
# flynn
# no! stop it, stop it! give it to me–give me that!–
#
#
# flynn
# ha!
#
#
# flynn
# ahhhhh!
#
#
# flynn
# alone at last.
#
#
# rapunzel
# ah!
#
#
# rapunzel
# oh.
#
#
# flynn
# huh?
#
#
# rapunzel
# okay, okay, okay, i've got a person in my closet. i've got a person in my closet. i've got a person in my closet! haha! uh! too weak to handle myself out there, huh, mother? well. . . hmmhmm. . .tell that to my frying pan–
#
#
# rapunzel
# huh?
#
#
# mother gothel
# rapunzel!
#
#
# rapunzel
# oh!
#
#
# mother gothel
# let down your hair!
#
#
# rapunzel
# one moment, mother!
#
#
# mother gothel
# i have a big surprise!
#
#
# rapunzel
# uh, i do too!
#
#
# mother gothel
# oo, i bet my surprise is bigger!
#
#
# rapunzel
# i seriously doubt it.
#
#
# mother gothel
# i brought back parsnips. i'm going to make hazelnut soup for dinner, your favourite–surprise!
#
#
# rapunzel
# well mother, there's something i want to tell you.
#
#
# mother gothel
# oh rapunzel, you know i hate leaving you after a fight especially when i've done absolutely nothing wrong.
#
#
# rapunzel
# okay, i've been thinking a lot about what you've said earlier
#
#
# rapunzel
# i hope you're not still talking about the stars.
#
#
# rapunzel
# ‘floating lights', and, yes, i'm leading up to that, and. . .
#
#
# mother gothel
# because i really thought we dropped the issue, sweetheart.
#
#
# rapunzel
# no, mother, i'm just saying, you think i'm not strong enough to handle myself out there.
#
#
# mother gothel
# oh, darling, i know you're not strong enough to handle yourself out there.
#
#
# rapunzel
# but if you just–
#
#
# mother gothel
# rapunzel, we're done talking about this–
#
#
# rapunzel
# trust me–
#
#
# mother gothel
# rapunzel–
#
#
# rapunzel
# i know what i'm saying–
#
#
# mother gothel
# rapunzel–
#
#
# rapunzel
# oh, come on–
#
#
# mother gothel
# enough of the lights, rapunzel! you are not leaving this tower! ever!
#
#
# mother gothel
# ugh, great. now i'm the bad guy.
#
#
# rapunzel
# all i was gonna say, mother, is that, i know what i want for my birthday now.
#
#
# mother gothel
# and what is that?
#
#
# rapunzel
# new paint. the paint made from the white shells you once brought me.
#
#
# mother gothel
# well, that is a very long trip, rapunzel. almost three days' time.
#
#
# rapunzel
# i just thought it was a better idea than. . . stars.
#
#
# mother gothel
# ugh. you're sure you'll be all right on your own?
#
#
# rapunzel
# i know i'm safe as long as i'm here.
#
#
# mother gothel
# i'll be back in three days' time. i love you very much, dear.
#
#
# rapunzel
# i love you more.
#
#
# mother gothel
# i love you most.
#
#
# rapunzel
# okay.
#
#
# rapunzel
# uh?
#
#
# rapunzel
# hmm.
#
#
# flynn
# agh! huh? uh?
#
#
# flynn
# is this hair?
#
#
# rapunzel
# struggling. . . struggling is pointless.
#
#
# flynn
# huh?
#
#
# rapunzel
# i know why you're here, and i'm not afraid of you.
#
#
# flynn
# what?
#
#
# rapunzel
# who are you? and how did you find me?
#
#
# flynn
# aha.
#
#
# rapunzel
# who are you, and how did you find me?
#
#
# flynn
# mmhm. i know not who you are, nor how i came to find you, but may i just say. . . hi. how ya doin'? the name's flynn rider. how's your day goin'? huh?
#
#
# rapunzel
# ugh! who else knows my location, flynn rider?
#
#
# flynn
# all right, blondie–
#
#
# rapunzel
# rapunzel.
#
#
# flynn
# gesundheit. here's the deal. i was in a situation, gallivanting through the forest. i came across your tower and. . . ho, oh no. . . where is my satchel?
#
#
# rapunzel
# i've hidden it, somewhere you'll never find it.
#
#
# flynn
# it's in that pot, isn't it?
#
#
# flynn
# er, uh. huh?
#
#
# flynn
# yike!
#
#
# rapunzel
# now it's hidden where you'll never find it. so, what do you want with my hair? to cut it?
#
#
# flynn
# what?
#
#
# rapunzel
# sell it?
#
#
# flynn
# no! listen, the only thing i want to do with your hair is to get out of it. literally.
#
#
# rapunzel
# yi. wait. you don't want my hair?
#
#
# flynn
# why on earth would i want your hair? look, i was being chased, i saw a tower, i climbed it, end of story.
#
#
# rapunzel
# you're. . . telling the truth?
#
#
# flynn
# yes.
#
#
# rapunzel
# i know, i need someone to take me.
#
#
# rapunzel
# i think he's telling the truth, too.
#
#
# rapunzel
# doesn't have fangs, but what choice do i have?
#
#
# rapunzel
# huh. okay, flynn rider, i'm prepared to offer you a deal.
#
#
# flynn
# deal?
#
#
# rapunzel
# look this way.
#
#
# rapunzel
# do you know what these are?
#
#
# flynn
# you mean the lantern thing they do for the princess?
#
#
# rapunzel
# lanterns. i knew they weren't stars. well, tomorrow evening they will light the night sky with these lanterns.you will act as my guide, take me to these lanterns, and return me home safely. then, and only then, will i return your satchel to you. that is my deal.
#
#
# flynn
# yeah. no can do. unfortunately, the kingdom and i aren't exactly 'simpatico' at the moment. so i won't be taking you anywhere.
#
#
# rapunzel
# something brought you here, flynn rider. call it what you will, fate, destiny. . .
#
#
# flynn
# a horse.
#
#
# rapunzel
# so i have made the decision to trust you.
#
#
# flynn
# a horrible decision, really.
#
#
# rapunzel
# but trust me when i tell you this.
#
#
# flynn
# ugh!
#
#
# rapunzel
# you can tear this tower apart brick by brick, but without my help, you will never find your precious satchel.
#
#
# flynn
# hmmmm. let me just get this straight. i take you to see the lanterns, bring you back home, and you'll give me back my satchel?
#
#
# rapunzel
# i promise. and when i promise something, i never ever break that promise. ever.
#
#
# flynn
# all right, listen, i didn't want to have to do this, but you leave me no choice. here comes the ‘smoulder'.
#
#
# rapunzel
# really? oops.
#
#
# flynn
# you broke my ‘smoulder'.

# %% [markdown]
# Okay, so this is actually formatted beautifully, but only has the first chunk of the movie! Uh oh.

# %%
patf = disney[disney.Movie == "The Princess and the Frog"]

# %%
patf_lines = patf[["Speaker", "Text"]]

# %%
for line in patf_lines.itertuples():
    print(line[1])
    print(line[2])
    print('\n')
# Out:
# singing
# evening star is shining bright, so make a wish and hold on tight, there's magic in the air tonight, and anything can happen.
#
#
# eudora
# just in that moment, the ugly little frog looked up with his sad, round eyes and pleaded oh, please, dear princess, only a kiss from you can break this terrible spell, that was inflicted on me by a wicked witch.
#
#
# charlotte
# there comes my favorite part.
#
#
# eudora
# and the beautiful princess was so moved by his desperate plea, that she stooped down, picked up the slippery creature, leaned forward, raised him to her lips, and kissed that little frog. then the frog was transformed into a handsome prince. they were married and lived happily ever after. the end.
#
#
# charlotte
# yay! read it again, read it again!
#
#
# eudora
# sorry charlotte, it's time for us to be headin' home. say good night, tiana.
#
#
# tiana
# there is no way, in this whole wide world ... i would ever, ever, ever i mean never kiss a frog. yuck!
#
#
# charlotte
# is that so? here comes your prince charming, tia. come on, kiss.
#
#
# tiana
# no!
#
#
# charlotte
# yes, yes!
#
#
# tiana
# stop it! i won't, i won't, i won't!
#
#
# charlotte
# i would do it. i would kiss a frog. i would kiss a hundred frogs, if i could marry a prince and be a princess.
#
#
# eudora
# you girls, stop tormentin' that poor little kitty. poor little thing.
#
#
# big daddy
# evenin' eudora!
#
#
# charlotte
# daddy, daddy, look at my new dress. isn't it pretty?
#
#
# big daddy
# hah,hah, look at you. why, i'd expect nothin' less from the finest seamstress in new orleans.
#
#
# charlotte
# uuh, i want that there.
#
#
# big daddy
# oh, no sugar come on.
#
#
# charlotte
# i want that one. please, please, please, please!
#
#
# big daddy
# eudora. you suppose you can web something up like that ?
#
#
#  eudora
# anything for my best customer.
#
#
# charlotte
# yeah!
#
#
#  eudora
# come along, tiana. your dad should be home from work by now.
#
#
# big daddy
# aah, now princess, you gettin' that drift but that's it. no more mr. pushover. now who wants a puppy?
#
#
# charlotte
# i do! i do! he's so cute!
#
#
# james
# mmm, gumbo smells good tiana.
#
#
# tiana
# i think it's done, daddy.
#
#
# james
# yeah. are you sure?
#
#
# tiana
# mmhmm.
#
#
# james
# absolutely positive?
#
#
# tiana
# yes!
#
#
# james
# okay, i'm about to put this spoon in my ...
#
#
# tiana
# wait! done.
#
#
# tiana
# what?
#
#
# james
# well, sweetheart ... this is the... the best gumbo i've ever tasted. come here. eudora, our little girl's got a gift.
#
#
#  eudora
# i coulda have told you that.
#
#
# james
# a gift this special just gotta be shared.
#
#
# tiana
# hey everybody i made gumbo.
#
#
# woman
# uuuh, that's smells good
#
#
# man
# i got some hush puppies. . .
#
#
# james
# you know the thing about good food? it brings folks together from all walks of life. it warms them right up and it puts little smiles on their faces. and when i open up my own restaurant, i tell you, people are gonna lined up for miles around, just to get a taste of my food.
#
#
# tiana
# our food!
#
#
# james
# that's right, baby. our food.
#
#
# tiana
# daddy, look.
#
#
# james
# where're you goin'?
#
#
# tiana
# charlotte's fairy tale book said, if you make a wish on evening star it's sure to come true.
#
#
# eudora
# hmmh, won't you wish on that star, sweetheart?
#
#
# james
# yes, you wish and you dream with all your little heart. but you remember tiana that, that old star can only take you part of a way. you got to help him with some hard work of your own. and then... yeah you can do anything you said you mind to. just promise your daddy one thing? that you'll never, ever lose sign what is really important. okay?
#
#
# eudora
# see you in the morning, baby cakes. get some sleep.
#
#
# tiana
# please, please, please.
#
#
# tiana
# aaaaaaah!!!
#
#
# tiana
# well miss tiana rough night for tips but every little penny counts. don't you worry, daddy ... we'll be there soon.
#
#
# tiana
# goodnight cal's good morning duke's.
#
#
# singer
# in the south land there's a city way down on the river where the women are very pretty and all the men deliver they got music it's always playin' start in the day time go all through the night when you hear that music playin' hear what i'm saying and make it feel alright grab somebody, come on down bring your paintbrush, we're painting the town oh there's some sweetness going around catch it down in new orleans we got magic, good and mase make it happen, make it real, say if anything you want is lose what you have down here in new orleans hey partner, don't be shy come on down here and give us a try you wanna do some livin' before you die do it down in new orleans stalee homes and mansions of the sugar darns and cotton candy rich people, old people, all got dreams ... dreams do come true in new orleans.
#
#
#  burford
# order up!
#
#
# virgil
# another coffee here, sug' .
#
#
# tiana
# comin' right up, virgil.
#
#
# georgia
# hey, tiana
#
#
# tiana
# morning, georgia.
#
#
# people
# hi, how are you doin' tiana?
#
#
# tiana
# hey y'all!
#
#
# georgia
# we all goin' out dancin' tonight. care to join us?
#
#
# people
# yeah, c'mon, tiana, you could use a little hand. it's mardi gras.
#
#
# tiana
# no, i got two left feet. besides i'm gonna... you need a napkin, sweetheart? i'm gonna work a double shift tonight... here you are, cakes. you know, so i...
#
#
# georgia
# you can save for your restaurant. i know, i know. girl! all you ever do is work!
#
#
# burford
# order up!
#
#
# tiana
# maybe next time.
#
#
# violet
# i told y'all she wouldn't come.
#
#
# burford
# are you talkin' 'bout that dang restaurant again?
#
#
# tiana
# buford, your eggs are burnin'.
#
#
# burford
# you ain't never gonna get enough for the dang payment.
#
#
# tiana
# i'm gettin' close.
#
#
# burford
# yeah. how close?
#
#
# tiana
# where my flapjacks?
#
#
# burford
# hah, hah! you got about as much chance of gettin' that restaurant as i do of winnin' the kentucky derby. saddle me up, y'all and pump that...
#
#
# tiana
# mornin', mr. la bouff.
#
#
# big daddy
# good mornin', tiana.
#
#
# tiana
# congratulations on bein' voted king of the mardi gras parade. caught me completely by surprise ... for the fifth year in a row. now, how about i celebrate with...
#
#
# tiana
# beignets? got me a fresh batch just waitin' for you.
#
#
# big daddy
# well, keep 'em comin' 'til i pass out.
#
#
# charlotte
# oh tia! tia, tia, tia!!
#
#
# tiana
# charlotte?!
#
#
# charlotte
# did you get the news? tell her, oh tell her big daddy.
#
#
# big daddy
# oh, yeah. prince naveen ...
#
#
# charlotte
# prince naveen of maldonia is coming to new orleans. isn't it the bee's knees? tell her what you did, big daddy. tell her!
#
#
# big daddy
# well, i invited ...
#
#
# charlotte
# daddy invited the prince to a masquerade ball tonight tell her what else you did big daddy. go on.
#
#
# big daddy
# and he's staying. . .
#
#
# charlotte
# and he's staying
#
#
# big daddy
# and he's staying in our house as my personal guest.
#
#
# tiana
# oh, lottie, that's swell. a little word of advice my mom always said that the quicks way to a man's heart is through his stomach.
#
#
#  charlotte
# that's it.
#
#
# big daddy
# what just happened?
#
#
# charlotte
# oh, tia, you are bonafide genius. i'm gonna need about five hundred of your mancatching beignets for my ball tonight. let's get it daddy. will this many cover it? well?
#
#
# tiana
# this should cover it just fine, lottie. this is it! i'm gettin' my restaurant.
#
#
# charlotte
# tonight my prince is finally coming. and i'll sure as heck ain't letting him go.
#
#
# tiana
# everything looks peacheykeen , mr. fenner. and. .. mr. fenner.
#
#
# mr. fenner
# we have all the paperwork ready to sign, first thing after mardi gras .
#
#
# tiana
# i'll do you one better, why we don't sign tonight when i see you all at the la bouff masquerade ball.
#
#
# mr. fenner
# you drive a hard bargain, tiana.
#
#
# eudora
# table for one, please.
#
#
# tiana
# oh, mama.
#
#
# eudora
# here is a little something to.. help you get started. daddy's gumbo pot.
#
#
# eudora
# i know. i miss him too. well now... hurry up and open the door.
#
#
# tiana
# just look at it, mama. doesn't just make you wanna cry?
#
#
# eudora
# yes.
#
#
# tiana
# the main d. gonna be right where you are stayin'. and over here, a gourmet kitchen. and hang up from the ceiling a big, old crystal chandelier.
#
#
# eudora
# you your daddy's daughter, all right. he used to go on and on about this old sugar mill too. baby cakes, i'm sure, this place is gonna be just wonderful. but it's a shame you're working so hard.
#
#
# tiana
# but how can i let up now when i'm so close. i got to make sure all that hard work means something.
#
#
# eudora
# tiana! your daddy may not have gotten place you always wanted but he had something better. he had love. and that's all i want for you, sweetheart. to me you and prince charming end dance out until y'all happily ever after.
#
#
#  tiana
# i don't have time for dancing.
#
#
# tiana
# that's just gonna have to wait a while
#
#
# eudora
# how long we're talkin' about here?
#
#
#  tiana
# ain't got time for messing around and it's not my style
#
#
# eudora
# i want some grandkids.
#
#
# tiana
# this whole town can slow you down people taking the easy way but i know exactly where i'm going and getting closer, closer, every day and i'm almost there i'm almost there people down here think i'm crazy, but i don't care tribes and tribulations i've had my share there ain't nothing gonna stop me now cause i'm almost there i remember daddy told me fairytales can come true you gotta make 'em happen it all depends on you so i work real hard each and every day now things for sure are going my way just doing what i do look out boys i'm coming through and i'm almost there i'm almost there people gonna come here from everywhere and i'm almost there, i'm almost there there's been tribes and tribulations you know i've had my share but i've climbed the mountain, i've crossed the river and i'm almost there, i'm almost there i'm almost there !
#
#
#  lawrence
# excuse me!
#
#
# man
# you need a hand in there, buddy?
#
#
# prince naveen
# achedanza...
#
#
# lawrence
# sir ... i've been looking for you everywhere.
#
#
# prince naveen
# what a coincidence, lawrence. i've been avoiding you everywhere.
#
#
# lawrence
# we are going to be late for the masquerade.
#
#
# prince naveen
# listen, lawrence, listen. it's jazz, that's the music. it was born here. it's beautiful, no?
#
#
# lawrence
# no. oh, dance with me, fat man. get loose, lawrence.
#
#
# lawrence
# we supposed to be at la bouff's estate by now.
#
#
# prince naveen
# yes, yes, yes. but first ... i buy everyone here a drink.
#
#
# lawrence
# with what? at this point you have two choices, woo and marry rich lady or ... get a job.
#
#
# prince naveen
# all right, fine but first... we dance.
#
#
# lawrence
# this is idiocy.
#
#
# prince naveen
# for someone who can't see his feet, you're very light on them! it's perfect. you're finally getting into the music! do you get my joke? because your head is, it is in the tuba!
#
#
# lawrence
# get me out!
#
#
# prince naveen
# all right. hold on.
#
#
# lawrence
# degrading. i never been so humiliated.
#
#
# prince naveen
# hello?
#
#
# dr. facilier
# gentlemen. enchantee. a tip of the hat from dr. facilier. how y'all doin'?
#
#
# prince naveen
# tarot readings, charms, potions ... dreams made real! achedanza!
#
#
# dr. facilier
# were i a betting man...and i'm not, i stay away from games of chance...
#
#
# lawrence
# sir!
#
#
# dr. facilier
# i'd wager... i'm in the company of visiting royalty. lawrence, lawrence!
#
#
# prince naveen
# this remarkable gentleman has just read my palm!
#
#
# lawrence
# or this morning's newspaper? sir, this chap is obviously a charlatan. i suggest we move on to a less...
#
#
# dr. facilier
# don't you disrespect me little man!. don't you derogate or deride!
#
#
# dr. facilier
# you're in my world now, not your world and i've got friends on the other side!
#
#
# choir
# he's got friends on the other side...
#
#
#  dr. facilier
# that's just an echo, gentlemen. just a little somethin' we have here in louisiana, a little parlor trick. don't worry.... sit down at my table put your minds at ease if you relax it will enable me to do anything i please i can read your future i can change it 'round some, too i'll look deep into your heart and soul
#
#
#  dr. facilier
# make your wildest dreams come true! i got voodoo, i got hoodoo, i got things i ain't even tried! and i got friends on the other side. he's got friends on the other side... the cards, the cards, the cards will tell the past, the present, and the future as well the cards, the cards, just take three take a little trip into your future with me! now you, man, are from across the sea you come from two long lines of royalty i'm a royal myself on my mother's side
#
#
#  dr. facilier
# your lifestyle's high but your funds are low you need to marry a little honey whose daddy got dough mommy and daddy cut you off, huh playboy?
#
#
# prince naveen
# yeah, sad but true.
#
#
# dr. facilier
# now y'all gotta get hitched, but hitchin' ties you down. you just wanna be free. hop from place to place. but freedom... takes green! it's the green, it's the green, it's the green you need and when i looked into your future it's the green that i see! on you little man, i don't want to waste much time you been pushed around all your life you been pushed around by your mother and your sister and your brother. and if you was married... you'd be pushed around by your wife but in your future, the you i see it's exactly the man you always wanted to be! shake my hand. come on, boys won't you shake the poor sinner's hand? are you ready? are you ready? are you ready? transformation central! transformation central! reformation central! reformation central! transmogrification central! can you feel it? you're changin', you're changin' you're changin', all right! i hope you're satisfied but if you ain't don't blame me you can blame my friends on the other side! you got what you wanted! but you lost what you had! hush...
#
#
# big daddy
# ah, senator johnson!
#
#
# senator
# hey, jimmy. i hope you leavin' some of the beignets for your constituents.
#
#
# tiana
# here you go, piping hot. stella, excuse me... stella, no, no. okay, but just one.
#
#
# travis
# but miss charlotte ... you said later two hours?
#
#
# charlotte
# travis! when a woman says later, she really means not ever! now run along. there are plenty of fillies dyin' for you to waltz them into a stupor. gimme that napkins! quick!
#
#
# tiana
# what on earth for?
#
#
# charlotte
# i swear, i'm sweatin' like a sinner in church! oh, tia, is gettin' to be so late.
#
#
# tiana
# there's still a few stragglers.
#
#
# charlotte
# this is a failure. tia, my prince is never comin'.
#
#
# tiana
# now, lottie...
#
#
# charlotte
# i never get anything i wish for!
#
#
# tiana
# lottie, wait!
#
#
# tiana
# just calm down and take a deep...
#
#
# charlotte
# maybe i just got to wish harder. please, please, please please, please ...
#
#
# tiana
# lottie, you can't just wish on a star expecting ...
#
#
#  announcer
# ladies and gentlemen! his royal highness, prince naveen.
#
#
# mr. fenner
# good evening, tiana. marvelous party.
#
#
# tiana
# evening, mr. fenner. and. .. mr. fenner. i'm smelling beignets.
#
#
# tiana
# gonna be the house specialty, once i signed those papers y'a'' brought.
#
#
# mr. fenner
# yes ...
#
#
# mr. fenner 2
# about that...
#
#
# mr. fenner
# you were outbid.
#
#
# tiana
# what?
#
#
# mr. fenner
# the fella came in offering a full amount of cash. less you can tap his offer by wednesday. you can kiss that place goodbye.
#
#
# tiana
# you know how long it took me to save that money?
#
#
# mr. fenner
# exactly! which is why a little woman of your background ... woulda had a hands full, trying to run a big business like that. you better off where you're at.
#
#
# tiana
# no, wait a minute!
#
#
# mr. fenner
# love those beignets, though!
#
#
# tiana
# no. .. hold on a minute! you..you come back!
#
#
# charlotte
# tia, time to get prince charmed with those mancatchin' being... what happened?
#
#
# tiana
# i. .. i ...just.
#
#
# charlotte
# oh, you poor dear. oh, prince naveen, we will be right back, sugar. i got just the dress for you. oh, tia, honey, did you see the way he danced with me? a marriage proposal, can't be far behind. thank you, evening star! you know, i was taught to think that wishing on stars was just for... babies an' crazy people. look at you! aren't you just as pretty as a magnolia in may? seems like only yesterday we were ... both little girls, dreaming our fairy tales dreams. and tonight they're finally coming true! well...back into the fray! wish me luck. oh, naveen ...
#
#
#  tiana
# almost... almost there people woulda come here from everywhere i was almost... there. i can not believe i'm doing this.
#
#
#  tiana
# please... please... please! very funny. so, what now? i reckon you want a kiss?
#
#
# prince naveen
# kissing would be nice, yes? i'm sorry, i'm sorry, i'm sorry. i did not mean to scare you, i... wait, no , no... wait, wait, wait, hold on. you know, you have a very strong arm, princess. ok, please! put the monkey down.
#
#
# tiana
# stay back, or i'll... i'll...
#
#
# prince naveen
# please, please, please... ah, oh well...allow me to introduce myself, i'm prince naveen. ... of maldonia.
#
#
# tiana
# a prince? but i didn't wish for any... hold on, if you're the prince, then... then who was that waltzing with lottie on the dance floor?
#
#
# prince naveen
# all i know, is one minute i am a prince, charming and handsome, cuttingarug, and the next thing i know, ...i am tripping over these. wait, wait, wait... wait! i know this story! di frogie prutto!
#
#
# tiana
# the frog prince?
#
#
# prince naveen
# yes, yes, yes... my mother had the servants read this to me every night. yes, yes...this is exactly the answer! you ...you must kiss me!
#
#
# tiana
# excuse me?
#
#
# prince naveen
# you will enjoy it, i guarantee. all women enjoy the kiss... of prince naveen. come, we pucker. that's new.
#
#
# tiana
# look, i'm sorry. i'd really like to help you, but i just... do not kiss frogs.
#
#
# prince naveen
# wait a second! but...on the balcony, you ask me...
#
#
# tiana
# i didn't expect you to answer!
#
#
# prince naveen
# oh, but you must kiss me. look, besides being unbelievably handsome, i also happened to come from a fabulously wealthy family. surely, i can offer you some type of reward or a wish i could grant perhaps... yes?
#
#
# tiana
# just... one kiss?
#
#
# prince nveen
# just one. unless you beg for more.
#
#
# tiana
# ok tiana, you can do this... just a little kiss, just a little kiss. ok! you don't look there much different. but how did you get way up there? and how did i get way down here, in all this!
#
#
# prince naveen
# easy princess, do not panic.
#
#
# tiana
# what did you do to me? i...i'm green and i'm...and i'm slimy!
#
#
# prince naveen
# no, no, no ... this is not slime.
#
#
# tiana
# what?
#
#
# prince naveen
# you're secreting mucus.
#
#
# person
# stella!
#
#
# person
# get that frogs!
#
#
# prince naveen
# run!
#
#
# tiana
# i can't run, i'm a frog.
#
#
# prince naveen
# then hop!
#
#
# person
# calm boy, calm you monster dog!
#
#
# person
# en garde!
#
#
# person
# look out! get out of the way.
#
#
# tiana
# where are we going?
#
#
# prince naveeen
# excuse me!
#
#
# tiana
# i can't see a thing.
#
#
# prince naveen
# me neither, can i?
#
#
# tiana
# wait, stella...
#
#
# prince naveen
# get up!
#
#
# tiana
# stella, it's me, tiana!
#
#
# stella
# tiana?
#
#
# tiana
# stella just talked to me! the dog just spoke to me!
#
#
# prince naveen
# you know, if you are going to let every little thing bother you... it's going to be very long night!
#
#
# lawrence
# oh dear? you are so quiet?
#
#
# dr. facilier
# you let him go!
#
#
# lawrence
# the poor dear frog was scarfing , so i loosened the lid, and.... how do i ever get tangled up in all this voodoo madness? i can't get through with this. you wear this ...this ghostly flinger!
#
#
# dr. facilier
# amulet! anything happens to this ... i'm gonna need... fun fact about voodoo, larry. can conjure a thing for myself. besides ... you and i both know the real power in this world ain't magic. it's money. lots of it.
#
#
# lawrence
# it's true.
#
#
# dr. facilier
# aren't you tired of living on a smidgens, while all those fat cats in their fancy cars don't give you so much of a sideway's glance ?
#
#
# lawrence
# yes... i am.
#
#
# dr. facilier
# all you got to do is marry big daddy's little princess ... and we will splittin' that juicy la bouff fortune right down in the middle. sixtyforty like i said.
#
#
# lawrence
# but ... what about naveen?
#
#
# dr. facilier
# you little slipup... we will be a minor bump in the road, so long as we got the prince's blood in this.
#
#
# tiana
# voodoo? you mean to tell me this all happened because you were messing with the shadow man?
#
#
# prince naveen
# he was very charismatic!
#
#
# tiana
# it serves me right for wishing on stars. the only way to get what you want in this world is through hard work.
#
#
# prince naveen
# hard work? why... why would a princess need to work hard?
#
#
# tiana
# huh? oh, i'm not a princess. i'm a waitress.
#
#
# prince naveen
# a waitress? well no wonder the kiss did not work! you lied to me!
#
#
# tiana
# i...i never said i was a princess.
#
#
# prince naveen
# you never said you were a w... a waitress! you were wearing a crown.
#
#
# tiana
# it was a costume party, you spoiled little rich boy.
#
#
# prince naveen
# oh, oh yes, oh ye? well, the egg is on your face, alright, because i do not have any riches!
#
#
# tiana
# what?
#
#
# prince naveen
# i am completely broke.
#
#
# tiana
# you said ... you were fabulously wealthy!
#
#
# prince naveen
# no, no, no. my parents are fabulously wealthy. but they cut me off for being a... leech! leech!
#
#
# tiana
# you're broke, and you had the gall to call me a liar?
#
#
# prince naveen
# it was not a lie! i fully inte...aaah! i fully intend to be rich again! once i marry miss charlotte la bouff' and she will help me!
#
#
# tiana
# you're a prince?
#
#
# prince naveen
# obviously!
#
#
# tiana
# she'll have you! all right then. once you two are married, you are gonna keep your promise and get me my restaurant, right?
#
#
# prince naveen
# whoa, oh, not so fast. i made that promise to a beautiful princess, not a cranky wai... why are those logs moving?
#
#
# tiana
# those aren't logs!
#
#
# louis
# i got glimpse on a big one.
#
#
# alligator
# c'mon, come here! come here you tasty one mussel!
#
#
# alligator
# where did they go?
#
#
# prince naveen
# psst. lower the vine.
#
#
# tiana
# find your own tree.
#
#
# alligator
# there he is.
#
#
# alligator
# i've seen him! i've seen him!
#
#
# prince naveen
# okay, help me get out of this swamp and once i married charlotte, i shall get you your restaurant.
#
#
# alligator
# you gonna taste so good battered and fried!
#
#
# prince naveen
# quick, quick, pull me up!
#
#
# alligator
# you can hop ... but you can't hide. we got all night!
#
#
# prince naveen
# well, waitress, looks like we going to be here for a while. so we may as well get ... comfortable.
#
#
# tiana
# take your slimy self away from me.
#
#
# prince naveen
# i've told you ... it is not slime! it is mucus.
#
#
# tiana
# rise and shine, sleeping beauty. gators are gone. we got to get back to new orleans ... and undo this mess you got us into.
#
#
# prince naveen
# i was not the one parading around with your phony baloney tiara. music to paddle by.
#
#
# tiana
# could use a little help!
#
#
# prince naveen
# i will play a little louder. how about a little less pickin'' and a ...
#
#
# louis
# i know that tune! dippermouth blues.
#
#
# prince naveen
# play it, brother!
#
#
# louis
# where you've been all my life?!
#
#
# prince naveen
# where did you learn to play like that?
#
#
# louis
# well, the bajou's is the best jazz school in the world. all the greats play the riverboats. oh, louis give anything to be up there jammin' with the big boys.
#
#
# prinve naveen
# so why don't you?
#
#
# louis
# oh, i tried once. it didn't end well.
#
#
# tiana
# it is been a real pleasure meetin' you, louis. and thank you for coming and for not eatin' us. we best be on our way.
#
#
# louis
# where are you goin'?
#
#
# tiana
# to find somebody to break the spell.
#
#
# louis
# what spell?
#
#
# prince naveen
# brace yourself, my scaly friend, we are not frogs ... we are humans.
#
#
# louis
# what? you are serious?
#
#
# prince naveen
# i am naveen, prince of maldonia. and she is tiana, the waitress. do not kiss her.
#
#
# tiana
# now just a second. this goon here got himself turned into a frog by a voodoo man and now ...
#
#
# louis
# voodoo? like the kind mama odie do.
#
#
# prince naveen
# mama, hoodie ?
#
#
# louis
# mama odie. she is the voodoo queen of the bajou. she got magic and spells all kind a voodoo .
#
#
# tiana and prince naveen
# could you take us to her?
#
#
# louis
# to the deepest, darkest part of a bayou?? facing raser sharks, prick ambushers, and trappers, and hunters with guns? no.
#
#
# prince naveen
# watch and learn. louis, that's too bad we can not help you with your dream. if only you were smaller... less toothy. you can play jazz to adoring crowd without scaring them. anyway, enjoy your loneliness, my friend! abenaza.
#
#
# tiana
# cute, but it's not gonna...
#
#
# louis
# hey guys, i just had me a crazy idea. what about if i ask mama odie to turn me human?
#
#
# prince naveen
# louis, you are a genius.
#
#
# louis
# hallelujah! if i were a human being i'd head straight for new orleans and i'd blow this horn so hot and strong like no one they'd ever seen louis armstrong, mister sydney bechet all the boys gonna step aside when they hear this old exgator play listen! when i'm human as i hope to be i'm gonna blow this horn till the cows come home and everyone's gonna bow down to me! thank you! thank you! aw, thank you! i love you too baby!
#
#
# prince naveen
# when i'm myself again i want just the life i had a great big party every night that doesn't sound too bad a redhead on my left arm a brunette on my right a blonde or two to hold a candle that seem just about right eh, louis? life is short when you're done, you're done we're on this earth to have some fun and that's the way things are
#
#
# louis
# say it, brother!
#
#
# prince naveen
# when i'm human, and i'm gonna be i'm gonna tear it up like i did before that's a royal guarantee
#
#
# tiana
# you are getting married!
#
#
# prince naveen
# all right. i just have to leave a string of broken hearts behind me.
#
#
# tiana
# your modesty becomes you and your sense of responsibility i worked hard for everything i got and that's the way it's supposed to be when i'm a human being at least i'll act like one if you do your best each and every day good things are sure to come your way what you give is what you get! my daddy said that and now i'll never forget and i commend it to you
#
#
#  all
# when we're human and we're gonna be
#
#
#  louis
# i'm gonna blow my horn!
#
#
# prince naveen
# i'm gonna live the high life!
#
#
# tiana
# i'm gonna do my best to take my place in the sun
#
#
# all
# when we're human!
#
#
# charlotte
# oh, prince naveen, dear. i am positively mortified you had to endure that frog fiasco last night.
#
#
# lawrence
# well, when you're next in line for the throne, you're poised like a panther, ready to expect the unexpected.
#
#
# charlotte
# yyour ear?
#
#
# lawrence
# what? oh, there's pesky mosquitoes... everywhere. please, miss charlotte, i can no longer ignore the throbbing of my... heart. even though our time together's been brief, it's been heavenly.
#
#
# charlotte
# please, prince naveen, you got me blushin' 'til i...
#
#
# lawrence
# would you do me the honor of becoming princess of maldonia?
#
#
# charlotte
# are you serious?
#
#
# lawrence
# as the plague.
#
#
# charlotte
# yes! oh, i most definitely will marry you! oh, there's so much to plan! the guest list! the dress! the music! the flowers! the shoes! we're gonna have ourselves a mardi gras weddin'.
#
#
# dr. facilier
# no! what we do now? because somebody let our frog prince go, larry ... i'm reduced to ask for help from my friends on the other side.
#
#
# louis
# now, that restaurant of yours, is it gonna have étouffée?
#
#
# tiana
# jambalaya, gumbo ...it's gonna have it all! it's gonna have it all!
#
#
# louis
# i always wanted to try red beans and rice, muffulettas, po' boys...
#
#
# prince naveen
# stop louis. you two are making me so very hungry.
#
#
# prince naveen
# interesting.
#
#
# tiana
# what are you doing?
#
#
# prince naveen
# you are frightening the food. this is harder than it looks.
#
#
# tiana
# what? oh, no! no, no, no! there is no way i'm kissing a frog and eating a bug on the same day. .
#
#
# prince naveen
# hello
#
#
# tiana
# what are you doin'? stop moving!
#
#
# prince naveen
# you are making this very difficult.
#
#
# louis
# y'all found anything to eat yet, ah? oh, my! hang on. old louis got it covered.
#
#
# tiana
# no, no, no, no ...
#
#
# louis
# how's that?
#
#
# tiana
# this could be a little better.
#
#
# louis
# you know what this needs? a sharp stick! be right back!
#
#
# tiana
# this is all your fault!
#
#
# prince naveen
# my fault... my fault ... let me tell you something. i was...
#
#
# ray
# well, lookee here! girl, i guess you and your boyfriend got a little carried away, am i right, am i right?
#
#
# tiana
# no, no, no, that's not possible!
#
#
# prince naveen
# ... i am the prince of maldonia!
#
#
# ray
# let me shine a little light on the situation. 'cuse me. one more time now. that's more better, yeah. oh, it's ok baby, i'm not gonna explode me. i ain't no fire cracka! got my big butt glowing. right. women like a man with big back porch. oh you know... now you done this up real good for sure. now where this go to at?
#
#
# tiana
# oh, dear!
#
#
# ray
# hang on, cap'. i'm just gonna give a little twist here. we're getting to know each other now!
#
#
#  prince naveen
# pardon me, but your accent... it's funny, you know?
#
#
# ray
# aw i'm a cajun bro, born and bred in the bayou y'all must be a new around here, ah ?
#
#
# prince naveen
# actually, we're from a place ... far, far away from this world.
#
#
# ray
# go to bed. y'all from shreveport ?
#
#
# prince naveen
# no, no, no. we are people!
#
#
# tiana
# the prince charming here got himself turned into a frog by a voodoo witch doctor.
#
#
# ray
# well, there you go. tiana and we are on a way to mama odie's, we think maybe she could...
#
#
# ray
# mama odie? you are headin' the wrong direction,cher. now what kinda chucklehead told y'all to go thisa way?
#
#
# louis
# i found the stick!
#
#
# tiana
# louis ... ray here says you've been taking us in the wrong direction.
#
#
# louis
# i was ...listen, i was confused by the topography and... the geography and choreography.
#
#
# ray
# fist rule the bayou. never take the rescue from a gator. me and my relationals will help you yard the way. achedanza!
#
#
# ray
# cousin randy, you are ready for the bayou zydeco.
#
#
# firefly
# ready when you are, cousin ray!
#
#
#  ray
# alright, lulu! let's get to it, darling! come on, cheri! just follow the bouncing butt!.
#
#
#  ray
# we're gonna take ya down, we're gonna take ya down we're gonna take ya all the way down. we're gonna take ya down, we're gonna take ya down we're gonna take ya all the way. goin' down the bayou! goin' down the bayou! goin' down the bayou! taking ya all the way! we got the whole family! there goes mimi! cousin boudreau! grandma ma, you're light out! we all gon' pool together down here that's how we do! me for them, and them for me, we all be there for you! we're gonna take ya, we're gonna take ya we're gonna take ya all the way down we know where yer going and we're going with you taking you all the way goin' down the bayou! goin' down the bayou! goin' down the bayou! take y'all.... yeah, you know! come on y'all! keep that life flowin', and them lights a'glowin! yeah, you're right!
#
#
# dr. facilier
# friends, i know i'm in hack to you all pretty deep already, but it seems or little froggy prince lost his way. and i need your generous assistance getting him back. hahaha, i hear you. now, what's in it for you? well... as soon as i dispose of "big daddy" la bouff, then i'm gonna run this town. i'll have the entire city of new orleans in the palm of my hand. and you'll have all the wayward souls your dark little hearts desire. y'all love that, don't you? so, we got ourselves a deal? hahaha! now we're cooking! we're gonna find ourselves a frog.
#
#
# search everywhere
# the bayou, the quarter... bring him to me alive. i need his heart pumping... for now. allez, tout de suite!
#
#
# ray
# i'll take you the rest of way!
#
#
# tiana
# nice meetin' you all!
#
#
# firefly
# bye, bye pooky!
#
#
# firefly
# adieu, bye, bye amis.
#
#
# ray
# and don't forget to tell angela that ray said bonjour!
#
#
#  tiana
# that's your girl?
#
#
# ray
# oh, no, no, no ... my girl. . .that's evangeline.
#
#
# tiana
# evangeline?
#
#
# ray
# she is the most prettiest butterfly ever did glow. you know, i talk to evangeline almost every night. she is kind of shy, don't say much. but i know in my heart someday we gonna be together.
#
#
# tiana
# oh, that's so sweet.
#
#
# prince naveen
# yes, so sweet ... just do not settle down so quickly, friend. there are plenty of fireflies in this world. what?
#
#
# louis
# pricker bus hers got me ... get down, get down! darkness ... it's closin' in. i'm so cold.
#
#
# ray
# will you hold still, big baby? i ain't touched it yet
#
#
# hunter 1
# oh, take a look at that two jumpers. i can taste the frog legs already... with a sauce picante, right pa?
#
#
# hunter 2
# will you keep quiet!
#
#
# hunter 1
# oh, my thought is exactly the same. it's time to catch up some frogs.
#
#
# prince naveen
# you know, waitress, i finally figured out what is wrong with you.
#
#
# tiana
# have you, now?
#
#
# prince naveen
# you do not know how to have fun. there. somebody had to say it.
#
#
#  tiana
# thank you, 'cause i figured out what your problem is too.
#
#
# prince naveen
# i am... too wonderful? no, you're a nocount, philanderin', lazy bump on a log.
#
#
# prince naveen
# ahaha... killjoy.
#
#
#  tiana
# what'd you say?
#
#
# prince naveen
# ah, nothing. stick in the mud.
#
#
# tiana
# listen here, mister. this stick in the mud has had to work two jobs her whole life while you've been sucking on a silver spoon chasing chamber maids around your... your ivory tower!
#
#
#  prince naveen
# actually, it's polished marble.
#
#
# hunter 1
# uh, i got me one, boys! get the little one over there. the hunt was good today, yes indeed?
#
#
# louis
# hunters with guns!
#
#
# hunter
# look at his big frog legs. i will make some corn bread with this one!
#
#
# ray
# oh, no, no, no. a bug gotta do what a bug gotta do! i think i got chipped my favorite tooth.
#
#
# hunter
# here i come, two fingers, i'll help. pa, we got one. be on quiet y'all.
#
#
# hunter 2
# what happened to yours? shut your preaft, darnell.
#
#
#  prince naveen
# i'm free!
#
#
# hunter 2
# pa, did you hear that suspicious tide?
#
#
# hunter 1
# yeah ... i surely did. what you two gawkin' at...?
#
#
#  hunter 1
# just miss it there.
#
#
# prince naveen
# now, go!
#
#
# hunter 1
# stop.
#
#
# hunter 2
# no, no, no, you idiot, don't shoot.
#
#
# prince naveen
# watch this.
#
#
# hunter 1
# missed it!
#
#
# hunter 2
# get out of way!
#
#
# hunter 1
# these two ain't like no frogs i've ever seen. they smart.
#
#
# tiana
# and we talk, too.
#
#
# louis
# you alright there, little bud?
#
#
# ray
# oh, i'm fine... but your breath done killed me to death!
#
#
# louis
# would you mind?
#
#
# ray
# i got you cover, brah.
#
#
# louis
# ah, much obliged, peewee. now how about ... the other side.
#
#
# prince naveen
# and we talk too. i like that! you are secretly funny.
#
#
# tiana
# not a stick in the mud?
#
#
# prince naven
# wwell i was...
#
#
# tiana
# say it. co... say it.
#
#
# prince naveen
# all right... you're not exactly...
#
#
# tiana
# i can't hear you, i'm sorry. what?
#
#
# prince naveen
# ...a complete stick deep in the mud.
#
#
# ray
# easy! easy! i get this one in there, in it, now hold on. sug', i know we got to get to mama odie lickety split but ... this particular extractification gonna take a while, yeah.
#
#
# tiana
# oh, poor louis.
#
#
# louis
# you know what would make me feel better? crawfish snuged in remoulade sauce. slow down!
#
#
# ray
# got a lil more!
#
#
#  louis
# some banana foster sprinkled with brollies.
#
#
# tiana
# how about swamp gumbo?
#
#
# louis
# that'll do.
#
#
# prince naveen
# sounds delicious! i'll start with pre dinner cocktail and something to nibble on, while i wait, thanks.
#
#
# tiana
# no, no, no, no, your royal highness.
#
#
# prince naveen
# what's a matter?
#
#
# tiana
# you are gonna to mince these mushrooms.
#
#
# prince naveen
# to do what?
#
#
# tiana
# mince the mushrooms. hop, to it!
#
#
# prince naveen
# this is ridiculous.
# tiana
# are you mincing?
#
#
# prince naveen
# all right ... relax. one!
#
#
# tiana
# step aside, mister. watch ... and learn.
#
#
# prince naveen
# all right.
#
#
# tiana
# there you go.
#
#
# prince naveen
# you know, i never done anything like this before.
#
#
#  tiana
# really?
#
#
# prince naveen
# all right. but, when you are livin' in a castle everything is done for you all the time they dress you, they feed you, drive you... brush your teeth!
#
#
# tiana
# aw, poor baby.
#
#
#  prince naveen
# i admitted it was a charmed life, until the day my parents cut me off, and suddenly i realized... i don't know how to do anything.
#
#
#  tiana
# well hey ... you've got the makings of a decent mushroom mincer!
#
#
#  prince naveen
# oh, you think so?
#
#
# tiana
# keep practicing and i just might hire you.
#
#
# prince naveen
# really?
#
#
# tiana
# no.
#
#
# prince naveen
# come on ... what was that?! that was below the frog belt...
#
#
# ray
# you said hello and he said what. and you said that a ugly fish!
#
#
# tiana
# anyone for seconds?
#
#
# prince naveen
# that was magnificent... you truly have a gift.
#
#
# tiana
# well! thank you!
#
#
# ray
# there she is. the sweetest firefly of all creation.
#
#
# tiana
# evangeline?
#
#
# louis
# i want to meet this girl, where she is?
#
#
# ray
# how can you miss her, she glows right up there, in front of y'all.
#
#
# ray
# look how she lights up the sky ma belle evangeline
#
#
# louis
# oh, that ain't no firefly, that's a...
#
#
# ray
# so far above me yet i know her heart belongs to only me j t'adore. prince naveen i adore you. ray je t'aime. prince naveen i love you.
#
#
#  ray
# evangeline
#
#
# prince naveen
# i'm just translating!
#
#
# ray
# you're my queen of the night so still, so bright to someone as beautiful as she who loves someone like me
#
#
# tiana
# no, no. i don't dance.
#
#
# ray
# love always finds a way, it's true
#
#
# tiana
# i've never danced. and i love you evangeline
#
#
# prince naveen
# if i can mince, you can dance.
#
#
# ray
# oooh, yeah! love is beautiful love is wonderful love is everything, do you agree? mais oui! look how she lights up the sky i love you, evangeline
#
#
# tiana
# ah, lottie's getting' one heck of a dance partner. we ... best we pushin' on.
#
#
# prince naveen
# tiana!
#
#
# tiana
# naveen! no, no, no.
#
#
# mama odie
# not bad for a 197 year old blind lady. now, which one of you naughty kiddy been messing with the shadow man?
#
#
# tiana
# we so glad we found you mama odie. ray and louis here been tellin' us all about you. we've been travelling quite a long way. and you can't imagine what we've been through. and we... and we heard that you ...
#
#
# mama odie
# juju! come on, over here, you bad boy. give a little sugar now. you just loves your mama, don't you? good to see you again, ray. how's your grandmama?
#
#
# ray
# oh, she's fine. got in a little trouble for flashing the neighbors again.
#
#
# mama odie
# ouh! i like that gal's spunk.
#
#
# tiana
# mama odie ... we don't want to take too much of your time.
#
#
# mama odie
# you want some candies?
#
#
# prince naveen
# no, not really.
#
#
# tiana
# no, no thank you.
#
#
# mama odie
# well now, that's too bad. this is a special candy. woulda turn y'all human.
#
#
# tiana
# no, no, no, please.
#
#
# mama odie
# i'm just messing with y'all.
#
#
# tiana
# how on earth did you know that we want to turn back...
#
#
# prince naveen
# mama odie?
#
#
# mama odie
# juju! why didn't you tell me my gumbo was burnin'?
#
#
# louis
# you sure this is the right blind voodoo lady who lives in the boat in the tree in the bayou?
#
#
# ray
# pretty sure.
#
#
# mama odie
# i can't believe this, got to do everythin' around here.
#
#
# tiana
# mama odie, if you ...
#
#
# mama odie
# taste it. well?
#
#
# tiana
# hit it hard with a couple of shots of tabasco, and it's the bee's knees! now, can we...
#
#
# mama odie
# juju! that's got some zang to it. i guess that's what it needed. now, you figured out what you need?
#
#
# tiana
# it's just like you said, mama odie. we need to be human. y'all ain't got the sense y'all was born with! you want to be human ... but you blind to what you need.
#
#
# prince naveen
# what we want, what we need ... it's all the same thing, yes?
#
#
# mama odie
# it's the same thing? no!
#
#
# mama odie
# you listen to your mama now. don't matter what you look like don't matter what you wear how many rings you got on your finger we don't care no we don't care don't matter where you come from don't even matter what you are a dog, a pig, a cow, a goat had 'em all in here we had 'em all in here and they all knew what they wanted what they wanted me to do i told 'em what they needed just like i be telling you you got to dig a little deeper find out who you are you got to dig a little deeper it really ain't that far when you find out who you are you'll find out what you need blue skies and sunshine guaranteed you got to dig dig you got to dig dig prince froggy is a rich little boy you wanna be rich again that ain't gonna make you happy now did it make you happy then? no! money ain't got no soul money ain't got no heart all you need is some selfcontrol make yourself a brand new start you got to dig a little deeper don't have far to go you got to dig a little deeper tell the people mama told you so can't tell you what you'll find maybe love will grant you peace of mind dig a little deeper and you'll know miss froggy,
#
#
# tiana
# ma'am ?
#
#
# mama odie
# might i have a word?
#
#
# tiana
# yes, ma'am.
#
#
# mama odie
# you's a hard one, that's what i heard your daddy was a loving man family through and through you your daddy's daughter what he had in him you got in you you got to dig a little deeper for you it's gonna be tough you got to dig a little deeper you ain't dug near far enough dig down deep inside yourself you'll find out what you need blue skies and sunshine guaranteed open up the windows let in the light children blue skies and sunshine blue skies and sunshine blue skies and sunshine guaranteed... well, miss froggy? do you understand what you need now, child?
#
#
# tiana
# yes! i do, mama odie. i need to dig a little deeper and work even harder to get my restaurant.
#
#
# mama odie
# all right y'all, one more time. it don't matter what you look like it don't...
#
#
# ray
# nobody goin' to sing with ray? okay.
#
#
# mama odie
# well, if y'all are set on bein' human there's only one way. gumbo, gumbo in the pot, we need a princess. whatcha got?
#
#
#  tiana
# lottie? but she is not a princess!
#
#
# mama odie
# oh, shut and look at gumbo!
#
#
#  tiana
# that's right ... big daddy is king of mardi gras parade. so, that makes lottie... a princess.
#
#
# prince naveen
# does that count?
#
#
# mama odie
# yes it does, but only 'til midnight, when mardi gras is over. hoplone, you only got 'til the end to got that princess to kiss you. once she does ... you both turnin' human.
#
#
# prince naveen
# midnight? that doesn't give us much time at all.
#
#
# louis
# what about me, mama? i want to be human too, so i can play jazz with the big boys. i want fingers, and toes, and a belly button, not the kind that sticks out, but the kind that goes in. . . jabber jaws, you dig little deeper, you'll find everythin' you need. c'mon, c'mon, c'mon... there's a lotta river between here and n'orleans. y'all best get to swimmin'.
#
#
# louis
# wait... i've got a better idea.
#
#
# louis
# they got guns!
#
#
#  boat guest
# bam, that is one killer diller costume. hey gator, can you blow that horn?
#
#
# boat guest
# come on, stay in with us. we play on mardi gras.
#
#
#  ray
# we can't miss this. little louis gonna finally play with the big boys.
#
#
# tiana
# naveen, you comin'?
#
#
# prince naveen
# i'll catch up with you later. oh, evangeline ... why i can't just look tiana in the eyes and say i will do whatever it takes to make all your dreams come true, because ... because i love you.
#
#
# ray
# whoa, whoa, whoa, cap'. you are makin' googoo eyes on my girl? got you! i will make some shoes out of you.
#
#
# prince naveen
# ray, i'm not in love with evangeline i am in love with tiana.
#
#
# ray
# i knew it, i knew it, i knew it. you come here, you...
#
#
# prince naveen
# i can't no longer marry miss charlotte la bouff.
#
#
# ray
# you will be so happy together.
#
#
# prince naveen
# i will find another way to get tiana a restaurant.
#
#
#  ray
# you coulda have a cute, little tadpoles.
#
#
# prince naveen
# i'll get job, maybe two. maybe three?
#
#
# ray
# i can't wait to tell her.
#
#
# prince naveen
# no, no, no. i must tell her. alone.
#
#
# ray
# right, you bet...
#
#
# tiana
# where are you taking me?
#
#
# prince naveen
# oh, i just... wanted to show you little something to celebrate our last night together as frogs.
#
#
#  tiana
# oh... all my years. no one's ever done anything like this for me.
#
#
#  prince naveen
# i it is too much, isn't it? um... thank you, bow.
#
#
# butterfly
# i thought it was a nice touch.
#
#
# prince naveen
# pretend you did not see that. please, please sit down.
#
#
# tiana
# what's this?
#
#
# prince naveen
# tada!
#
#
# tiana
# you minced!
#
#
# prince naveen
# i did! you have had quite an influence on me. which is amazing because i have dated thousands of women and... no, like two, three... just other women! aand anyway, you could not be more different! you know, you are you are practically, one of the guys! no no no! you are not a guy! let me begin again! uh... ha... i am not myself tonight. tiana! sorry, that was loud. this is a disaster.
#
#
# tiana
# no, it's cute.
#
#
# prince naveen
# tiana ... i ...
#
#
# tiana
# there it is!
#
#
# prince naveen
# your restaurant?
#
#
# tiana
# oh, can you just picture it? all lit up like the fourth of july.
#
#
# prince naveen
# yes, jazz pouring out from every window.
#
#
# tiana
# it should be elegant. prince naveen you should keep it loose, let it swing
#
#
# tiana
# you know a good ukulele player?
#
#
# prince naveen
# really? you let me perform?
#
#
# tiana
# i'll talk to the owner ... owner says...yes. folks are gonna be comin' together from all walks of life just to get a taste of our food.
#
#
# prince naveen
# our food?
#
#
# tiana
# oh no, no, no. my daddy... he always wanted open this restaurant. he died before he could see it happened. but tomorrow ... with your help. our dream is finally comin' true.
#
#
# prince naveen
# tomorrow?
#
#
# tiana
# if i don't deliver that money first thing tomorrow, i lose this place forever.
#
#
# prince naveen
# tiana, i love ... the way you light up when you talk about your dream. a dream that it is so beautiful i ... i promise ... i will do whatever it takes to make it come true.
#
#
# captain
# port of new orleans. all ashore.
#
#
# prince naveen
# i. .. i'll go round up the boys.
#
#
# tiana
# evangeline ... i've always been so sure about what i wanted. but now ... what do i do? please tell me.
#
#
# charlotte
# prince naveen, darlin'. you better hurry up. don't wanna be late for our mardi gras weddin'.
#
#
# lawrence
# getting dressed just a few moments, my dear charlotte.
#
#
# charlotte
# okay, honeylame. we'll been waitin' in the packwood. daddy, start the car!
#
#
# lawrence
# oh, heavens ... i'm doomed.
#
#
# dr. facilier
# no, larry. i'm the one who's doomed. less me get that frog's blood...
#
#
# dr. facilier
# no! we are back in business, boys.
#
#
# prince naveen
# get your filthy hands off me. lawrence?
#
#
# lawrence
# hold still, your eminence.
#
#
# tiana
# ray, have you seen naveen?
#
#
# ray
# look at you, where's the ring at?
#
#
# tiana
# what are you talking about?
#
#
# ray
# well, if captain say nothing i ain't gonna say nothing. because old ray sealed up tight as a drum you ain't got nothin' out of me, no!
#
#
# tiana
# ray?
#
#
# ray
# okay, captain ain't gonna marry charlotte he gonna marry you. soon as he get himself kissed, and you both turn human, he go find a job, get you that restaurant. i said too much, didn't i?
#
#
# tiana
# you said just enough, ray! thank you, evangeline. he was trying to propose, that's what all that fumbling was about and here i thought, all he wanted was to marry a rich girl.
#
#
# ray
# sug', what are we looking for in here?
#
#
# tiana
# you just keep your eyes at one of of the biggest gaudiest floats with a mardi gras princess about to kissed herself a ...a frog.
#
#
# priest
# dear beloved, we are gathered here tonight in this fine celebration to join together this prince and this woman in holy matrimony.
#
#
# ray
# oh, no, this can't be right, darlin'. then how you can still be a frog? mama odie...she's...
#
#
# ray
# i know what we've seen with our eyes but... if we just go back there we gonna find that your fairy tale come true.
#
#
# tiana
# just because you wish for somethin', doesn't make it true.
#
#
# ray
# it's like my evangeline always said to me ...
#
#
# tiana
# evangeline is nothing but a star, ray! a big ball of hot air a million miles from here. open your eyes now! before you get hurt.
#
#
# ray
# she's just speaking out of a broken heart. that's all that is. come on evangeline. we gonna show chere the truth.
#
#
#  priest
# if any of you, object to the union of this two people speak now or forever hold your plea.
#
#
# prince naveen
# me, me, i object.
#
#
# priest
# do you, prince naveen, take charlotte to be your wife ...
#
#
# ray
# cap, what are you doing, son?
#
#
# priest
# ...as long as you both shall live?
#
#
# lawrence
# what? i do ... yes, i'm for it.
#
#
# ray
# is that you, cap?
#
#
# prince naveen
# ray, get me out of this box!
#
#
# ray
# i can't hear you, i'm gonna get you out of this box.
#
#
# priest
# ...as long as you both shall live?
#
#
# charlotte
# oh, i do.
#
#
# priest
# then so, by the power invested in me by the state of louisiana i now pronounce you ... man and. .. charlotte prince naveen! goodness gracious! are you all right?
#
#
# lawrence
# i just need a moment to compose myself.
#
#
# charlotte
# cheese and crackers!
#
#
# prince naveen
# lawrence, why are you doing this?
#
#
# lawrence
# it's payback for all those years of... humiliation.
#
#
# dr. facilier
# get your royal rump back on that wedding cake and finish this deal.
#
#
# dr. facilier
# what is he doing? stop him!
#
#
# lawrence
# give me that!
#
#
# ray
# i got it. it got me too!
#
#
# lawrence
# let go of that!
#
#
# dr. facilier
# stay out of sight!
#
#
# louis
# ray?
#
#
# other band member
# hey, why did you stop?
#
#
# man
# he's a real gator!
#
#
# ray
# cherie, cherie!
#
#
# tiana
# ray?
#
#
# ray
# this proves what we saw ain't what we thought we saw. what is this? it's voodoo, how ya call it? the shadow man, he's been usin' voodoo...
#
#
# ray
# you can't let shadow man get this, no matter what. now run girl, run! do not make me light my butt. i got lightin' on me. come here, you! ok, come! ok who's next?
#
#
# louis
# ray! what ... ray?
#
#
# tiana
# back off! or i'm gonna break this into a million pieces. naveen?
#
#
# dr. facilier
# now, isn't this whole life better than hoppin' around bayou for the rest of your life??
#
#
# tiana
# shadow man?
#
#
# dr. facilier
# got a head to you, tiana. when you dream, you dream big. just look at this place! gonna be the crown jewel of the crescent city and all you got to do, to make this reality it's handle that little old talisman of mine.
#
#
# tiana
# no. thisthis is not right.
#
#
# dr. facilier
# come on, darlin'? think of everything you sacrificed.
#
#
# geogria
# girl, all you ever do is work.
#
#
# violet
# i told y'all she wouldn't come.
#
#
# dr. facilier
# think of all those maecenas who doubted you.
#
#
# burford
# you ain't never gonna get enough for the dang payment.
#
#
# mr. fenner
# woman of your background, you better off where y'are.
#
#
# dr. facilier
# and don't forget your poor daddy. now, that was one hard working man.
#
#
# eudora
# see you tomorrow, james!
#
#
# dr. facilier
# double, sometimes triple shifts. never let know how bone tired, beat down he really was.
#
#
# tiana
# daddy!
#
#
# james
# hey, babby cakes.
#
#
# dr. facilier
# shame on that hard work, didn't amount much more than a busted up, old gumbo pot. and a dream that never get off the back porch. but you ... you can give your poor daddy everything he ever wanted. come on, tiana. you're almost there.
#
#
# tiana
# my daddy never did get what he wanted. but he had what he needed. he had love. never lost a sight what was really important.
#
#
# dr. facilier
# easy with that! careful!
#
#
# tiana
# and neither will i.
#
#
# dr. facilier
# y'all should've taken my deal. now you will spend the rest of your life bein' a slimy little frog!
#
#
# tiana
# i got news for you, shadow man! it's not slime, it's mucus!
#
#
# dr. facilier
# no! no! how am i ever gonna pay back my debt?!
#
#
# dr. facilier
# friends!
#
#
# voodoo masks
# are you ready?
#
#
# dr. facilier
# no! i'm not ready at all! in fact, i got lots more plans!
#
#
# voodoo masks
# are you ready?
#
#
# dr. facilier
# this is just a minor setback in a major operation! as soon as i whip up another spell, we'll be back in business! i still got that froggy prince locked away! i just need a little more time. no! no, please, no! just a little more time! i promise i'll pay y'all back! i promise!
#
#
# charlotte
# prince! prince naveen your shy and retirin' bride to be is gettin' antsy.
#
#
# lawrence
# hello, darling!
#
#
# prince naveen
# miss la bouff please down here. let me to introduce myself. i am the real prince naveen!
#
#
# prince naveen
# of maldonia.
#
#
# charlotte
# did you say prince?
#
#
# big daddy
# boys, drag this maggot down to the parish prison.
#
#
# lawrence
# i'm completely innocent. the shadow man bamboozled me.
#
#
# charlotte
# goodness gracious! this is so much to absorb. let me see if i got this right. if i kiss you before midnight, you and tiana will turn human again, and then we gonna get ourselves married and live happily ever after! the end!
#
#
# prince naveen
# yeah, more or less. but remember, you must give tiana all the money she requires for her restaurant. because tiana ... she is my evangeline.
#
#
# charlotte
# anything you want, sugar. pucker up, buttercup!
#
#
# tiana
# wait!
#
#
# charlotte
# tiana?
#
#
# prince naveen
# tiana?
#
#
# tiana
# don't do this.
#
#
# prince naveen
# i have to do this and we are running out of time!
#
#
# tiana
# i won't let you!
#
#
# prince naveen
# it's the only way to get you your dream!
#
#
# tiana
# my dream? my dream wouldn't be complete... without you in it. i love you, naveen.
#
#
# prince naveen
# warts and all?
#
#
# tiana
# warts and all.
#
#
# charlotte
# all my life, i read about true love and fairytales, and... tia, you found it! i'll kiss him! for you, honey! no marriage required.
#
#
# charlotte
# oh my word! mmaybe that ol' clock's a little fast! i'm so sorry!
#
#
# louis
# tiana! naveen!
#
#
# prince naveen
# louis, what is it?
#
#
# louis
# shadow man lay poor ray low!
#
#
# tiana
# ray?
#
#
# louis
# he's hurtin' awful bad.
#
#
# ray
# hey, cherie! how come, y'all still ...
#
#
# tiana
# we are stayin' frogs, ray. and we are stayin' together.
#
#
#  ray
# oh, i like that very much. evangeline like that too.
#
#
# mama odie
# so, by the power invested in me ... i now pronounce you frog and wife. get to it, hop lone, and give your lovely bride some sugar. congratulations! this gonna be good!
#
#
# mama odie
# like i told y'all, kissing a princess breaks the spell.
#
#
# prince naveen
# once you became my wife, that made you ...
#
#
# tiana
# a princess. you just kissed yourself a princess!
#
#
# prince naveen
# and i'm about to do it again!
#
#
#  tiana
# in the south land there's a city way down on the river where the women are very pretty and all the men deliver they got music it's always playin' start in the day time, go all through the night when you hear that music playin' hear what i'm saying and make it feel alright
#
#
# charlotte
# who would've thought the prince woulda had a er brother. how old did you say you were?
#
#
#  prince
# i'm six and a half.
#
#
# charlotte
# well, i waited this long.
#
#
# tiana
# grab somebody, come on down bring your paintbrush, we're painting the town there's some sweetness going around dreams do come true in new orleans.

# %% [markdown]
# ## In Summary:
# The two movies with the most problems are Frozen and tangled. Both seem to have been scraped from a webpage. While Frozen COULD be edited by going through line by line, this may be tedious. Tangled, on the other hand, is missing the last two-thirds of the movie. I may have to do my own scraping.
