# %% [markdown]
# ## Total Token/Type Stats per Character
# Because lines are so short, and therefore not necessarily informative in terms of ttr and k-band, here I will group together a characters total token/type count (in terms of dialogue only)

# %%
#importing my pickle file
import pandas as pd

# %%
movie_df = pd.read_pickle(r"C:/Users/cassi/Desktop/Data_Science/Animated-Movie-Gendered-Dialogue/private/all_movies_toktype.pkl")

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14096 entries, 0 to 14095
# Data columns (total 14 columns):
# Disney_Period       14096 non-null object
# Gender              14096 non-null object
# Movie               14096 non-null object
# Role                14096 non-null object
# Song                14096 non-null object
# Speaker             14096 non-null object
# Speaker_Status      14096 non-null object
# Text                14096 non-null object
# UTTERANCE_NUMBER    14096 non-null int64
# Year                14096 non-null int64
# Tokens              14096 non-null object
# Types               14096 non-null object
# Token_Count         14096 non-null int64
# Type_Count          14096 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 991.2+ KB

# %%
movie_df = movie_df[movie_df.Song == 'D']

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13450 entries, 0 to 14095
# Data columns (total 14 columns):
# Disney_Period       13450 non-null object
# Gender              13450 non-null object
# Movie               13450 non-null object
# Role                13450 non-null object
# Song                13450 non-null object
# Speaker             13450 non-null object
# Speaker_Status      13450 non-null object
# Text                13450 non-null object
# UTTERANCE_NUMBER    13450 non-null int64
# Year                13450 non-null int64
# Tokens              13450 non-null object
# Types               13450 non-null object
# Token_Count         13450 non-null int64
# Type_Count          13450 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# First, let's attempt this on a small scale

# %%
movie_sample = movie_df.sample(500)

# %%
movie_sample.Movie.unique()
# Out:
# array(['How to Train Your Dragon 2', 'Shrek 3',
#        'How to Train Your Dragon', 'The Princess and the Frog', 'Antz',
#        'Frozen', 'Rise of the Guardians', 'Kung Fu Panda',
#        'The Little Mermaid', 'The Croods', 'Tangled', 'Pocahontas',
#        'Beauty and the Beast', 'Megamind', 'Shrek', 'Brave', 'Cinderella',
#        'Aladdin', 'Moana', 'Sleeping Beauty', 'Snow White', 'Mulan'],
#       dtype=object)

# %%
movie_sample.head()
# Out:
#       Disney_Period Gender                       Movie    Role Song   Speaker  \
# 13509    DREAMWORKS      m  How to Train Your Dragon 2     ANT    D      eret
# 9492     DREAMWORKS      f                     Shrek 3     PRO    D     fiona
# 10688    DREAMWORKS      m    How to Train Your Dragon  HELPER    D  snotlout
# 5036           LATE      m   The Princess and the Frog  HELPER    D       ray
# 8026     DREAMWORKS      m                        Antz     PRO    D         z
#
#       Speaker_Status                                               Text  \
# 13509          NON-P  this is what he gave me last time i showed up ...
# 9492        PRINCESS                                            i care.
# 10688          NON-P  what was that? some kind of trick? what did yo...
# 5036           NON-P  i knew it, i knew it, i knew it. you come here...
# 8026           NON-P  we need to form a scaffolding around this moun...
#
#        UTTERANCE_NUMBER  Year  \
# 13509               122  2014
# 9492                705  2007
# 10688               342  2010
# 5036                517  2009
# 8026                605  1998
#
#                                                   Tokens  \
# 13509  [this, is, what, he, gave, me, last, time, i, ...
# 9492                                        [i, care, .]
# 10688  [what, was, that, ?, some, kind, of, trick, ?,...
# 5036   [i, knew, it, ,, i, knew, it, ,, i, knew, it, ...
# 8026   [we, need, to, form, a, scaffolding, around, t...
#
#                                                    Types  Token_Count  \
# 13509  {understanding, he, is, time, last, gave, be, ...           24
# 9492                                        {i, care, .}            3
# 10688  {was, ?, did, that, what, trick, some, you, ki...           14
# 5036           {here, ..., knew, ,, it, i, you, ., come}           18
# 8026   {let, to, mound, a, 's, it, form, need, we, !,...           15
#
#        Type_Count
# 13509          22
# 9492            3
# 10688          11
# 5036            9
# 8026           15

# %%
for movie in movie_sample.Movie.unique():
    movie_data = movie_sample[movie_sample.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        print('\t'+char)
# Out:
# Movie:How to Train Your Dragon 2
# 	eret
# 	hiccup
# 	drago
# 	valka
# 	stoick
# 	snotlout
# 	teeny
# 	hoark
# 	astrid
# Movie:Shrek 3
# 	fiona
# 	pinocchio
# 	artie
# 	prince charming
# 	donkey
# 	king harold
# 	shrek
# 	master of ceremonies
# 	merlin
# 	rapunzel
# 	captain hook
# 	lancelot
# 	puss
# 	knight
# Movie:How to Train Your Dragon
# 	snotlout
# 	fishlegs
# 	gobber
# 	hiccup
# 	tuffnut
# 	hoark
# 	astrid
# 	stoick
# 	ruffnut
# Movie:The Princess and the Frog
# 	ray
# 	prince naveen
# 	eudora
# 	charlotte
# 	tiana
# 	alligator
# 	person
# 	mr. fenner
# 	mama odie
# Movie:Antz
# 	z
# 	azteca
# 	tracker ant
# 	carpenter
# 	bala
# 	weaver
# 	male wasp
# 	formica
# 	worker
# 	mandible
# Movie:Frozen
# 	kristoff
# 	anna
# 	olaf
# 	troll #2
# 	guard #2
# 	voice of man
# 	hans
# 	elsa
# 	spanish dignitary
# 	voice of woman
# 	french dignitary
# 	bulda
# Movie:Rise of the Guardians
# 	north
# 	pitch
# 	jack
# 	bunnymund
# 	jack's sister
# 	jamie
# 	tooth
# 	yeti
# 	caleb
# 	walker
# 	claude
# 	pippa
# 	sophie
# Movie:Kung Fu Panda
# 	po's dad
# 	po
# 	crane
# 	commander
# 	zeng
# 	shifu
# 	oogway
# 	tigress
# Movie:The Little Mermaid
# 	ariel
# 	triton
# 	flounder
# 	eric
# 	grimsby
# 	sebastian
# 	vanessa
# 	ursula
# Movie:The Croods
# 	grug
# 	ugga
# 	eep
# 	gran
# 	thunk
# 	guy
# 	belt
# 	sandy
# Movie:Tangled
# 	flynn
# 	rapunzel
# 	gothel
# Movie:Pocahontas
# 	nakoma
# 	grandmother willow
# 	englishman
# 	thomas
# 	john smith
# 	pocahontas
# 	ratcliffe
# 	wiggins
# 	powhatan
# Movie:Beauty and the Beast
# 	mrs. potts
# 	lumiere
# 	beast
# 	belle
# 	gaston
# 	maurice
# 	chip
# 	lefou
# Movie:Megamind
# 	minion
# 	megamind
# 	hal
# 	lord scott
# 	metro man
# 	roxanne ritchie
# Movie:Shrek
# 	shrek
# 	donkey
# 	fiona
# 	gingerbread man
# 	blind mouse1
# 	crowd
# 	farquaad
# 	man1
# Movie:Brave
# 	queen elinor
# 	merida
# 	lord macintosh
# Movie:Cinderella
# 	jaq
# 	drizella
# 	cinderella
# 	king
# 	fairy godmother
# 	gus
# 	stepmother
# 	birds
# Movie:Aladdin
# 	jasmine
# 	iago
# 	jafar
# 	aladdin
# 	cave
# 	gazeem
# 	sultan
# 	guard
# 	genie
# 	old man
# 	abu
# Movie:Moana
# 	moana
# 	maui
# 	tala
# 	tui
# 	young moana
# Movie:Sleeping Beauty
# 	fauna
# 	phillip
# 	merryweather
# 	flora
# 	hubert
# 	1st servant
# 	briar rose
# 	fairies
# Movie:Snow White
# 	happy
# 	all dwarfs
# 	doc
# 	snow white
# 	sneezy
# 	grumpy
# Movie:Mulan
# 	mushu
# 	fa zhou
# 	emperor
# 	ling
# 	mulan
# 	shang
# 	chi fu
# 	yao

# %%
for movie in movie_sample.Movie.unique():
    movie_data = movie_sample[movie_sample.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        all_toks = movie_data[movie_data.Speaker == char]['Tokens']
        all_toks_count = movie_data[movie_data.Speaker == char]['Token_Count']
        print('\t'+char)
        print(all_toks.sum())
        print(len(all_toks.sum())) #this returns a full list of all their lines! Sweet!
        print("DOUBLE CHECK:", all_toks_count.sum())
        print("TYPES:")
        print(len(set(all_toks.sum())))
        print(set(all_toks.sum()))
        #print(movie_data[movie_data.Speaker == char]['Types'].sum())
        #print(movie_data[movie_data.Speaker == char]['Type_Count'].sum())
        print(all_toks.map(len))
        print(all_toks)
# Out:
# Movie:How to Train Your Dragon 2
# 	eret
# ['this', 'is', 'what', 'he', 'gave', 'me', 'last', 'time', 'i', 'showed', 'up', 'empty-handed', '.', 'he', 'promised', 'to', 'be', 'far', 'less', 'understanding', 'in', 'the', 'future', '.', 'tie', 'those', 'legs', 'up', '!', 'net', '`', 'em', ',', 'lads', '!', 'take', '`', 'em', 'down', '!', 'have', 'you', 'forgotten', 'who', 'you', "'re", 'riding', 'with', '?', 'check', 'every', 'trap', '.', 'they', "'re", 'here', 'somewhere', '.']
# 58
# DOUBLE CHECK: 58
# TYPES:
# 47
# {'those', 'understanding', '?', 'he', 'is', 'time', 'last', '`', 'forgotten', 'you', 'gave', 'they', 'to', 'be', 'tie', ',', 'riding', 'somewhere', "'re", 'i', 'less', 'this', 'take', 'have', 'trap', 'here', 'with', 'up', 'future', 'promised', 'legs', 'me', '!', 'showed', 'lads', 'in', 'check', 'far', 'net', 'who', 'every', 'em', 'what', 'the', 'empty-handed', 'down', '.'}
# 13509    24
# 13491     5
# 13584    11
# 14016     9
# 13855     9
# Name: Tokens, dtype: int64
# 13509    [this, is, what, he, gave, me, last, time, i, ...
# 13491                            [tie, those, legs, up, !]
# 13584       [net, `, em, ,, lads, !, take, `, em, down, !]
# 14016    [have, you, forgotten, who, you, 're, riding, ...
# 13855    [check, every, trap, ., they, 're, here, somew...
# Name: Tokens, dtype: object
# 	hiccup
# ['because', 'some', 'guy', 'you', 'knew', 'is', 'stirring', 'up', 'trouble', 'in', 'some', 'faraway', 'land', '?', 'my', 'best', 'friend', '.', 'this', 'is', 'where', 'you', "'ve", 'been', 'for', 'twenty', 'years', '?', 'life', 'here', 'is', 'amazing', ',', 'just', 'not', 'for', 'the', 'faint', 'of', 'heart', '.', 'see', ',', 'where', 'most', 'folks', 'enjoy', 'hobbies', 'like', 'whittling', 'or', 'needlepoint', ',', 'we', 'berkians', 'prefer', 'a', 'little', 'something', 'we', 'like', 'to', 'call', '--', 'uh', ',', 'yeah', '.', 'i', 'could', 'eat', '.', 'not', 'again', '.', 'toothless', '!', 'it', "'s", 'now', 'or', 'never', '!', 'they', 'are', 'building', 'a', 'dragon', 'army', '.', 'you', "'re", 'right', '!', 'you', "'re", 'right', '!', 'you', 'win', '!', 'you', 'win', '!', 'what', 'are', 'you', 'guys', 'doing', 'here', '?', '!', 'it', 'was', "n't", 'your', 'fault', ',', 'bud', '.', 'they', 'made', 'you', 'do', 'it', '.']
# 126
# DOUBLE CHECK: 126
# TYPES:
# 82
# {'heart', "'ve", 'berkians', 'prefer', 'was', 'faint', '?', 'is', 'it', 'fault', 'building', 'hobbies', 'you', 'win', 'they', 'most', 'like', 'because', 'little', 'to', 'guy', 'twenty', 'your', ',', 'army', 'bud', 'right', 'folks', "'re", 'i', 'some', 'this', 'again', 'enjoy', 'here', 'just', 'could', 'eat', 'made', 'knew', 'up', 'uh', 'never', 'now', 'call', "'s", 'something', 'faraway', 'or', '!', 'doing', 'not', 'in', 'amazing', 'guys', "n't", 'we', 'of', 'whittling', 'yeah', 'dragon', 'trouble', 'do', 'my', 'see', 'land', 'needlepoint', 'a', 'best', 'years', 'life', 'where', 'stirring', 'the', 'what', 'been', 'for', 'toothless', '.', '--', 'are', 'friend'}
# 13565    14
# 14034     4
# 13678    10
# 13389    36
# 13730     8
# 14051    11
# 13550     7
# 13447    14
# 13619     8
# 14030    14
# Name: Tokens, dtype: int64
# 13565    [because, some, guy, you, knew, is, stirring, ...
# 14034                                [my, best, friend, .]
# 13678    [this, is, where, you, 've, been, for, twenty,...
# 13389    [life, here, is, amazing, ,, just, not, for, t...
# 13730                   [uh, ,, yeah, ., i, could, eat, .]
# 14051    [not, again, ., toothless, !, it, 's, now, or,...
# 13550            [they, are, building, a, dragon, army, .]
# 13447    [you, 're, right, !, you, 're, right, !, you, ...
# 13619            [what, are, you, guys, doing, here, ?, !]
# 14030    [it, was, n't, your, fault, ,, bud, ., they, m...
# Name: Tokens, dtype: object
# 	drago
# ['or', 'tear', 'them', 'apart', '.']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 5
# {'apart', 'or', 'them', 'tear', '.'}
# 13949    5
# Name: Tokens, dtype: int64
# 13949    [or, tear, them, apart, .]
# Name: Tokens, dtype: object
# 	valka
# ['do', "n't", '!']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {"n't", '!', 'do'}
# 13709    3
# Name: Tokens, dtype: int64
# 13709    [do, n't, !]
# Name: Tokens, dtype: object
# 	stoick
# ['hiccup', '!']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'!', 'hiccup'}
# 13580    2
# Name: Tokens, dtype: int64
# 13580    [hiccup, !]
# Name: Tokens, dtype: object
# 	snotlout
# ['did', 'i', 'tell', 'you', 'that', 'you', 'look', 'amazing', 'today', '?', '`', 'cause', 'you', 'do', '.']
# 15
# DOUBLE CHECK: 15
# TYPES:
# 13
# {'?', 'did', 'that', 'tell', 'today', '`', 'cause', 'i', 'do', 'you', 'amazing', 'look', '.'}
# 13394    15
# Name: Tokens, dtype: int64
# 13394    [did, i, tell, you, that, you, look, amazing, ...
# Name: Tokens, dtype: object
# 	teeny
# ['he', "'s", 'expecting', 'a', 'new', 'shipment', 'of', 'dragons', 'for', 'his', 'army', 'by', 'tomorrow', '.', 'no-name', 'and', 'drago', 'do', "n't", 'take', 'well', 'to', 'excuses', '.']
# 24
# DOUBLE CHECK: 24
# TYPES:
# 23
# {'by', 'he', 'expecting', 'new', 'to', 'army', 'drago', 'take', 'excuses', "'s", 'dragons', "n't", 'his', 'do', 'of', 'well', 'no-name', 'shipment', 'a', 'tomorrow', 'and', 'for', '.'}
# 13508    24
# Name: Tokens, dtype: int64
# 13508    [he, 's, expecting, a, new, shipment, of, drag...
# Name: Tokens, dtype: object
# 	hoark
# ['ah', ',', 'that', "'s", 'a', 'good', 'boy', '!']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'ah', 'boy', 'a', ',', 'good', "'s", 'that', '!'}
# 14008    8
# Name: Tokens, dtype: int64
# 14008    [ah, ,, that, 's, a, good, boy, !]
# Name: Tokens, dtype: object
# 	astrid
# ['what', "'s", 'down', 'there', '?']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 5
# {'?', "'s", 'what', 'down', 'there'}
# 13778    5
# Name: Tokens, dtype: int64
# 13778    [what, 's, down, there, ?]
# Name: Tokens, dtype: object
# Movie:Shrek 3
# 	fiona
# ['i', 'care', '.', 'what', '?', 'shrek', '!', 'daddy', '!']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 8
# {'shrek', '?', 'daddy', 'what', 'i', 'care', '!', '.'}
# 9492    3
# 9346    2
# 8851    2
# 8906    2
# Name: Tokens, dtype: int64
# 9492    [i, care, .]
# 9346       [what, ?]
# 8851      [shrek, !]
# 8906      [daddy, !]
# Name: Tokens, dtype: object
# 	pinocchio
# ['if', 'that', 'indeed', 'was', "n't", 'where', 'he', 'is', "n't", '.', 'even', 'if', 'he', 'was', "n't", 'not', 'where', 'i', 'knew', 'he', 'was', 'could', 'mean', 'that', 'i', 'would', "n't", 'completely', 'not', 'know', 'where', 'he', 'was', "n't", '.']
# 35
# DOUBLE CHECK: 35
# TYPES:
# 18
# {'if', 'would', 'knew', 'was', 'mean', 'he', 'that', 'is', 'even', 'where', 'i', 'know', 'not', '.', "n't", 'indeed', 'completely', 'could'}
# 9192    35
# Name: Tokens, dtype: int64
# 9192    [if, that, indeed, was, n't, where, he, is, n'...
# Name: Tokens, dtype: object
# 	artie
# ['okay', '.', 'there', "'s", 'a', 'baby', 'bird', 'and', 'a', 'father', 'bird', 'sitting', 'in', 'a', 'nest', '.', 'it', "'s", 'artie', ',', 'actually', '.', 'yeah', ',', 'yeah', ',', 'okay', '.', 'i', 'get', 'it', '.', 'the', 'bird', "'s", 'me', '.', 'my', 'dad', 'left', '.', 'so', 'what', '?']
# 44
# DOUBLE CHECK: 44
# TYPES:
# 27
# {'?', 'bird', 'it', 'father', 'baby', ',', 'left', 'sitting', 'okay', 'i', 'nest', 'so', "'s", 'me', 'in', 'there', 'yeah', 'artie', 'my', 'get', 'dad', 'a', 'and', 'the', 'what', 'actually', '.'}
# 9302    16
# 9468     6
# 9307    22
# Name: Tokens, dtype: int64
# 9302    [okay, ., there, 's, a, baby, bird, and, a, fa...
# 9468                      [it, 's, artie, ,, actually, .]
# 9307    [yeah, ,, yeah, ,, okay, ., i, get, it, ., the...
# Name: Tokens, dtype: object
# 	prince charming
# ['prepare', 'foul', 'beast-', 'i', 'suggest', 'you', 'freaks', 'cooperate', 'with', 'the', 'new', 'king', 'of', 'far', 'far', 'away', '.']
# 17
# DOUBLE CHECK: 17
# TYPES:
# 16
# {'prepare', 'with', 'cooperate', 'suggest', 'freaks', 'the', 'new', 'foul', 'i', 'you', 'king', 'away', 'of', 'beast-', '.', 'far'}
# 8802     3
# 9174    14
# Name: Tokens, dtype: int64
# 8802                              [prepare, foul, beast-]
# 9174    [i, suggest, you, freaks, cooperate, with, the...
# Name: Tokens, dtype: object
# 	donkey
# ['oh', '!', 'what', 'in', 'the', 'shista-shire', 'kind', 'of', 'place', 'is', 'this', '?', 'peek-a-boo', '.', 'peek-a-boo', '.', 'oh', '!', 'shrimp', '!', 'my', 'favorite', '.']
# 23
# DOUBLE CHECK: 23
# TYPES:
# 17
# {'my', 'place', '?', 'is', 'the', 'what', 'oh', '!', 'shista-shire', 'this', 'favorite', 'in', 'kind', 'shrimp', '.', 'of', 'peek-a-boo'}
# 8826     2
# 9017    10
# 9652     4
# 8859     7
# Name: Tokens, dtype: int64
# 8826                                              [oh, !]
# 9017    [what, in, the, shista-shire, kind, of, place,...
# 9652                       [peek-a-boo, ., peek-a-boo, .]
# 8859                  [oh, !, shrimp, !, my, favorite, .]
# Name: Tokens, dtype: object
# 	king harold
# ['shrek', ',', 'please', 'come', 'hither', '.', 'i', 'know', 'i', "'ve", 'made', 'many', 'mistakes', 'with', 'you', '.', 'his', 'name', 'is', 'arthur', '.']
# 21
# DOUBLE CHECK: 21
# TYPES:
# 18
# {'with', 'hither', "'ve", 'made', 'mistakes', 'name', ',', 'please', 'is', 'many', 'i', 'know', 'arthur', 'shrek', 'you', 'his', '.', 'come'}
# 8896     6
# 8888    10
# 8907     5
# Name: Tokens, dtype: int64
# 8896                  [shrek, ,, please, come, hither, .]
# 8888    [i, know, i, 've, made, many, mistakes, with, ...
# 8907                           [his, name, is, arthur, .]
# Name: Tokens, dtype: object
# 	shrek
# ['and', 'if', 'he', 'gives', 'me', 'any', 'trouble', ',', 'i', "'ve", 'always', 'got', 'persuasion', 'and', 'reason', '.', 'here', "'s", 'persuasion', ',', 'and', 'here', "'s", 'reason', '.', 'oh', ',', 'nice', 'going', ',', 'your', 'highness', '.', 'calm', 'down', '?', 'who', 'do', 'you', 'think', 'we', "'re", 'kidding', '?', 'i', 'am', 'an', 'ogre', '!', 'i', "'m", 'not', 'cut', 'out', 'for', 'this', ',', 'fiona', 'and', 'i', 'never', 'will', 'be', '.', 'alright', ',', 'let', "'s", 'not', 'overdo', 'it', '.', 'oh', ',', "c'mon", ',', 'there', "'s", 'no', 'way', 'i', 'could', 'ever', 'run', 'a', 'kingdom', '.', 'that', "'s", 'why', 'your', 'cousin', 'arthur', "'s", 'the', 'perfect', 'choice', '.', 'well', ',', 'my', 'stomach', 'aches', 'and', 'my', 'palms', 'just', 'got', 'sweaty', '.', 'must', 'be', 'a', 'high', 'school', '.', 'i', "'m", 'not', 'here', 'to', 'eat', 'him', '.']
# 124
# DOUBLE CHECK: 124
# TYPES:
# 79
# {"'ve", '?', 'fiona', 'he', 'him', 'it', 'alright', 'going', 'arthur', 'ogre', 'you', 'gives', 'perfect', 'choice', 'school', 'if', 'let', 'got', 'your', "'m", 'be', 'to', ',', 'that', 'run', 'aches', 'sweaty', "'re", 'i', 'palms', 'this', 'here', 'kidding', "c'mon", 'could', 'just', 'eat', 'any', 'nice', 'never', 'calm', "'s", 'no', 'me', '!', 'out', 'kingdom', 'not', 'must', 'ever', 'persuasion', 'do', 'we', 'there', 'well', 'trouble', 'way', 'think', 'my', 'high', 'am', 'always', 'and', 'a', 'who', 'stomach', 'overdo', 'the', 'oh', 'why', 'cousin', 'an', 'highness', 'down', 'cut', 'for', '.', 'will', 'reason'}
# 8952    25
# 9242     8
# 8862    31
# 9101     8
# 8950    26
# 9018    18
# 9085     8
# Name: Tokens, dtype: int64
# 8952    [and, if, he, gives, me, any, trouble, ,, i, '...
# 9242           [oh, ,, nice, going, ,, your, highness, .]
# 8862    [calm, down, ?, who, do, you, think, we, 're, ...
# 9101            [alright, ,, let, 's, not, overdo, it, .]
# 8950    [oh, ,, c'mon, ,, there, 's, no, way, i, could...
# 9018    [well, ,, my, stomach, aches, and, my, palms, ...
# 9085                  [i, 'm, not, here, to, eat, him, .]
# Name: Tokens, dtype: object
# 	master of ceremonies
# ['ladies', 'and', 'gentlemen', ',', 'princess', 'fiona', 'and', 'sir', 'shrek', '!']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 9
# {'princess', ',', 'and', 'fiona', 'ladies', '!', 'shrek', 'sir', 'gentlemen'}
# 8845    10
# Name: Tokens, dtype: int64
# 8845    [ladies, and, gentlemen, ,, princess, fiona, a...
# Name: Tokens, dtype: object
# 	merlin
# ['uh', '...', 'alright', ',', 'alright', '...', 'look..', 'now', 'all', 'of', 'you', ',', 'look', 'into', 'the', '``', 'fire', 'of', 'truth', "''", 'and', 'tell', 'me', 'what', 'you', 'see', '!', 'yah', '!', 'ha', '!', 'woo-looo-looo-looo', '!', 'woah', '!', 'it', 'worked', '!']
# 38
# DOUBLE CHECK: 38
# TYPES:
# 28
# {'truth', '...', 'worked', 'it', 'alright', 'yah', 'woah', 'all', 'you', 'look', 'into', ',', 'ha', "''", 'uh', 'look..', 'now', 'tell', '``', 'me', '!', 'of', 'and', 'see', 'woo-looo-looo-looo', 'fire', 'the', 'what'}
# 9639     7
# 9294    26
# 9404     5
# Name: Tokens, dtype: int64
# 9639          [uh, ..., alright, ,, alright, ..., look..]
# 9294    [now, all, of, you, ,, look, into, the, ``, fi...
# 9404                             [woah, !, it, worked, !]
# Name: Tokens, dtype: object
# 	rapunzel
# ['well', ',', 'now', 'you', "'ll", 'have', 'plenty', 'of', 'time', 'to', 'work', 'on', 'your', 'marriage', '.']
# 15
# DOUBLE CHECK: 15
# TYPES:
# 15
# {'to', 'your', 'plenty', ',', 'now', 'time', 'on', 'marriage', 'work', "'ll", 'you', 'have', '.', 'of', 'well'}
# 9139    15
# Name: Tokens, dtype: int64
# 9139    [well, ,, now, you, 'll, have, plenty, of, tim...
# Name: Tokens, dtype: object
# 	captain hook
# ['ahhh', '.', 'and', 'there', 'ai', "n't", 'nothing', 'you', 'can', 'do', 'to', 'stop', 'him', '!']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 14
# {'to', 'ai', 'and', 'stop', 'him', 'nothing', '!', 'ahhh', 'can', '.', "n't", 'do', 'you', 'there'}
# 9374    14
# Name: Tokens, dtype: int64
# 9374    [ahhh, ., and, there, ai, n't, nothing, you, c...
# Name: Tokens, dtype: object
# 	lancelot
# ['that', 'dork', 'over', 'there', 'is', 'arthur', '!']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 7
# {'over', 'that', 'is', 'dork', 'arthur', '!', 'there'}
# 9054    7
# Name: Tokens, dtype: int64
# 9054    [that, dork, over, there, is, arthur, !]
# Name: Tokens, dtype: object
# 	puss
# ['shrek', 'only', 'said', 'those', 'things', 'to', 'protect', 'you', '!']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 9
# {'those', 'to', 'protect', 'said', '!', 'things', 'shrek', 'you', 'only'}
# 9555    9
# Name: Tokens, dtype: int64
# 9555    [shrek, only, said, those, things, to, protect...
# Name: Tokens, dtype: object
# 	knight
# ['ha', 'ha', '!', 'there', 'is', 'no', 'sweeter', 'taste', 'on', 'thy', 'tongue', 'than', 'victory', '!']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 12
# {'than', 'sweeter', 'ha', 'is', 'on', 'no', '!', 'tongue', 'victory', 'taste', 'thy', 'there'}
# 9037    14
# Name: Tokens, dtype: int64
# 9037    [ha, ha, !, there, is, no, sweeter, taste, on,...
# Name: Tokens, dtype: object
# Movie:How to Train Your Dragon
# 	snotlout
# ['what', 'was', 'that', '?', 'some', 'kind', 'of', 'trick', '?', 'what', 'did', 'you', 'do', '?']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 11
# {'was', '?', 'did', 'that', 'what', 'trick', 'some', 'you', 'kind', 'do', 'of'}
# 10688    14
# Name: Tokens, dtype: int64
# 10688    [what, was, that, ?, some, kind, of, trick, ?,...
# Name: Tokens, dtype: object
# 	fishlegs
# ['firepower', 'fifteen', '.']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'fifteen', '.', 'firepower'}
# 10526    3
# Name: Tokens, dtype: int64
# 10526    [firepower, fifteen, .]
# Name: Tokens, dtype: object
# 	gobber
# ['every', 'bit', 'the', 'boar-headed', ',', 'stubborn', 'viking', 'you', 'ever', 'were', '.', 'you', 'got', 'a', 'headache', '.']
# 16
# DOUBLE CHECK: 16
# TYPES:
# 14
# {'got', 'headache', 'bit', 'a', ',', 'boar-headed', 'every', 'the', 'viking', 'stubborn', 'were', 'you', 'ever', '.'}
# 10975    11
# 10474     5
# Name: Tokens, dtype: int64
# 10975    [every, bit, the, boar-headed, ,, stubborn, vi...
# 10474                           [you, got, a, headache, .]
# Name: Tokens, dtype: object
# 	hiccup
# ['toothless', '?', 'down', '.', 'gently', '.', 'meet', 'the', 'neighbors', '.', 'hoark', 'the', 'haggard', '...', 'fishlegs', ',', 'break', 'it', 'down', '.', 'oh', 'wow', '.', 'i', 'did', 'it', '.', 'i', 'did', 'it', '.', 'this', 'fixes', 'everything', '.', 'yes', '!', 'you', ',', 'sir', ',', 'are', 'playing', 'a', 'dangerous', 'game', '.', 'keeping', 'this', 'much', ',', 'raw', '...', 'vikingness', 'contained', '.', 'there', 'will', 'be', 'consequences', '!', 'hey', 'toothless', '.', 'i', 'brought', 'breakfast', '.', 'i', 'hope', 'you', "'re", 'hungry', '.']
# 74
# DOUBLE CHECK: 74
# TYPES:
# 46
# {'...', '?', 'did', 'it', 'raw', 'brought', 'hey', 'you', 'be', 'fishlegs', 'yes', 'will', 'gently', 'contained', ',', 'breakfast', "'re", 'i', 'this', 'sir', 'meet', 'neighbors', 'everything', 'vikingness', 'hungry', 'playing', 'keeping', 'game', '!', 'hoark', 'dangerous', 'there', 'hope', 'much', 'haggard', 'a', 'the', 'oh', 'fixes', 'down', 'toothless', '.', 'wow', 'are', 'break', 'consequences'}
# 10808     6
# 10354     8
# 10976     6
# 10478    17
# 10396    24
# 10643    13
# Name: Tokens, dtype: int64
# 10808                   [toothless, ?, down, ., gently, .]
# 10354    [meet, the, neighbors, ., hoark, the, haggard,...
# 10976                    [fishlegs, ,, break, it, down, .]
# 10478    [oh, wow, ., i, did, it, ., i, did, it, ., thi...
# 10396    [you, ,, sir, ,, are, playing, a, dangerous, g...
# 10643    [hey, toothless, ., i, brought, breakfast, ., ...
# Name: Tokens, dtype: object
# 	tuffnut
# ['yeah', ',', 'that', 'sounds', 'great', '.', 'there', 'was', 'a', 'chance', 'i', 'was', 'going', 'to', 'read', 'that', '...', 'what', '?', '!', 'i', "'m", 'on', 'it', 'first', '!', 'i', "'m", 'ahead', 'of', 'you', '.']
# 32
# DOUBLE CHECK: 32
# TYPES:
# 25
# {'...', 'was', '?', 'it', 'going', 'you', 'to', "'m", 'first', ',', 'that', 'on', 'i', 'sounds', 'chance', '!', 'read', 'of', 'there', 'yeah', 'ahead', 'a', 'what', '.', 'great'}
# 10583    17
# 10544     3
# 11014    12
# Name: Tokens, dtype: int64
# 10583    [yeah, ,, that, sounds, great, ., there, was, ...
# 10544                                         [what, ?, !]
# 11014    [i, 'm, on, it, first, !, i, 'm, ahead, of, yo...
# Name: Tokens, dtype: object
# 	hoark
# ['what', 'are', 'you', 'doing', 'out', '!', '?']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 7
# {'?', 'what', 'out', '!', 'doing', 'you', 'are'}
# 10355    7
# Name: Tokens, dtype: int64
# 10355    [what, are, you, doing, out, !, ?]
# Name: Tokens, dtype: object
# 	astrid
# ['who', 'is', 'him', '?', 'why', 'did', "n't", 'you', '?']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 8
# {'?', 'did', 'him', 'is', 'who', 'why', 'you', "n't"}
# 10797    4
# 10906    5
# Name: Tokens, dtype: int64
# 10797          [who, is, him, ?]
# 10906    [why, did, n't, you, ?]
# Name: Tokens, dtype: object
# 	stoick
# ['any', 'night', 'furies', '?']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'furies', 'any', '?', 'night'}
# 10367    4
# Name: Tokens, dtype: int64
# 10367    [any, night, furies, ?]
# Name: Tokens, dtype: object
# 	ruffnut
# ['okay', ',', 'i', "'ve", 'been', 'stuck', 'with', 'you', 'since', 'birth', ',', 'and', 'that', 'was', 'never', 'there', 'before', '.']
# 18
# DOUBLE CHECK: 18
# TYPES:
# 17
# {'with', "'ve", 'was', 'and', ',', 'never', 'that', 'before', 'stuck', 'okay', 'i', 'been', 'birth', 'you', 'since', '.', 'there'}
# 10640    18
# Name: Tokens, dtype: int64
# 10640    [okay, ,, i, 've, been, stuck, with, you, sinc...
# Name: Tokens, dtype: object
# Movie:The Princess and the Frog
# 	ray
# ['i', 'knew', 'it', ',', 'i', 'knew', 'it', ',', 'i', 'knew', 'it', '.', 'you', 'come', 'here', ',', 'you', '...']
# 18
# DOUBLE CHECK: 18
# TYPES:
# 9
# {'...', 'knew', ',', 'it', 'i', '.', 'you', 'here', 'come'}
# 5036    18
# Name: Tokens, dtype: int64
# 5036    [i, knew, it, ,, i, knew, it, ,, i, knew, it, ...
# Name: Tokens, dtype: object
# 	prince naveen
# ['ah', ',', 'nothing', '.', 'stick', 'in', 'the', 'mud', '.', 'tiana', '!', 'all', 'i', 'know', ',', 'is', 'one', 'minute', 'i', 'am', 'a', 'prince', ',', 'charming', 'and', 'handsome', ',', 'cuttingarug', ',', 'and', 'the', 'next', 'thing', 'i', 'know', ',', '...', 'i', 'am', 'tripping', 'over', 'these', '.', 'wait', ',', 'wait', ',', 'wait', '...', 'wait', '!', 'i', 'know', 'this', 'story', '!', 'di', 'frogie', 'prutto', '!', 'please', ',', 'please', ',', 'please', '...', 'ah', ',', 'oh', 'well', '...', 'allow', 'me', 'to', 'introduce', 'myself', ',', 'i', "'m", 'prince', 'naveen', '.', '...', 'of', 'maldonia', '.']
# 86
# DOUBLE CHECK: 86
# TYPES:
# 47
# {'...', 'introduce', 'ah', 'charming', 'maldonia', 'is', 'one', 'di', 'all', 'tiana', 'these', 'to', 'thing', "'m", 'next', ',', 'please', 'allow', 'myself', 'tripping', 'i', 'know', 'story', 'handsome', 'cuttingarug', 'naveen', 'this', 'prince', 'frogie', 'prutto', 'mud', 'minute', '!', 'me', 'stick', 'in', 'of', 'well', 'over', 'am', 'a', 'and', 'the', 'oh', 'nothing', '.', 'wait'}
# 4901     9
# 4984     2
# 4707    49
# 4705    26
# Name: Tokens, dtype: int64
# 4901          [ah, ,, nothing, ., stick, in, the, mud, .]
# 4984                                           [tiana, !]
# 4707    [all, i, know, ,, is, one, minute, i, am, a, p...
# 4705    [please, ,, please, ,, please, ..., ah, ,, oh,...
# Name: Tokens, dtype: object
# 	eudora
# ['here', 'is', 'a', 'little', 'something', 'to..', 'help', 'you', 'get', 'started', '.', 'daddy', "'s", 'gumbo', 'pot', '.', 'sorry', 'charlotte', ',', 'it', "'s", 'time', 'for', 'us', 'to', 'be', 'headin', "'", 'home', '.', 'say', 'good', 'night', ',', 'tiana', '.']
# 36
# DOUBLE CHECK: 36
# TYPES:
# 31
# {'say', 'to..', 'is', 'sorry', 'it', 'time', 'headin', 'home', 'charlotte', 'you', 'us', 'night', 'tiana', 'little', 'to', 'be', ',', 'gumbo', 'here', 'started', "'s", 'something', 'help', 'get', 'a', "'", 'daddy', 'good', 'for', 'pot', '.'}
# 4622    16
# 4525    20
# Name: Tokens, dtype: int64
# 4622    [here, is, a, little, something, to.., help, y...
# 4525    [sorry, charlotte, ,, it, 's, time, for, us, t...
# Name: Tokens, dtype: object
# 	charlotte
# ['there', 'comes', 'my', 'favorite', 'part', '.', 'did', 'you', 'say', 'prince', '?']
# 11
# DOUBLE CHECK: 11
# TYPES:
# 11
# {'my', 'say', 'prince', '?', 'did', 'part', 'favorite', '.', 'you', 'comes', 'there'}
# 4522    6
# 5159    5
# Name: Tokens, dtype: int64
# 4522    [there, comes, my, favorite, part, .]
# 5159               [did, you, say, prince, ?]
# Name: Tokens, dtype: object
# 	tiana
# ['have', 'you', ',', 'now', '?', 'no', '.', 'i', '...', 'i', 'never', 'said', 'i', 'was', 'a', 'princess', '.', 'i', '.', '..', 'i', '...', 'just', '.', 'are', 'you', 'mincing', '?', 'evangeline', '?', 'just', '...', 'one', 'kiss', '?', 'you', 'just', 'keep', 'your', 'eyes', 'at', 'one', 'of', 'of', 'the', 'biggest', 'gaudiest', 'floats', 'with', 'a', 'mardi', 'gras', 'princess', 'about', 'to', 'kissed', 'herself', 'a', '...', 'a', 'frog', '.']
# 62
# DOUBLE CHECK: 62
# TYPES:
# 38
# {'...', 'eyes', 'was', 'about', '?', 'one', 'kissed', 'gras', 'herself', 'you', 'to', 'your', 'at', ',', 'i', 'kiss', 'biggest', 'have', 'just', 'with', 'never', 'now', 'no', 'said', 'keep', 'of', 'frog', 'a', 'princess', 'mincing', 'the', 'floats', 'mardi', '.', 'are', 'gaudiest', '..', 'evangeline'}
# 4895     5
# 4962     2
# 4758    10
# 4699     7
# 4948     4
# 4969     2
# 4716     5
# 5089    27
# Name: Tokens, dtype: int64
# 4895                               [have, you, ,, now, ?]
# 4962                                              [no, .]
# 4758     [i, ..., i, never, said, i, was, a, princess, .]
# 4699                          [i, ., .., i, ..., just, .]
# 4948                               [are, you, mincing, ?]
# 4969                                      [evangeline, ?]
# 4716                            [just, ..., one, kiss, ?]
# 5089    [you, just, keep, your, eyes, at, one, of, of,...
# Name: Tokens, dtype: object
# 	alligator
# ['i', "'ve", 'seen', 'him', '!', 'i', "'ve", 'seen', 'him', '!']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 5
# {'seen', "'ve", 'him', 'i', '!'}
# 4779    10
# Name: Tokens, dtype: int64
# 4779    [i, 've, seen, him, !, i, 've, seen, him, !]
# Name: Tokens, dtype: object
# 	person
# ['get', 'that', 'frogs', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'!', 'that', 'get', 'frogs'}
# 4725    4
# Name: Tokens, dtype: int64
# 4725    [get, that, frogs, !]
# Name: Tokens, dtype: object
# 	mr. fenner
# ['exactly', '!', 'which', 'is', 'why', 'a', 'little', 'woman', 'of', 'your', 'background', '...', 'woulda', 'had', 'a', 'hands', 'full', ',', 'trying', 'to', 'run', 'a', 'big', 'business', 'like', 'that', '.', 'you', 'better', 'off', 'where', 'you', "'re", 'at', '.']
# 35
# DOUBLE CHECK: 35
# TYPES:
# 31
# {'which', '...', 'background', 'is', 'big', 'you', 'like', 'little', 'your', 'to', 'full', 'at', ',', 'that', 'run', "'re", 'had', 'woulda', 'better', 'off', '!', 'hands', 'business', 'of', 'woman', 'a', 'trying', 'why', 'where', '.', 'exactly'}
# 4694    35
# Name: Tokens, dtype: int64
# 4694    [exactly, !, which, is, why, a, little, woman,...
# Name: Tokens, dtype: object
# 	mama odie
# ['you', 'want', 'some', 'candies', '?']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 5
# {'?', 'want', 'candies', 'some', 'you'}
# 4992    5
# Name: Tokens, dtype: int64
# 4992    [you, want, some, candies, ?]
# Name: Tokens, dtype: object
# Movie:Antz
# 	z
# ['we', 'need', 'to', 'form', 'a', 'scaffolding', 'around', 'this', 'mound', '--', 'let', "'s", 'do', 'it', '!', 'so', '...', 'you', 'never', 'did', 'tell', 'me', '...', 'what', 'made', 'you', 'come', 'out', 'to', 'the', 'worker', 'bar', 'that', 'night', '?', 'to', 'save', 'you', 'all', '!', 'now', 'we', "'ve", 'got', 'to', 'go', '!', 'cut', 'to', ':', 'are', 'you', 'kidding', '?', 'there', 'were', 'sparks', 'between', 'us', '!', 'this', 'scarf', 'is', 'a', 'sign', '!', 'now', 'climb', '!', '...', 'the', 'land', 'of', 'red', 'and', 'white', '...', 'geez', '--', 'tough', 'room', '.', 'weaver', ',', 'i', "'m", 'an', 'insect', ',', 'not', 'a', 'liquid', '.']
# 93
# DOUBLE CHECK: 93
# TYPES:
# 68
# {'...', "'ve", 'room', 'white', '?', 'did', 'scarf', 'it', 'go', 'is', 'climb', 'scaffolding', 'bar', 'all', 'you', 'night', 'us', 'come', 'sparks', 'let', 'to', 'got', 'tough', "'m", ',', 'that', 'i', 'this', 'save', 'liquid', 'geez', 'kidding', 'made', 'red', 'so', 'never', 'now', "'s", 'tell', 'sign', 'me', '!', 'out', 'were', 'insect', 'not', 'mound', 'do', 'around', 'we', ':', 'there', 'of', 'weaver', 'a', 'land', 'and', 'need', 'form', 'what', 'the', 'worker', 'an', 'cut', '.', '--', 'are', 'between'}
# 8026    15
# 7911    20
# 8009    15
# 7565    16
# 8027     3
# 7841     8
# 7584     5
# 7510    11
# Name: Tokens, dtype: int64
# 8026    [we, need, to, form, a, scaffolding, around, t...
# 7911    [so, ..., you, never, did, tell, me, ..., what...
# 8009    [to, save, you, all, !, now, we, 've, got, to,...
# 7565    [are, you, kidding, ?, there, were, sparks, be...
# 8027                                      [now, climb, !]
# 7841           [..., the, land, of, red, and, white, ...]
# 7584                           [geez, --, tough, room, .]
# 7510    [weaver, ,, i, 'm, an, insect, ,, not, a, liqu...
# Name: Tokens, dtype: object
# 	azteca
# ['hey', ',', 'slow', 'it', 'down', ',', 'big', 'boy', '.', 'you', "'re", 'making', 'the', 'rest', 'of', 'us', 'look', 'bad', '...', 'how', 'come', 'i', 'have', "n't", 'seen', 'you', 'around', 'here', 'before', '?', 'i', 'tell', 'ya', ',', 'i', "'m", 'gettin', "'", 'sick', 'of', 'bein', "'", 'yelled', 'at', '.', 'leave', 'him', 'alone', '!', 'he', "'s", 'new', '.']
# 53
# DOUBLE CHECK: 53
# TYPES:
# 44
# {'...', '?', 'he', 'him', 'it', 'big', 'new', 'yelled', 'hey', 'you', 'us', 'look', 'ya', 'come', 'seen', "'m", 'at', ',', 'how', "'re", 'bein', 'i', 'making', 'gettin', 'have', 'here', 'sick', 'alone', 'before', "'s", 'tell', '!', "n't", 'around', 'of', 'boy', 'rest', 'bad', "'", 'leave', 'the', 'down', 'slow', '.'}
# 7649    30
# 7761    15
# 7657     8
# Name: Tokens, dtype: int64
# 7649    [hey, ,, slow, it, down, ,, big, boy, ., you, ...
# 7761    [i, tell, ya, ,, i, 'm, gettin, ', sick, of, b...
# 7657               [leave, him, alone, !, he, 's, new, .]
# Name: Tokens, dtype: object
# 	tracker ant
# ['nnononononononoyeahyeahnononononono', 'no', '...']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'...', 'nnononononononoyeahyeahnononononono', 'no'}
# 7890    3
# Name: Tokens, dtype: int64
# 7890    [nnononononononoyeahyeahnononononono, no, ...]
# Name: Tokens, dtype: object
# 	carpenter
# ['well', ',', 'uh', ',', 'who', 'notices', 'workers', ',', 'sir', '?']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 8
# {'notices', 'uh', ',', 'workers', '?', 'who', 'sir', 'well'}
# 7814    10
# Name: Tokens, dtype: int64
# 7814    [well, ,, uh, ,, who, notices, workers, ,, sir...
# Name: Tokens, dtype: object
# 	bala
# ['you', "'re", 'right', '!', 'i', 'know', '.', 'you', 'were', 'right', '...', 'you', 'were', 'right', '!', 'z', ',', 'it', "'s", 'beautiful', '!', 'hello', '?', 'i', "'m", 'not', 'just', '``', 'any', 'insect', "''", '.', 'my', 'mother', 'is', 'the', 'queen', '.', 'i', "'m", 'princess', 'bala', '!', 'z', '!', 'you', 'came', 'back', '!']
# 49
# DOUBLE CHECK: 49
# TYPES:
# 32
# {'...', 'beautiful', '?', 'is', 'it', 'you', "'m", ',', 'back', 'right', "'re", 'i', 'know', 'z', 'hello', 'just', 'any', "''", 'mother', "'s", 'came', '``', 'queen', 'bala', '!', 'were', 'not', 'insect', 'my', 'princess', 'the', '.'}
# 7545     4
# 7531     3
# 7843    14
# 7855    22
# 7975     6
# Name: Tokens, dtype: int64
# 7545                                 [you, 're, right, !]
# 7531                                         [i, know, .]
# 7843    [you, were, right, ..., you, were, right, !, z...
# 7855    [hello, ?, i, 'm, not, just, ``, any, insect, ...
# 7975                           [z, !, you, came, back, !]
# Name: Tokens, dtype: object
# 	weaver
# ['i', "'m", 'new', '...', 'i', 'was', 'born', 'yesterday', '.', 'well', ',', 'you', 'just', 'sit', 'here', 'and', 'be', 'a', 'party-pooper', '.']
# 20
# DOUBLE CHECK: 20
# TYPES:
# 18
# {"'m", '...', 'be', 'was', 'party-pooper', 'and', ',', 'a', 'new', 'i', 'born', '.', 'you', 'here', 'yesterday', 'well', 'just', 'sit'}
# 7650     9
# 7527    11
# Name: Tokens, dtype: int64
# 7650        [i, 'm, new, ..., i, was, born, yesterday, .]
# 7527    [well, ,, you, just, sit, here, and, be, a, pa...
# Name: Tokens, dtype: object
# 	male wasp
# ['well', '--', 'like', 'my', 'father', 'used', 'to', 'say', '--', 'there', "'s", 'no', 'such', 'thing', 'as', 'a', 'free', 'meal', '!']
# 19
# DOUBLE CHECK: 19
# TYPES:
# 18
# {'like', 'my', 'to', 'say', 'thing', 'a', 'such', "'s", 'meal', 'father', 'no', 'there', '!', 'as', 'free', 'used', '--', 'well'}
# 7859    19
# Name: Tokens, dtype: int64
# 7859    [well, --, like, my, father, used, to, say, --...
# Name: Tokens, dtype: object
# 	formica
# ['first', 'of', 'all', ',', 'let', 'me', 'make', 'one', 'thing', 'clear', '.', 'nobody', 'ever', 'won', 'a', 'battle', 'by', 'thinking', 'for', 'himself', '.', 'all', 'this', '``', 'thinking', "''", 'stuff', 'is', 'a', 'load', 'of', 'crap', '.', 'if', 'the', 'almighty', 'had', 'wanted', 'you', 'boys', 'to', 'think', ',', 'he', 'would', "n't", 'have', 'given', 'you', 'huge', 'mandibles', 'and', 'a', 'brain', 'so', 'small', 'you', "'d", 'misplace', 'it', 'if', 'it', 'was', "n't", 'trapped', 'inside', 'your', 'head', '.', 'okay', ',', 'son', '.']
# 73
# DOUBLE CHECK: 73
# TYPES:
# 57
# {'would', 'battle', 'was', 'by', 'he', 'one', 'is', 'brain', 'it', 'crap', 'wanted', 'all', 'himself', 'you', 'head', '.', 'load', 'if', 'let', 'to', 'thing', 'your', 'first', 'mandibles', ',', 'make', 'had', 'okay', 'this', 'inside', 'have', 'stuff', "''", 'boys', 'so', 'clear', 'son', 'nobody', '``', 'almighty', 'trapped', 'me', 'ever', "n't", 'huge', 'of', "'d", 'misplace', 'think', 'a', 'and', 'small', 'the', 'thinking', 'for', 'won', 'given'}
# 7582    69
# 7824     4
# Name: Tokens, dtype: int64
# 7582    [first, of, all, ,, let, me, make, one, thing,...
# 7824                                    [okay, ,, son, .]
# Name: Tokens, dtype: object
# 	worker
# ['he', 'did', 'it', '!', 'z', '!', 'z', '!', 'z', '!', 'z', '!', 'z', '!']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 5
# {'he', 'did', 'it', '!', 'z'}
# 8029    14
# Name: Tokens, dtype: int64
# 8029    [he, did, it, !, z, !, z, !, z, !, z, !, z, !]
# Name: Tokens, dtype: object
# 	mandible
# ['talk', 'to', 'me', '.']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'me', 'talk', 'to', '.'}
# 7885    4
# Name: Tokens, dtype: int64
# 7885    [talk, to, me, .]
# Name: Tokens, dtype: object
# Movie:Frozen
# 	kristoff
# ['mm', '.', 'it', "'s", 'too', 'steep', '.', 'i', "'ve", 'only', 'got', 'one', 'rope', 'and', 'you', 'do', "n't", 'know', 'how', 'to', 'climb', 'mountains', '.', 'you', "'re", 'gon', 'na', 'kill', 'yourself', '.', 'i', 'would', "n't", 'put', 'my', 'foot', 'there', '.', 'hey', ',', 'hey', ',', 'do', "n't", 'worry', 'about', 'my', 'ice', 'business', '.', 'worry', 'about', 'your', 'hair', '?', '!', 'hey', ',', 'woh', '.', 'i', 'did', "n't", 'even', 'recognize', 'you', '.', 'you', "'ve", 'lost', 'so', 'much', 'wight', '.', 'no', '.', 'that', "'s", 'not', 'why', 'i', 'brought', 'her', 'here', '.', 'no', ',', 'no', ',', 'no', '!', 'anna', ',', 'wait', '!', 'but', 'you', 'can', 'remove', 'it', ',', 'right', '?']
# 103
# DOUBLE CHECK: 103
# TYPES:
# 62
# {'foot', "'ve", 'would', 'about', '?', 'ice', 'hair', 'one', 'it', 'climb', 'did', 'her', 'mm', 'worry', 'brought', 'hey', 'steep', 'you', 'gon', 'can', 'got', 'to', 'your', 'but', 'remove', 'how', ',', 'that', 'right', 'wight', "'re", 'yourself', 'i', 'know', 'na', 'mountains', 'recognize', 'here', 'so', "'s", 'no', 'even', '!', 'business', 'too', 'not', "n't", 'do', 'there', 'only', 'my', 'much', 'and', 'lost', 'rope', 'why', 'kill', 'woh', 'anna', '.', 'wait', 'put'}
# 7013    23
# 7017    15
# 7151    18
# 7181    18
# 7205    11
# 7184    10
# 7257     8
# Name: Tokens, dtype: int64
# 7013    [mm, ., it, 's, too, steep, ., i, 've, only, g...
# 7017    [you, 're, gon, na, kill, yourself, ., i, woul...
# 7151    [hey, ,, hey, ,, do, n't, worry, about, my, ic...
# 7181    [hey, ,, woh, ., i, did, n't, even, recognize,...
# 7205    [no, ., that, 's, not, why, i, brought, her, h...
# 7184              [no, ,, no, ,, no, !, anna, ,, wait, !]
# 7257             [but, you, can, remove, it, ,, right, ?]
# Name: Tokens, dtype: object
# 	anna
# ['ew', '!', 'no', ',', 'i', 'was', 'raised', 'in', 'a', 'castle', '.', 'oh', ',', 'no', '.', 'uh', '...', 'north', 'mountain', '.', 'oh', '.', 'um', '...', 'i', 'was', 'just', 'wondering', ',', 'has', 'another', 'young', 'woman', ',', 'the', 'queen', 'perhaps', ',', 'i', 'do', "n't", 'know', ',', 'passed', 'through', 'here', '?', 'you', 'have', 'to', '!', 'no', 'returns', '.', 'no', 'exchanges', '.', 'queen', "'s", 'orders', '.', 'she', "'s", 'named', 'you', 'the', 'official', 'arendelle', 'ice', 'master', 'and', 'deliverer', '.', 'well', ',', 'we', 'have', "n't", 'worked', 'out', 'all', 'the', 'details', 'ourselves', '.', 'we', "'ll", 'need', 'a', 'few', 'days', 'to', 'plan', 'the', 'ceremony', '.', 'of', 'course', ',', 'we', "'ll", 'have', 'soup', ',', 'roast', ',', 'and', 'ice', 'cream', '.', 'and', 'then', '...', 'wait', '.', 'would', 'we', 'live', 'here', '?', 'no', '!', 'kristoff', '!', 'you', 'are', '?', '!', 'i', 'mean', ',', 'sure', '.', 'i', "'ll", 'let', 'you', 'tag', 'along', '.', 'arendelle', '.', 'elsa', '?', 'go', 'faster', '!', 'wait', ',', 'what', '?', 'kristoff', '!', 'my-my', 'sister', "'s", 'not', 'a', 'monster', '.', 'okay', ',', 'can', 'i', 'just', 'say', 'something', 'crazy', '?']
# 169
# DOUBLE CHECK: 169
# TYPES:
# 90
# {'kristoff', 'raised', 'monster', 'can', 'tag', 'wondering', 'to', 'okay', 'arendelle', 'castle', 'days', 'uh', 'faster', '!', 'then', 'returns', 'course', "n't", 'a', 'young', 'orders', 'official', 'cream', 'are', 'would', '?', 'crazy', 'through', 'ourselves', 'go', 'my-my', 'you', 'let', 'details', 'live', 'have', 'north', 'something', 'no', 'in', 'we', 'deliverer', '.', 'soup', 'master', 'ice', 'worked', 'named', 'all', 'sure', 'i', 'know', 'here', 'out', 'not', "'ll", 'has', 'well', 'ew', 'woman', 'and', 'the', 'oh', 'perhaps', 'what', 'mountain', 'um', 'few', 'another', 'wait', 'sister', 'roast', '...', 'elsa', 'say', 'was', 'exchanges', 'ceremony', ',', 'she', 'passed', 'just', "'s", 'plan', 'queen', 'do', 'of', 'along', 'mean', 'need'}
# 6881    11
# 7210     4
# 6866     2
# 6848     3
# 6840    27
# 7406    26
# 6768    47
# 6948     2
# 7185     2
# 6935    18
# 6796     2
# 7137     9
# 6819     7
# 6716     9
# Name: Tokens, dtype: int64
# 6881     [ew, !, no, ,, i, was, raised, in, a, castle, .]
# 7210                                       [oh, ,, no, .]
# 6866                                            [uh, ...]
# 6848                                 [north, mountain, .]
# 6840    [oh, ., um, ..., i, was, just, wondering, ,, h...
# 7406    [you, have, to, !, no, returns, ., no, exchang...
# 6768    [well, ,, we, have, n't, worked, out, all, the...
# 6948                                              [no, !]
# 7185                                        [kristoff, !]
# 6935    [you, are, ?, !, i, mean, ,, sure, ., i, 'll, ...
# 6796                                            [elsa, ?]
# 7137       [go, faster, !, wait, ,, what, ?, kristoff, !]
# 6819              [my-my, sister, 's, not, a, monster, .]
# 6716    [okay, ,, can, i, just, say, something, crazy, ?]
# Name: Tokens, dtype: object
# 	olaf
# ['that', "'s", 'okay', ',', 'i', 'do', '.', 'love', 'is', 'putting', 'someone', 'else', "'s", 'needs', 'before', 'yours', '.', 'like', ',', 'you', 'know', ',', 'how', 'kristoff', 'brought', 'you', 'back', 'here', 'to', 'hans', 'and', 'left', 'you', 'forever', '.', 'i', "'m", 'coming', '!', 'let', "'s", 'go', 'kiss', 'hans', '!', 'who', 'is', 'this', 'hans', '?', '!', 'look', ',', 'sven', '.', 'the', 'sky', "'s", 'awake', '.']
# 60
# DOUBLE CHECK: 60
# TYPES:
# 42
# {'needs', '?', 'is', 'go', 'kristoff', 'someone', 'brought', 'hans', 'you', 'else', 'look', 'love', 'like', 'to', "'m", 'let', 'awake', ',', 'how', 'that', 'back', 'left', 'okay', 'i', 'know', 'kiss', 'this', 'here', 'putting', 'sky', 'coming', 'before', "'s", '!', 'do', 'yours', 'forever', 'and', 'who', 'the', 'sven', '.'}
# 7352    35
# 7264    16
# 7169     9
# Name: Tokens, dtype: int64
# 7352    [that, 's, okay, ,, i, do, ., love, is, puttin...
# 7264    [i, 'm, coming, !, let, 's, go, kiss, hans, !,...
# 7169           [look, ,, sven, ., the, sky, 's, awake, .]
# Name: Tokens, dtype: object
# 	troll #2
# ['take', 'off', 'your', 'clothes', '!', 'i', "'ll", 'wash', 'them', '...']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 10
# {'...', 'your', 'off', '!', 'clothes', 'i', 'wash', "'ll", 'them', 'take'}
# 7189    10
# Name: Tokens, dtype: int64
# 7189    [take, off, your, clothes, !, i, 'll, wash, th...
# Name: Tokens, dtype: object
# 	guard #2
# ['be', 'careful', '.']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'careful', 'be', '.'}
# 7339    3
# Name: Tokens, dtype: int64
# 7339    [be, careful, .]
# Name: Tokens, dtype: object
# 	voice of man
# ['that', "'s", 'princess', 'anna', "'s", 'horse', '.']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 6
# {'horse', 'princess', "'s", 'that', 'anna', '.'}
# 7001    7
# Name: Tokens, dtype: int64
# 7001    [that, 's, princess, anna, 's, horse, .]
# Name: Tokens, dtype: object
# 	hans
# ['twelve', 'older', 'brothers', '.', 'three', 'of', 'them', 'pretended', 'i', 'was', 'invisible', '...', 'literally', ',', 'for', 'two', 'years', '.', 'just', 'you', '?']
# 21
# DOUBLE CHECK: 21
# TYPES:
# 20
# {'twelve', '...', 'was', 'older', 'three', ',', '?', 'two', 'invisible', 'years', 'i', 'them', 'brothers', 'for', '.', 'you', 'pretended', 'literally', 'of', 'just'}
# 6711    18
# 6665     3
# Name: Tokens, dtype: int64
# 6711    [twelve, older, brothers, ., three, of, them, ...
# 6665                                       [just, you, ?]
# Name: Tokens, dtype: object
# 	elsa
# ['no', '!', 'please', '!', 'do', 'you', 'have', 'to', 'go', '?', 'anna', '!', 'oh', ',', 'anna', '.', 'no..no', ',', 'please', ',', 'no', '.', 'get', 'it', 'together', '.', 'control', 'it', '.', 'do', "n't", 'feel', '.', 'do', "n't", 'feel', '.', 'do', "n't", 'feel', '.', 'do', "n't", 'feel', '!', 'thank', 'you', '.', 'i', 'never', 'knew', 'what', 'i', 'was', 'capable', 'of', '.']
# 57
# DOUBLE CHECK: 57
# TYPES:
# 28
# {'was', 'feel', '?', 'it', 'go', 'no..no', 'thank', 'you', 'together', 'to', 'please', ',', 'i', 'have', 'knew', 'never', 'no', '!', "n't", 'control', 'do', 'of', 'get', 'capable', 'what', 'oh', 'anna', '.'}
# 7270     4
# 6610     6
# 7381    12
# 7168    23
# 7046    12
# Name: Tokens, dtype: int64
# 7270                                   [no, !, please, !]
# 6610                           [do, you, have, to, go, ?]
# 7381    [anna, !, oh, ,, anna, ., no..no, ,, please, ,...
# 7168    [get, it, together, ., control, it, ., do, n't...
# 7046    [thank, you, ., i, never, knew, what, i, was, ...
# Name: Tokens, dtype: object
# 	spanish dignitary
# ['i', 'bet', 'they', 'are', 'beautiful', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'beautiful', 'bet', 'i', '.', 'are', 'they'}
# 6624    6
# Name: Tokens, dtype: int64
# 6624    [i, bet, they, are, beautiful, .]
# Name: Tokens, dtype: object
# 	voice of woman
# ['but', 'where', 'is', 'the', 'princess', '?']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'but', 'princess', '?', 'is', 'the', 'where'}
# 7002    6
# Name: Tokens, dtype: int64
# 7002    [but, where, is, the, princess, ?]
# Name: Tokens, dtype: object
# 	french dignitary
# ['you', 'can', 'not', 'risk', 'going', 'out', 'there', 'again', '.']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 9
# {'again', 'going', 'out', 'not', 'can', 'risk', 'you', '.', 'there'}
# 7295    9
# Name: Tokens, dtype: int64
# 7295    [you, can, not, risk, going, out, there, again...
# Name: Tokens, dtype: object
# 	bulda
# ['a', 'true', 'love', "'s", 'kiss', ',', 'perhaps', '?']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'love', 'true', 'a', ',', "'s", '?', 'perhaps', 'kiss'}
# 7260    8
# Name: Tokens, dtype: int64
# 7260    [a, true, love, 's, kiss, ,, perhaps, ?]
# Name: Tokens, dtype: object
# Movie:Rise of the Guardians
# 	north
# ['please', '.', 'bunny', '.', 'easter', 'is', 'not', 'christmas', '.', 'hey', '!', 'moi', 'deti', ',', 'moi', 'deti', '.', 'quiet', ',', 'quiet', '.', 'epic', '!', '!', 'hmmmm', '?']
# 26
# DOUBLE CHECK: 26
# TYPES:
# 16
# {'moi', 'christmas', '?', 'please', ',', 'is', 'quiet', 'bunny', '!', 'deti', 'easter', 'not', 'hey', '.', 'epic', 'hmmmm'}
# 11735     9
# 11985    12
# 12104     3
# 11967     2
# Name: Tokens, dtype: int64
# 11735    [please, ., bunny, ., easter, is, not, christm...
# 11985    [hey, !, moi, deti, ,, moi, deti, ., quiet, ,,...
# 12104                                         [epic, !, !]
# 11967                                           [hmmmm, ?]
# Name: Tokens, dtype: object
# 	pitch
# ['i', 'thought', 'this', 'might', 'happen', '.', 'do', "n't", 'look', 'at', 'me', 'like', 'that', ',', 'old', 'friend', '.', 'you', 'must', 'have', 'known', 'this', 'day', 'would', 'come', '.', 'my', 'nightmares', 'are', 'finally', 'ready', '.', 'are', 'your', 'guardians', '?', 'very', 'well', '.', 'you', 'want', 'to', 'be', 'left', 'alone', '?', 'done', '.', 'but', 'first', '...', 'the', 'lights', '...', 'why', 'are', "n't", 'they', 'going', 'out', '?']
# 61
# DOUBLE CHECK: 61
# TYPES:
# 48
# {'very', 'might', 'would', '...', '?', 'ready', 'going', 'you', 'old', 'look', 'they', 'come', 'like', 'to', 'your', 'be', 'day', 'at', 'guardians', ',', 'but', 'that', 'first', 'lights', 'left', 'i', 'thought', 'this', 'have', 'alone', 'want', 'me', 'out', 'must', 'finally', "n't", 'do', 'well', 'done', 'my', 'known', 'happen', 'the', 'why', '.', 'are', 'friend', 'nightmares'}
# 12356     6
# 11873    30
# 12372    15
# 12128    10
# Name: Tokens, dtype: int64
# 12356                 [i, thought, this, might, happen, .]
# 11873    [do, n't, look, at, me, like, that, ,, old, fr...
# 12372    [very, well, ., you, want, to, be, left, alone...
# 12128    [the, lights, ..., why, are, n't, they, going,...
# Name: Tokens, dtype: object
# 	jack
# ['there', "'s", 'a', 'tiny', 'wooden', 'baby', '?', 'ahhhhhh', '!', '!', '!', '!', '!', 'you', 'have', 'big', 'eyes', '?', 'would', 'i', 'trick', 'you', '?', 'did', 'he', 'just', 'say', '--', '?', 'woooooohoooooooooo', '!', 'what', "'s", 'going', 'on', '?', 'bunny', '?', 'you', "'re", 'not', 'still', 'mad', 'about', 'that', '...', 'are', 'yah', '?', 'haaah', '!', 'i', 'got', 'it', '!', 'check', 'out', 'this', 'view', '--', 'eeeyaaaagghghh', '!']
# 62
# DOUBLE CHECK: 62
# TYPES:
# 43
# {'would', 'eyes', 'say', 'about', '...', '?', 'view', 'did', 'he', 'still', 'it', 'big', 'going', 'yah', 'you', 'got', 'baby', 'that', 'ahhhhhh', 'on', "'re", 'woooooohoooooooooo', 'i', 'this', 'have', 'just', 'mad', 'haaah', "'s", '!', 'trick', 'bunny', 'not', 'out', 'tiny', 'there', 'check', 'wooden', 'a', 'what', 'eeeyaaaagghghh', '--', 'are'}
# 11972     7
# 12211     6
# 11974     5
# 12393     5
# 12433     6
# 11772     2
# 12058     5
# 11878    13
# 12184     6
# 12006     7
# Name: Tokens, dtype: int64
# 11972                [there, 's, a, tiny, wooden, baby, ?]
# 12211                             [ahhhhhh, !, !, !, !, !]
# 11974                            [you, have, big, eyes, ?]
# 12393                            [would, i, trick, you, ?]
# 12433                          [did, he, just, say, --, ?]
# 11772                              [woooooohoooooooooo, !]
# 12058                             [what, 's, going, on, ?]
# 11878    [bunny, ?, you, 're, not, still, mad, about, t...
# 12184                            [haaah, !, i, got, it, !]
# 12006      [check, out, this, view, --, eeeyaaaagghghh, !]
# Name: Tokens, dtype: object
# 	bunnymund
# ['no', '!', 'wrong', '!', 'not', ',', 'not', 'true', '!', 'i', "'m", 'right', 'in', 'front', 'of', 'ya', ',', 'mate', '!', 'but', 'this', 'is', 'about', 'something', 'else', '.', 'fellas', '...', 'it', 'is', 'pitch', '.', 'we', 'have', 'a', 'problem', ',', 'mate', '!', 'trouble', 'at', 'the', 'tooth', 'palace', '.', 'oh', 'strewth', ',', 'i', 'knew', 'we', 'should', 'have', 'taken', 'the', 'tunnels', '.', 'oh', ',', 'what', "'s", 'over', 'there', '?']
# 64
# DOUBLE CHECK: 64
# TYPES:
# 45
# {'...', 'about', '?', 'is', 'it', 'else', 'ya', "'m", 'but', 'problem', 'at', ',', 'right', 'tooth', 'i', 'tunnels', 'taken', 'this', 'have', 'wrong', 'knew', 'true', "'s", 'something', 'no', '!', 'not', 'in', 'mate', 'we', 'of', 'palace', 'fellas', 'there', 'pitch', 'trouble', 'over', 'a', 'strewth', 'front', 'the', 'oh', 'what', '.', 'should'}
# 12326    19
# 11880     9
# 11753     4
# 11980    13
# 12010    12
# 12269     7
# Name: Tokens, dtype: int64
# 12326    [no, !, wrong, !, not, ,, not, true, !, i, 'm,...
# 11880    [but, this, is, about, something, else, ., fel...
# 11753                                   [it, is, pitch, .]
# 11980    [we, have, a, problem, ,, mate, !, trouble, at...
# 12010    [oh, strewth, ,, i, knew, we, should, have, ta...
# 12269                    [oh, ,, what, 's, over, there, ?]
# Name: Tokens, dtype: object
# 	jack's sister
# ['yes', '!', 'you', 'always', 'play', 'tricks', '!']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 6
# {'yes', 'always', 'tricks', '!', 'you', 'play'}
# 12394    7
# Name: Tokens, dtype: int64
# 12394    [yes, !, you, always, play, tricks, !]
# Name: Tokens, dtype: object
# 	jamie
# ['you', "'re", 'real', '?', 'who', "'s", 'jack', 'frost', '?', 'snow', '?']
# 11
# DOUBLE CHECK: 11
# TYPES:
# 9
# {'real', '?', "'s", 'who', 'jack', "'re", 'frost', 'you', 'snow'}
# 12443    4
# 11796    5
# 12431    2
# Name: Tokens, dtype: int64
# 12443          [you, 're, real, ?]
# 11796    [who, 's, jack, frost, ?]
# 12431                    [snow, ?]
# Name: Tokens, dtype: object
# 	tooth
# ['do', "n't", 'worry', ',', 'bunny', '.', 'i', 'bet', 'she', "'s", 'a', 'fairy', 'fan', '.', 'it', "'s", 'okay', 'little', 'one', '.', 'i', 'think', 'it', "'s", 'time', 'to', 'get', 'her', 'home', '.']
# 30
# DOUBLE CHECK: 30
# TYPES:
# 23
# {'one', 'it', 'time', 'her', 'home', 'worry', 'little', 'to', ',', 'she', 'bet', 'okay', 'i', 'fairy', 'fan', "'s", 'bunny', "n't", 'do', 'think', 'get', 'a', '.'}
# 12244    20
# 12278    10
# Name: Tokens, dtype: int64
# 12244    [do, n't, worry, ,, bunny, ., i, bet, she, 's,...
# 12278      [i, think, it, 's, time, to, get, her, home, .]
# Name: Tokens, dtype: object
# 	yeti
# ['arghbal', '...']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'...', 'arghbal'}
# 11700    2
# Name: Tokens, dtype: int64
# 11700    [arghbal, ...]
# Name: Tokens, dtype: object
# 	caleb
# ['yeah', ',', 'free', 'candy', '!']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 5
# {',', '!', 'free', 'candy', 'yeah'}
# 11779    5
# Name: Tokens, dtype: int64
# 11779    [yeah, ,, free, candy, !]
# Name: Tokens, dtype: object
# 	walker
# ['hey', ',', 'slow', 'down', '!']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 5
# {',', '!', 'down', 'slow', 'hey'}
# 11829    5
# Name: Tokens, dtype: int64
# 11829    [hey, ,, slow, down, !]
# Name: Tokens, dtype: object
# 	claude
# ['oh', '!', 'no', 'way', '!', 'on', 'bunny']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 6
# {'way', 'on', 'no', 'oh', '!', 'bunny'}
# 11813    2
# 12534    5
# Name: Tokens, dtype: int64
# 11813                    [oh, !]
# 12534    [no, way, !, on, bunny]
# Name: Tokens, dtype: object
# 	pippa
# ['crud', ',', 'i', 'hit', 'cupcake', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'crud', ',', 'cupcake', 'i', 'hit', '.'}
# 11810    6
# Name: Tokens, dtype: int64
# 11810    [crud, ,, i, hit, cupcake, .]
# Name: Tokens, dtype: object
# 	sophie
# ['bunny', '!', 'hop', '!', 'hop', '!', 'hop', '!']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 3
# {'!', 'bunny', 'hop'}
# 12179    8
# Name: Tokens, dtype: int64
# 12179    [bunny, !, hop, !, hop, !, hop, !]
# Name: Tokens, dtype: object
# Movie:Kung Fu Panda
# 	po's dad
# ['when', 'i', 'was', 'young', 'and', 'crazy', '...', 'that', "'s", 'my', 'boy', '.', 'that', 'big', ',', 'lovely', 'kung', 'fu', 'warrior', 'is', 'my', 'son', '!']
# 23
# DOUBLE CHECK: 23
# TYPES:
# 21
# ...
# 	old man
# ['you', "'re", 'only', 'a', 'fool', 'if', 'you', 'give', 'up', ',', 'boy', '.']
# 12
# DOUBLE CHECK: 12
# TYPES:
# 11
# {'if', 'give', 'boy', 'fool', 'up', 'a', ',', "'re", 'you', '.', 'only'}
# 1982    12
# Name: Tokens, dtype: int64
# 1982    [you, 're, only, a, fool, if, you, give, up, ,...
# Name: Tokens, dtype: object
# 	abu
# ['blah', 'blah', 'blah', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 2
# {'!', 'blah'}
# 1847    4
# Name: Tokens, dtype: int64
# 1847    [blah, blah, blah, !]
# Name: Tokens, dtype: object
# Movie:Moana
# 	moana
# ['what', 'if', 'we', 'fish', 'beyond', 'the', 'reef', '?', 'we', 'were', 'voyagers', '.', 'we', 'were', 'voyagers', '!', 'we', 'were', 'voyagers', '!', 'we', 'were', 'voyagers', '!', 'we', 'were', 'voyagers', '!', 'why', "'d", 'we', 'stop', '?', 'what', 'is', 'your', 'problem', '?', 'are…you', 'afraid', 'of', 'it', '?', 'and', 'he', 'lives', 'up', '...', 'there', '?', 'no', '!', 'stop', '!', 'hey', '!', 'you', 'have', 'to', 'put', 'back', 'the', 'heart', '!', 'and', 'restore', 'the', 'heart', 'of', 'te', 'fiti', '!', 'the', 'ocean', 'chose', 'me', '!', 'the', 'windward', 'side', '?']
# 81
# DOUBLE CHECK: 81
# TYPES:
# 44
# {'heart', '...', '?', 'he', 'is', 'it', 'fish', 'side', 'hey', 'you', 'if', 'to', 'your', 'problem', 'back', 'windward', 'afraid', 'voyagers', 'beyond', 'chose', 'te', 'have', 'up', 'stop', 'are…you', 'no', 'me', 'were', '!', 'restore', 'we', 'of', 'there', "'d", 'reef', 'lives', 'and', 'ocean', 'what', 'the', 'why', '.', 'fiti', 'put'}
# 5669     8
# 5705    25
# 5768    10
# 5828     7
# 5760    14
# 5946    13
# 5664     4
# Name: Tokens, dtype: int64
# 5669           [what, if, we, fish, beyond, the, reef, ?]
# 5705    [we, were, voyagers, ., we, were, voyagers, !,...
# 5768    [what, is, your, problem, ?, are…you, afraid, ...
# 5828                  [and, he, lives, up, ..., there, ?]
# 5760    [no, !, stop, !, hey, !, you, have, to, put, b...
# 5946    [and, restore, the, heart, of, te, fiti, !, th...
# 5664                             [the, windward, side, ?]
# Name: Tokens, dtype: object
# 	maui
# ['it', "'s", 'called', 'wayfinding', ',', 'princess', '.', 'it', "'s", 'not', 'just', 'sails', 'and', 'knots', '.', 'it', "'s", 'seeing', 'where', 'you', "'re", 'going', 'in', 'your', 'mind', '.', 'knowing', 'where', 'you', 'are', 'by', 'knowing', 'where', 'you', "'ve", 'been', '.']
# 37
# DOUBLE CHECK: 37
# TYPES:
# 25
# {"'ve", 'by', 'it', 'going', 'sails', 'you', 'called', 'your', ',', "'re", 'knowing', 'just', 'knots', "'s", 'not', 'seeing', 'in', 'wayfinding', 'princess', 'and', 'mind', 'where', 'been', '.', 'are'}
# 5809    37
# Name: Tokens, dtype: int64
# 5809    [it, 's, called, wayfinding, ,, princess, ., i...
# Name: Tokens, dtype: object
# 	tala
# ['i', "'m", 'the', 'village', 'crazy', 'lady', '.', 'that', "'s", 'my', 'job', '.', 'in', 'the', 'beginning', ',', 'there', 'was', 'only', 'ocean', 'until', 'the', 'mother', 'island', 'emerged', '.', 'te', 'fiti', '.', 'her', 'heart', 'held', 'the', 'greatest', 'power', 'ever', 'known', '.', 'it', 'could', 'create', 'life', 'itself', '!', 'and', 'te', 'fiti', 'shared', 'it', 'with', 'the', 'world', '.', 'but', 'in', 'time', ',', 'some', 'began', 'to', 'seek', 'te', 'fiti', "'s", 'heart', '.', 'they', 'believed', 'if', 'they', 'could', 'possess', 'it', ',', 'the', 'great', 'power', 'of', 'creation', 'would', 'be', 'theirs', '.', 'and', 'one', 'day', ',', 'the', 'most', 'daring', 'of', 'them', 'all', 'voyaged', 'across', 'the', 'vast', 'ocean', 'to', 'take', 'it', '.', 'he', 'was', 'a', 'demigod', 'of', 'the', 'wind', 'and', 'sea', '.', 'he', 'was', 'a', 'warrior', ',', 'a', 'trickster', ',', 'a', 'shapeshifter', 'who', 'could', 'change', 'form', 'with', 'the', 'power', 'of', 'his', 'magical', 'fish', 'hook', '.', 'and', 'his', 'name', 'was', 'maui', '.', 'but', 'without', 'her', 'heart', ',', 'te', 'fiti', 'began', 'to', 'crumble', ',', 'giving', 'birth', 'to', 'a', 'terrible', 'darkness', '.', 'maui', 'tried', 'to', 'escape', 'but', 'was', 'confronted', 'by', 'another', 'who', 'sought', 'the', 'heart', ':', 'te', 'ka', '!', 'a', 'demon', 'of', 'earth', 'and', 'fire', '.', 'maui', 'was', 'struck', 'from', 'the', 'sky', 'never', 'to', 'be', 'seen', 'again', '.', 'and', 'his', 'magical', 'fish', 'hook', 'and', 'the', 'heart', 'of', 'te', 'fiti', 'were', 'lost', 'to', 'the', 'sea', ',', 'where', ',', 'even', 'now', ',', 'a', 'thousand', 'years', 'later', ',', 'te', 'ka', 'and', 'the', 'demons', 'of', 'the', 'deep', 'still', 'hunt', 'for', 'the', 'heart', ',', 'hiding', 'in', 'a', 'darkness', 'that', 'will', 'continue', 'to', 'spread', ',', 'chasing', 'away', 'our', 'fish', ',', 'draining', 'the', 'life', 'from', 'island', 'after', 'island', 'until', 'every', 'one', 'of', 'us', 'is', 'devoured', 'by', 'the', 'bloodthirsty', 'jaws', 'of', 'inescapable', 'death', '!', 'but', 'one', 'day', ',', 'the', 'heart', 'will', 'be', 'found', 'by', 'someone', 'who', 'will', 'journey', 'beyond', 'our', 'reef', ',', 'find', 'maui', ',', 'deliver', 'him', 'across', 'the', 'great', 'ocean', 'to', 'resture', 'te', 'fiti', "'s", 'heart', ',', 'and', 'save', 'us', 'all', '.']
# 312
# DOUBLE CHECK: 312
# TYPES:
# 147
# {'he', 'him', 'greatest', 'resture', 'hunt', 'demons', 'to', 'village', 'bloodthirsty', 'without', 'lady', 'take', 'terrible', 'with', 'escape', 'never', 'mother', '!', 'demigod', 'began', 'creation', 'our', 'his', 'journey', 'emerged', 'only', 'a', 'fire', 'life', 'great', 'away', 'would', 'by', 'crazy', 'one', 'it', 'is', 'fish', 'us', 'hook', 'most', 'be', 'seen', 'after', 'day', 'inescapable', 'giving', 'magical', 'some', 'beyond', 'save', 'te', 'found', 'deliver', 'later', 'even', 'were', 'in', 'ever', 'struck', 'years', 'continue', 'for', '.', 'wind', 'death', 'hiding', 'jaws', 'shared', 'all', 'devoured', 'tried', 'spread', "'m", 'demon', 'but', 'name', 'daring', 'possess', 'i', 'until', 'again', 'world', 'crumble', 'seek', 'earth', 'now', 'ka', 'power', 'birth', 'thousand', 'reef', 'from', 'my', 'and', 'ocean', 'every', 'form', 'the', 'warrior', 'will', 'fiti', 'beginning', 'another', 'shapeshifter', 'confronted', 'heart', 'create', 'was', 'chasing', 'her', 'time', 'still', 'change', 'someone', 'they', 'across', 'if', 'itself', ',', 'that', 'draining', 'them', 'sea', 'held', 'could', 'theirs', 'trickster', 'sky', 'maui', "'s", 'vast', 'job', 'believed', 'island', ':', 'of', 'there', 'known', 'find', 'lost', 'voyaged', 'who', 'darkness', 'deep', 'where', 'sought'}
# 5696     12
# 5606    300
# Name: Tokens, dtype: int64
# 5696    [i, 'm, the, village, crazy, lady, ., that, 's...
# 5606    [in, the, beginning, ,, there, was, only, ocea...
# Name: Tokens, dtype: object
# 	tui
# ['of', 'course', ',', 'i', 'understand', 'you', 'have', 'reason', 'for', 'concern', '.', 'i', 'will', 'talk', 'to', 'the', 'council', '.', 'i', "'m", 'sure', 'we', 'can', '--']
# 24
# DOUBLE CHECK: 24
# TYPES:
# 21
# {'--', 'can', 'you', '.', 'sure', 'to', "'m", ',', 'i', 'talk', 'have', 'council', 'course', 'we', 'understand', 'of', 'the', 'for', 'concern', 'will', 'reason'}
# 5668    24
# Name: Tokens, dtype: int64
# 5668    [of, course, ,, i, understand, you, have, reas...
# Name: Tokens, dtype: object
# 	young moana
# ['shoo', '!', 'shoo', '!', 'eeee', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 3
# {'!', 'shoo', 'eeee'}
# 5618    6
# Name: Tokens, dtype: int64
# 5618    [shoo, !, shoo, !, eeee, !]
# Name: Tokens, dtype: object
# Movie:Sleeping Beauty
# 	fauna
# ['happy', 'birthday', '!', 'eggs', ',', 'flour', ',', 'milk', ',']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 7
# {'milk', ',', 'eggs', 'happy', '!', 'flour', 'birthday'}
# 1131    3
# 1112    6
# Name: Tokens, dtype: int64
# 1131            [happy, birthday, !]
# 1112    [eggs, ,, flour, ,, milk, ,]
# Name: Tokens, dtype: object
# 	phillip
# ['goodbye', ',', 'father', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'goodbye', '!', ',', 'father'}
# 1231    4
# Name: Tokens, dtype: int64
# 1231    [goodbye, ,, father, !]
# Name: Tokens, dtype: object
# 	merryweather
# ['you', 'really', 'think', 'we', 'can', '?', 'they', 'are', "n't", '?', 'she', "'s", 'got', 'prince', 'phillip', '!']
# 16
# DOUBLE CHECK: 16
# TYPES:
# 15
# {'think', 'really', 'got', '?', 'she', "'s", '!', 'phillip', 'can', 'you', "n't", 'are', 'we', 'they', 'prince'}
# 944     6
# 1267    4
# 1279    6
# Name: Tokens, dtype: int64
# 944       [you, really, think, we, can, ?]
# 1267                   [they, are, n't, ?]
# 1279    [she, 's, got, prince, phillip, !]
# Name: Tokens, dtype: object
# 	flora
# ['oh', 'gracious', 'how', 'the', 'child', 'has', 'grown', '.', 'now', ',', 'dear', ',', 'we', 'decided', 'pink', 'was', 'her', 'color', '.', 'yes', '...']
# 21
# DOUBLE CHECK: 21
# TYPES:
# 19
# {'pink', '...', 'yes', 'was', 'how', 'now', 'child', ',', 'gracious', 'her', 'the', 'oh', 'dear', 'we', 'decided', 'color', 'grown', 'has', '.'}
# 1045     8
# 1036    11
# 894      2
# Name: Tokens, dtype: int64
# 1045       [oh, gracious, how, the, child, has, grown, .]
# 1036    [now, ,, dear, ,, we, decided, pink, was, her,...
# 894                                            [yes, ...]
# Name: Tokens, dtype: object
# 	hubert
# ['what', "'s", 'wrong', 'with', 'my', 'phillip', '?', 'children', 'need', 'a', 'nest', 'of', 'their', 'own', ',', 'what', '?', 'place', 'to', 'raise', 'their', 'little', 'brood', ',', 'ey', '?']
# 26
# DOUBLE CHECK: 26
# TYPES:
# 21
# {'their', '?', 'raise', 'ey', 'to', 'little', ',', 'own', 'nest', 'place', 'phillip', 'with', 'wrong', "'s", 'brood', 'of', 'my', 'a', 'need', 'what', 'children'}
# 1195     7
# 1172    19
# Name: Tokens, dtype: int64
# 1195              [what, 's, wrong, with, my, phillip, ?]
# 1172    [children, need, a, nest, of, their, own, ,, w...
# Name: Tokens, dtype: object
# 	1st servant
# ['yeah', ',', 'yeah', ',', 'anywhere', ',', 'we', 'all', '...']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 6
# {'...', ',', 'anywhere', 'all', 'we', 'yeah'}
# 962    9
# Name: Tokens, dtype: int64
# 962    [yeah, ,, yeah, ,, anywhere, ,, we, all, ...]
# Name: Tokens, dtype: object
# 	briar rose
# ['oh', 'dear', ',', 'why', 'do', 'they', 'still', 'treat', 'me', 'like', 'a', 'child', '.', 'betrothed', '?', 'oh', ',', 'no', ',', 'no', '!', 'i', 'ca', "n't", 'believe', 'it', '.', 'no', ',', 'no', '!']
# 31
# DOUBLE CHECK: 31
# TYPES:
# 22
# {'?', 'child', 'still', 'it', 'dear', 'ca', 'they', 'like', ',', 'i', 'treat', 'no', 'me', '!', "n't", 'betrothed', 'do', 'believe', 'a', 'oh', 'why', '.'}
# 1061    13
# 1147     2
# 1156    16
# Name: Tokens, dtype: int64
# 1061    [oh, dear, ,, why, do, they, still, treat, me,...
# 1147                                       [betrothed, ?]
# 1156    [oh, ,, no, ,, no, !, i, ca, n't, believe, it,...
# Name: Tokens, dtype: object
# 	fairies
# ['maleficent', '!']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'!', 'maleficent'}
# 1278    2
# Name: Tokens, dtype: int64
# 1278    [maleficent, !]
# Name: Tokens, dtype: object
# Movie:Snow White
# 	happy
# ['what', 'is', 'it', '?']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'is', 'it', 'what', '?'}
# 117    4
# Name: Tokens, dtype: int64
# 117    [what, is, it, ?]
# Name: Tokens, dtype: object
# 	all dwarfs
# ['shh', '!']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'!', 'shh'}
# 87    2
# Name: Tokens, dtype: int64
# 87    [shh, !]
# Name: Tokens, dtype: object
# 	doc
# ['courage', ',', 'men', ',', 'courage', '!', 'do', "n't", 'be', 'nervous', '.']
# 11
# DOUBLE CHECK: 11
# TYPES:
# 9
# {'be', 'nervous', 'men', ',', '!', '.', "n't", 'do', 'courage'}
# 196    11
# Name: Tokens, dtype: int64
# 196    [courage, ,, men, ,, courage, !, do, n't, be, ...
# Name: Tokens, dtype: object
# 	snow white
# ['goodbye', '.', 'goodbye', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 3
# {'goodbye', '!', '.'}
# 297    4
# Name: Tokens, dtype: int64
# 297    [goodbye, ., goodbye, !]
# Name: Tokens, dtype: object
# 	sneezy
# ['hey', '!', 'hey', '!', 'hey', '!', 'hey', '!']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 2
# {'!', 'hey'}
# 239    8
# Name: Tokens, dtype: int64
# 239    [hey, !, hey, !, hey, !, hey, !]
# Name: Tokens, dtype: object
# 	grumpy
# ['nothin', "'", '!', 'just', 'standin', "'", 'there', 'sputterin', "'", 'like', 'a', 'doodlebug', '!']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 10
# {'nothin', 'like', 'doodlebug', 'a', "'", 'standin', '!', 'sputterin', 'there', 'just'}
# 157    13
# Name: Tokens, dtype: int64
# 157    [nothin, ', !, just, standin, ', there, sputte...
# Name: Tokens, dtype: object
# Movie:Mulan
# 	mushu
# ['of', 'course', '!', 'i', 'am', 'travelsized', ',', 'for', 'your', 'convenience', '.', 'if', 'i', 'was', 'my', 'real', 'size', ',', 'your', 'cow', 'here', 'would', 'die', 'of', 'fright', '.', 'did', 'i', 'hear', 'someone', 'ask', 'for', 'a', 'miracle', '!', 'lem', 'me', 'hear', 'ya', 'say', ',', '``', 'aaah', '!', "''", 'you', 'missed', '!', 'how', 'could', 'you', 'miss', '?', '!', 'he', 'was', 'three', 'feet', 'in', 'front', 'of', 'you', '!', 'beautiful', ',', 'is', "n't", 'it', '.', 'urgent', 'new', 'from', 'the', 'general', '!']
# 75
# DOUBLE CHECK: 75
# TYPES:
# 54
# {'would', 'say', 'beautiful', 'was', '?', 'did', 'he', 'is', 'it', 'new', 'someone', 'you', 'die', 'ya', 'if', 'your', 'ask', ',', 'how', 'cow', 'hear', 'i', 'missed', 'here', 'could', 'urgent', 'real', 'size', "''", 'fright', 'feet', '``', 'miss', 'lem', 'me', '!', 'course', 'in', "n't", 'of', 'from', 'my', 'am', 'a', 'three', 'convenience', 'front', 'the', 'travelsized', 'miracle', 'for', '.', 'aaah', 'general'}
# 4159    26
# 4145    19
# 4366    18
# 4165     6
# 4339     6
# Name: Tokens, dtype: int64
# 4159    [of, course, !, i, am, travelsized, ,, for, yo...
# 4145    [did, i, hear, someone, ask, for, a, miracle, ...
# 4366    [you, missed, !, how, could, you, miss, ?, !, ...
# 4165                       [beautiful, ,, is, n't, it, .]
# 4339                 [urgent, new, from, the, general, !]
# Name: Tokens, dtype: object
# 	fa zhou
# ['mulan', '!', 'no', '...', 'mulan', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 4
# {'mulan', '!', '...', 'no'}
# 4081    4
# 4063    2
# Name: Tokens, dtype: int64
# 4081    [mulan, !, no, ...]
# 4063             [mulan, !]
# Name: Tokens, dtype: object
# 	emperor
# ['chi', 'fu', '!']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'!', 'fu', 'chi'}
# 4485    3
# Name: Tokens, dtype: int64
# 4485    [chi, fu, !]
# Name: Tokens, dtype: object
# 	ling
# ['hey', '!', 'there', 'he', 'goes', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 5
# {'he', 'goes', '!', 'hey', 'there'}
# 4187    6
# Name: Tokens, dtype: int64
# 4187    [hey, !, there, he, goes, !]
# Name: Tokens, dtype: object
# 	mulan
# ['i', "'ve", 'got', 'a', 'name', '...', 'and', 'it', "'s", 'a', 'boy', "'s", 'name', ',', 'too', '.', 'i', 'do', "n't", 'think', 'i', 'can', 'do', 'this', '...', 'no', '!', 'i', '...']
# 29
# DOUBLE CHECK: 29
# TYPES:
# 20
# {"'ve", 'got', '...', 'boy', 'name', 'a', 'and', ',', "'s", 'it', 'think', 'no', 'i', '!', 'too', 'can', '.', "n't", 'this', 'do'}
# 4211    16
# 4171     9
# 4329     4
# Name: Tokens, dtype: int64
# 4211    [i, 've, got, a, name, ..., and, it, 's, a, bo...
# 4171           [i, do, n't, think, i, can, do, this, ...]
# 4329                                      [no, !, i, ...]
# Name: Tokens, dtype: object
# 	shang
# ['oh', 'i', 'will', '!', 'i', 'wo', "n't", 'let', 'you', 'down', '!', 'this', 'is', '...', 'i', 'mean', '...', 'yes', 'sir', '.', 'you', 'do', "n't", 'belong', 'here', ',', 'mulan', '.', 'go', 'home', '.']
# 31
# DOUBLE CHECK: 31
# TYPES:
# 23
# {'...', 'is', 'go', 'home', 'you', 'let', 'yes', ',', 'wo', 'i', 'this', 'sir', 'here', 'belong', '!', "n't", 'do', 'mean', 'oh', 'mulan', 'down', '.', 'will'}
# 4195    20
# 4418    11
# Name: Tokens, dtype: int64
# 4195    [oh, i, will, !, i, wo, n't, let, you, down, !...
# 4418    [you, do, n't, belong, here, ,, mulan, ., go, ...
# Name: Tokens, dtype: object
# 	chi fu
# ['insubordinate', 'ruffians', '.', 'you', 'men', 'owe', 'me', 'a', 'new', 'pair', 'of', 'slippers', '!']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 13
# {'men', 'a', 'slippers', 'owe', 'me', 'new', 'pair', 'insubordinate', '!', 'ruffians', 'you', '.', 'of'}
# 4337    13
# Name: Tokens, dtype: int64
# 4337    [insubordinate, ruffians, ., you, men, owe, me...
# Name: Tokens, dtype: object
# 	yao
# ['and', 'i', 'am', 'yao', ',', 'king', 'of', 'the', 'rock', '!', 'and', 'there', "'s", 'nothing', 'you', 'girls', 'can', 'do', 'about', 'it', '.']
# 21
# DOUBLE CHECK: 21
# TYPES:
# 20
# {'am', 'about', 'and', ',', "'s", 'it', 'the', 'i', 'king', '!', 'nothing', 'girls', 'can', 'you', 'do', 'yao', 'rock', 'of', 'there', '.'}
# 4306    21
# Name: Tokens, dtype: int64
# 4306    [and, i, am, yao, ,, king, of, the, rock, !, a...
# Name: Tokens, dtype: object

# %%
char_toks_df = pd.DataFrame(columns=["Disney_Period", "Gender", "Movie", "Role", "Speaker", "Speaker_Status", "Year"])
for movie in movie_df.Movie.unique():
    movie_data = movie_df[movie_df.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        char_data = movie_data[movie_data.Speaker == char]#['Tokens']
        #print('|{}|'.format(char))
        #if isinstance(char_data,str):
        #    print(char_data)
        #print(type(char_data))
        all_toks = char_data['Tokens']
        print('\n')
        all_toks_count = char_data['Token_Count'].sum()
        print('\n')
        total_toks_list = all_toks.sum()
        print(type(total_toks_list))
        print('\n')
       # print(char_data)
        char_movie_data = pd.DataFrame([char_data.iloc[0]])
       # print(char_movie_data)
        print('\n')
        char_movie_data['Total_Toks'] = [total_toks_list]
        char_movie_data['Total_Tok_Count'] = all_toks_count
        print('\n')
        #Now for Types--just create a set of the big list instead of combining all sets
        char_movie_data['Total_Types'] = [set(total_toks_list)]
        print('\n')
        char_movie_data['Total_Type_Count'] = len(set(total_toks_list))
        print('\n')
        char_movie_data.drop(labels=['Song', 'Text', 'UTTERANCE_NUMBER', 'Tokens', 'Token_Count', 'Types', 'Type_Count'],
                             axis=1, inplace=True)
        char_toks_df = pd.concat([char_toks_df, char_movie_data], axis=0, sort=True, ignore_index = True)
        
    break

char_movie_data
# Out:
# Movie:Snow White
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#     Disney_Period Gender       Movie    Role          Speaker Speaker_Status  \
# 173         EARLY      m  Snow White  HELPER  grumpy & sneezy          NON-P
#
#      Year             Total_Toks  Total_Tok_Count            Total_Types  \
# 173  1937  [apple, dumplings, !]                3  {!, dumplings, apple}
#
#      Total_Type_Count
# 173                 3

# %%
char_toks_df.shape
# Out:
# (15, 11)

# %%
len(movie_df[movie_df.Movie == "Snow White"].Speaker.unique())
# Out:
# 15

# %%
char_toks_df
# Out:
#    Disney_Period Gender       Movie    Role          Speaker Speaker_Status  \
# 0          EARLY      f  Snow White     ANT            queen          NON-P
# 1          EARLY      m  Snow White     ANT           mirror          NON-P
# 2          EARLY      m  Snow White     PRO           prince         PRINCE
# 3          EARLY      f  Snow White     PRO       snow white       PRINCESS
# 4          EARLY      m  Snow White     ANT            guard          NON-P
# 5          EARLY      m  Snow White  HELPER              doc          NON-P
# 6          EARLY      m  Snow White  HELPER       all dwarfs          NON-P
# 7          EARLY      m  Snow White  HELPER            happy          NON-P
# 8          EARLY      m  Snow White  HELPER          bashful          NON-P
# 9          EARLY      m  Snow White  HELPER            dopey          NON-P
# 10         EARLY      m  Snow White  HELPER           grumpy          NON-P
# 11         EARLY      m  Snow White  HELPER           sneezy          NON-P
# 12         EARLY      m  Snow White  HELPER   various dwarfs          NON-P
# 13         EARLY      m  Snow White  HELPER           sleepy          NON-P
# 14         EARLY      m  Snow White  HELPER  grumpy & sneezy          NON-P
#
#     Total_Tok_Count                                         Total_Toks  \
# 0             940.0  [slave, in, the, magic, mirror, come, from, th...
# 1              81.0  [what, wouldst, thou, know, ,, my, queen, ?, f...
# 2               5.0                       [today, hello, ., one, song]
# 3            1231.0  [oh, !, oh, ., hello, there, ., what, 's, the,...
# 4              95.0  [yes, ,, your, majesty, ., but, ,, your, majes...
# 5             903.0  [look, !, our, house, !, the, lit, 's, lightuh...
# 6             224.0  [jiminy, crickets, ., the, door, is, open, ., ...
# 7             178.0  [gosh, ., our, window, 's, been, washed, ., th...
# 8              92.0  [that, 's, a, bad, sign, ., gosh, ,, our, cobw...
# 9               2.0                                           [shh, !]
# 10            411.0  [hah, !, chair, 's, been, dusted, ., there, 's...
# 11            183.0  [sink, 's, empty, ., hey, ,, someone, stole, o...
# 12            195.0  [do, n't, let, go, ., hold, him, tight, ., i, ...
# 13             36.0  [how, 'd, you, guess, ?, it, 's, cold, too, !,...
# 14              3.0                              [apple, dumplings, !]
#
#     Total_Type_Count                                        Total_Types  Year
# 0              314.0  {'em, 've, raiment, suspect, he, him, fair, li...  1937
# 1               57.0  {than, thee, heart, pig, white, ?, hair, black...  1937
# 2                5.0                       {song, today, one, ., hello}  1937
# 3              311.0  {women, 've, wonder, he, whywhy, him, butbut, ...  1937
# 4               43.0  {woods, jealous, child, it, go, you, ca, come,...  1937
# 5              288.0  {'em, bluff, 've, doin, he, whywhy, him, squea...  1937
# 6              107.0  {he, him, words, to, hurt, ai, story, with, sl...  1937
# 7               93.0  {nowhere, he, somethin, come, to, ai, happy, t...  1937
# 8               59.0  {say, beautiful, bedroom, ?, did, he, it, wile...  1937
# 9                2.0                                           {!, shh}  1937
# 10             165.0  {give, 'em, women, kettle, afoot, wiles, catch...  1937
# 11              86.0  {'ve, fever, count, hey, to, watch, take, ahch...  1937
# 12              80.0  {give, jiminy, doin, was, ?, knot, did, him, i...  1937
# 13              31.0  {was, white, ?, he, it, big, you, us, old, ya,...  1937
# 14               3.0                              {!, dumplings, apple}  1937

# %%
#Some speakers only have a few lines, or one! makes things tricky....

# %%
char_toks_df = pd.DataFrame(columns=["Disney_Period", "Gender", "Movie", "Role", "Speaker", "Speaker_Status", "Year"])
counter = 0
for movie in movie_df.Movie.unique():
    movie_data = movie_df[movie_df.Movie == movie]
    print("Movie:"+movie)
    char_count = 0
    for char in movie_data.Speaker.unique():
        char_data = movie_data[movie_data.Speaker == char]
        all_toks = char_data['Tokens']
        all_toks_count = char_data['Token_Count'].sum()
        total_toks_list = all_toks.sum()
        char_movie_data = pd.DataFrame([char_data.iloc[0]])
        char_movie_data['Total_Toks'] = [total_toks_list]
        char_movie_data['Total_Tok_Count'] = all_toks_count
        #Now for Types--just create a set of the big list instead of combining all sets
        char_movie_data['Total_Types'] = [set(total_toks_list)]
        char_movie_data['Total_Type_Count'] = len(set(total_toks_list))
        char_movie_data.drop(labels=['Song', 'Text', 'UTTERANCE_NUMBER', 'Tokens', 'Token_Count', 'Types', 'Type_Count'],
                             axis=1, inplace=True)
        char_toks_df = pd.concat([char_toks_df, char_movie_data], axis=0, sort=True, ignore_index = True)
        char_count+=1
    counter +=1    
    print(movie, 'complete!')
    print("This many characters captured!", char_count)
    print(counter)
# Out:
# Movie:Snow White
# Snow White complete!
# This many characters captured! 15
# 1
# Movie:Cinderella
# Cinderella complete!
# This many characters captured! 24
# 2
# Movie:Sleeping Beauty
# Sleeping Beauty complete!
# This many characters captured! 16
# 3
# Movie:The Little Mermaid
# The Little Mermaid complete!
# This many characters captured! 24
# 4
# Movie:Aladdin
# Aladdin complete!
# This many characters captured! 28
# 5
# Movie:Beauty and the Beast
# Beauty and the Beast complete!
# This many characters captured! 28
# 6
# Movie:Pocahontas
# Pocahontas complete!
# This many characters captured! 17
# 7
# Movie:Mulan
# Mulan complete!
# This many characters captured! 42
# 8
# Movie:The Princess and the Frog
# The Princess and the Frog complete!
# This many characters captured! 39
# 9
# Movie:Brave
# Brave complete!
# This many characters captured! 12
# 10
# Movie:Moana
# Moana complete!
# This many characters captured! 19
# 11
# Movie:Tangled
# Tangled complete!
# This many characters captured! 16
# 12
# Movie:Frozen
# Frozen complete!
# This many characters captured! 60
# 13
# Movie:Antz
# Antz complete!
# This many characters captured! 56
# 14
# Movie:Shrek
# Shrek complete!
# This many characters captured! 36
# 15
# Movie:Shrek 3
# Shrek 3 complete!
# This many characters captured! 70
# 16
# Movie:Kung Fu Panda
# Kung Fu Panda complete!
# This many characters captured! 30
# 17
# Movie:How to Train Your Dragon
# How to Train Your Dragon complete!
# This many characters captured! 27
# 18
# Movie:Megamind
# Megamind complete!
# This many characters captured! 14
# 19
# Movie:Rise of the Guardians
# Rise of the Guardians complete!
# This many characters captured! 28
# 20
# Movie:The Croods
# The Croods complete!
# This many characters captured! 12
# 21
# Movie:How to Train Your Dragon 2
# How to Train Your Dragon 2 complete!
# This many characters captured! 19
# 22

# %%
len(movie_df.Movie.unique()) #all movies done!
# Out:
# 22

# %%
#did we get all the characters?
movie_df.groupby('Movie', sort=False)['Speaker'].unique().map(len)
#number match up!!!
# Out:
# Movie
# Snow White                    15
# Cinderella                    24
# Sleeping Beauty               16
# The Little Mermaid            24
# Aladdin                       28
# Beauty and the Beast          28
# Pocahontas                    17
# Mulan                         42
# The Princess and the Frog     39
# Brave                         12
# Moana                         19
# Tangled                       16
# Frozen                        60
# Antz                          56
# Shrek                         36
# Shrek 3                       70
# Kung Fu Panda                 30
# How to Train Your Dragon      27
# Megamind                      14
# Rise of the Guardians         28
# The Croods                    12
# How to Train Your Dragon 2    19
# Name: Speaker, dtype: int64

# %% [markdown]
# Now that we have this info by character, let's save it!

# %%
char_toks_df.shape #total number of unique characters = 632
# Out:
# (632, 11)

# %%
movie_df.groupby('Movie', sort=False)['Speaker'].unique().map(len).sum() #lol, double-double check!
# Out:
# 632

# %%
char_toks_df.to_pickle(r"C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\char_toks.pkl")
