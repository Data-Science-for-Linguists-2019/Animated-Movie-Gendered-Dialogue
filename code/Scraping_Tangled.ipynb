# %% [markdown]
# ## An Attempt at Web Scraping

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
link = "https://imeldasanders123.wordpress.com/disney-tangled-script/"

# %%
page_response = requests.get(link, timeout=5)

# %%
page_response
# Out:
# <Response [200]>

# %%
page_content = BeautifulSoup(page_response.content, "html.parser")

# %%
print(page_content)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 6]>
# <html id="ie6" lang="en">
# <![endif]-->
# <!--[if IE 8]>
# <html id="ie8" lang="en">
# <![endif]-->
# <!--[if (!IE)]><!-->
# <html lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>Script for Tangled | I, Merida, and my interactive Disney/Pixar scripts</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://imeldasanders123.wordpress.com/xmlrpc.php" rel="pingback"/>
# <meta content="C8r_HkMuOWdBLDxRG_syhlr9G5BR-LonuelzwdRCXPE" name="google-site-verification"/>
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//s1.wp.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="https://imeldasanders123.wordpress.com/feed/" rel="alternate" title="I, Merida, and my interactive Disney/Pixar scripts » Feed" type="application/rss+xml"/>
# ...

# %%
type(page_content)
# Out:
# bs4.BeautifulSoup

# %%
page_content.body.div id
# Out:
# <div class="hfeed contain" id="container">
# <div id="header">
# <div id="masthead" role="banner">
# <div id="site-title">
# <span>
# <a href="https://imeldasanders123.wordpress.com/" rel="home" title="I, Merida, and my interactive Disney/Pixar scripts">I, Merida, and my interactive Disney/Pixar scripts</a>
# </span>
# </div>
# <div id="site-description">Brave With My Tangled Untamed Hair; Disney Tangled x Pixar Brave (script)</div>
# </div><!-- #masthead -->
# <div id="access" role="navigation">
# <div class="skip-link screen-reader-text"><a href="#content" title="Skip to content">Skip to content</a></div>
# <div class="menu-header"><ul class="menu" id="menu-menu-1"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-3712" id="menu-item-3712"><a href="https://imeldasanders123.wordpress.com/">Home</a></li>
# ...

# %%
new_html = page_content.find("div", {"class": "entry-content"})

# %%
new_html #this is the script portion!!!
# Out:
# <div class="entry-content">
# <p>—Key—<br/>
# R:Rapunzel, Mandy Moore<br/>
# F:Eugene Fitzherbert/Flynn Rider, Zachary Levi<br/>
# G:Mother Gothel, Donna Murphy<br/>
# Hook:Hook-Hand Thug, Brad Garrett<br/>
# Big:Big Nose Thug, Jeffrey Tambor<br/>
# St:The Stabbington Brothers, Ron Perlman (only the speaking one; the one without the eye-patch)<br/>
# Vlad:Vladamir, Richard Kiel<br/>
# Shorty:Shorty Thug, Paul F. Tompkins<br/>
# Young R:Young Rapunzel, Delaney Rose Stein<br/>
# Capt:Captain of the Guard, M. C. Gainey</p>
# <p>Other voices:<br/>
# Guard #1/Thug #1 (voice): Nathan Greno<br/>
# Guard #2/Thug #2 (voice): Byron Howard<br/>
# Guard #3 (voice): Tim Mertens<br/>
# Additional Voices:<br/>
# ...

# %%
for span in new_html.find_all('span'):
    span.replace_with('')

# %%
new_html
# Out:
# <div class="entry-content">
# <p>—Key—<br/>
# R:Rapunzel, Mandy Moore<br/>
# F:Eugene Fitzherbert/Flynn Rider, Zachary Levi<br/>
# G:Mother Gothel, Donna Murphy<br/>
# Hook:Hook-Hand Thug, Brad Garrett<br/>
# Big:Big Nose Thug, Jeffrey Tambor<br/>
# St:The Stabbington Brothers, Ron Perlman (only the speaking one; the one without the eye-patch)<br/>
# Vlad:Vladamir, Richard Kiel<br/>
# Shorty:Shorty Thug, Paul F. Tompkins<br/>
# Young R:Young Rapunzel, Delaney Rose Stein<br/>
# Capt:Captain of the Guard, M. C. Gainey</p>
# <p>Other voices:<br/>
# Guard #1/Thug #1 (voice): Nathan Greno<br/>
# Guard #2/Thug #2 (voice): Byron Howard<br/>
# Guard #3 (voice): Tim Mertens<br/>
# Additional Voices:<br/>
# ...

# %%
for line in new_html.p.children:
    print(line)
    print("Now a new child:")
# Out:
# —Key—
# Now a new child:
# <br/>
# Now a new child:
#
# R:Rapunzel, Mandy Moore
# Now a new child:
# <br/>
# Now a new child:
#
# F:Eugene Fitzherbert/Flynn Rider, Zachary Levi
# Now a new child:
# <br/>
# Now a new child:
#
# G:Mother Gothel, Donna Murphy
# Now a new child:
# <br/>
# Now a new child:
#
# Hook:Hook-Hand Thug, Brad Garrett
# Now a new child:
# <br/>
# Now a new child:
#
# Big:Big Nose Thug, Jeffrey Tambor
# Now a new child:
# <br/>
# Now a new child:
#
# St:The Stabbington Brothers, Ron Perlman (only the speaking one; the one without the eye-patch)
# Now a new child:
# <br/>
# Now a new child:
#
# Vlad:Vladamir, Richard Kiel
# Now a new child:
# <br/>
# Now a new child:
#
# Shorty:Shorty Thug, Paul F. Tompkins
# Now a new child:
# <br/>
# Now a new child:
#
# Young R:Young Rapunzel, Delaney Rose Stein
# Now a new child:
# <br/>
# Now a new child:
#
# Capt:Captain of the Guard, M. C. Gainey
# Now a new child:

# %%
import re

# %%
#I'm really not familiar with webscraping or beautiful soup objects...can I turn this into a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-16e215ad8050> in <module>
# ----> 1 new = page_content.split("-BEGIN-")
#
# TypeError: 'NoneType' object is not callable

# %%
tangled_string = str(new_html)

# %%
tangled_string
# Out:
# '<div class="entry-content">\n<p>—Key—<br/>\nR:Rapunzel, Mandy Moore<br/>\nF:Eugene Fitzherbert/Flynn Rider, Zachary Levi<br/>\nG:Mother Gothel, Donna Murphy<br/>\nHook:Hook-Hand Thug, Brad Garrett<br/>\nBig:Big Nose Thug, Jeffrey Tambor<br/>\nSt:The Stabbington Brothers, Ron Perlman (only the speaking one; the\xa0one without the eye-patch)<br/>\nVlad:Vladamir, Richard Kiel<br/>\nShorty:Shorty Thug, Paul F. Tompkins<br/>\nYoung R:Young Rapunzel, Delaney Rose Stein<br/>\nCapt:Captain of the Guard, M. C. Gainey</p>\n<p>Other voices:<br/>\nGuard #1/Thug #1 (voice): Nathan Greno<br/>\nGuard #2/Thug #2 (voice): Byron Howard<br/>\nGuard #3 (voice): Tim Mertens<br/>\nAdditional Voices:<br/>\nMichael Bell, Bob Bergen, Susan Blakeslee, June Christopher, Roy\xa0Conli, David Cowgill, Terri Douglas, Chad Einbinder,\xa0Pat Fraley, Eddie Frierson, Jackie Gonneau, Nicholas Guest,\xa0Bridget Hoffman, Daniel Kaz Anne Lockhart, Scott Menville,\xa0Mona Marshall, Laraine Newman, Paul Pape, Lynwood Robin
# ...

# %%
splitting = tangled_string.split("BEGIN")

# %%
len(splitting)
# Out:
# 2

# %%
rough_script = splitting[1]

# %%
new_split = rough_script.split("THE END")

# %%
script = new_split[0]

# %%
script
# Out:
# '—<br/>\nF: This is the story of how I died.<br/>\nDon’t worry, this is actually a very fun story and the truth is, it\xa0isn’t even mine.<br/>\nThis is the story of a girl named Rapunzel and it starts with the\xa0sun.</p>\n<p>Now, once upon a time, a single drop of sunlight fell from the\xa0heavens and from this small drop of sun, grew a magic, golden flower. It\xa0had the\xa0ability to heal the sick and injured.<br/>\nOh, you see that old woman over there? You might want to remember<br/>\nher. She’s kind of important.</p>\n<p>Well, centuries passed, and a hop skip and a boat ride away there\xa0grew a kingdom. The kingdom was ruled by a beloved King and Queen.<br/>\nAnd the Queen, (well,) she was about to have a baby. She got sick.\xa0Really, sick.<br/>\nShe was running out of time, and that’s when people usually start\xa0to look for a miracle. Or in this case, a magic golden flower.</p>\n<p>Ah, I told you she’d be important. You see, instead of sharing the\xa0sun’s gift, this woman
# ...

# %%
script = script.replace('\xa0', ' ')

# %%
script = script.replace('&amp', '')

# %%
len(re.findall(r"<br/>\n+", script))
# Out:
# 1111

# %%
len(re.findall(r"</p>\n+", script))
# Out:
# 24

# %%
len(re.findall(r"\n\n))

# %%
len(re.findall(r"\n\n", script))
# Out:
# 4

# %%
1111 + 24 + 4 # checks out
# Out:
# 1135

# %%
script = re.sub(r"\n", '', script)

# %%
action = re.findall(r"\[[^\]]*\]", script) #was 287

# %%
len(action)
# Out:
# 297

# %%
for bracket in action:
    print(bracket)
# Out:
# [gasps at cut hair]
# [Pascal flees window to hide]
# [Pascal sniggers. R finds it]
# [Pascal frowns]
# [Pascal motions to go outside]
# [Pascal sticks out tongue]
# [leaves window]
# [paints lights]
# [back to window]
# [St lower F to steal crown. A guard sneezes]
# [realizes there has been intruder]
# [distant]
# [R gasps]
# [Pascal straightens up]
# [distant]
# [pulls up G]
# [setup]
# [speedily]
# [G brushes hair as quickly as possible]
# [Pascal urges R]
# [Lights out]
# [kisses R’s forehead]
# [Boxed in]
# [chase]
# [Maximus neighs, the other brown horses neigh in reply. F being chased]
# [chase, Capt knocked off, F rides on Maximus]
# [Maximus comes to adrupt halt, grunts angrily]
# [Maximus stares at satchel only, to snatch satchel]
# [Maximus to snatch satchel]
# [chase. F gets hold of satchel]
# [branch breaks, both fall]
# [Maximus neighs in horror]
# [Maximus searches for F, F hides ; discovers tower, Maximus neighs in distance, climbs it]
# [enters tower, pants.]
# ...

# %%
script = re.sub(r"\[[^\]]*\]", '', script)

# %%
script_2 = re.findall(r"<br/>\n[A-Z][a-z]*:", script)

# %%
len(script_2) #number of lines
# Out:
# 567

# %%
script_3 = re.findall(r"[A-Z][a-z ]*:", script)

# %%
len(script_3) #587 w/o space
# Out:
# 587

# %%
script_4 = re.findall(r"[A-Z][a-z]*:", script)

# %%
len(script_4)
# Out:
# 585

# %%
set(script_4) - set(script_3)
#try replacing all newline chars with empty string, then use > before the word to capture all new lines?
# Out:
# {'St:', 'Vlad:', 'Thugs:', 'Guard:', 'F:', 'Attila:', 'G:', 'Girl:', 'Big:', 'Guards:', 'All:', 'R:', 'Shorty:', 'Thug:', 'Greno:', 'Citizen:', 'Chorus:', 'Hook:', 'Capt:'}

# %%
sorted(list(set(script_3))) #not good....
# Out:
# ['All:', 'Attila:', 'Big:', 'Call it what you will:', 'Capt:', 'Chorus:', 'Citizen:', 'F:', 'G:', 'Girl:', 'Greno:', 'Guard:', 'Guards:', 'Hook:', 'I distinctly remember:', 'R:', 'Shorty:', 'St:', 'Thug:', 'Thugs:', 'Vlad:']

# %%
sorted(list(set(script_4)))
# Out:
# ['All:', 'Attila:', 'Big:', 'Capt:', 'Chorus:', 'Citizen:', 'F:', 'G:', 'Girl:', 'Greno:', 'Guard:', 'Guards:', 'Hook:', 'R:', 'Shorty:', 'St:', 'Thug:', 'Thugs:', 'Vlad:']

# %%
len(set(script_4))
# Out:
# 19

# %%
two_word_char = re.findall(r">(([A-Z][a-z]* )?[A-Z][a-z]*:)", script)

# %%
len(two_word_char)
# Out:
# 581

# %%
two_word_char[:20]
# Out:
# [('F:', ''), ('G:', ''), ('F:', ''), ('Guards:', ''), ('F:', ''), ('G:', ''), ('F:', ''), ('Young R:', 'Young '), ('F:', ''), ('Young R:', 'Young '), ('G:', ''), ('Young R:', 'Young '), ('F:', ''), ('R:', ''), ('R:', ''), ('R:', ''), ('R:', ''), ('R:', ''), ('F:', ''), ('St:', '')]

# %%
two_word_char_full = [x[0] for x in two_word_char]

# %%
sorted(list(set(two_word_char_full)))
# Out:
# ['>All:', '>Attila:', '>Big:', '>Capt:', '>Citizen:', '>F:', '>G:', '>Girl:', '>Greno:', '>Guard:', '>Guards:', '>Hook:', '>R:', '>Shorty:', '>St:', '>Thug Chorus:', '>Thug:', '>Thugs:', '>Vlad:', '>Young R:']

# %%
script_test = re.sub(r"(<br/>|<p>|</p>)(([A-Z][a-z]* )?[A-Z][a-z]*:)", r"_NEWLINE_\2_START", script)

# %%
script_2
# Out:
# '—_NEWLINE_<br/ This is the story of how I died.<br/>Don’t worry, this is actually a very fun story and the truth is, it isn’t even mine.<br/>This is the story of a girl named Rapunzel and it starts with the sun.</p><p>Now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. It had the ability to heal the sick and injured.<br/>Oh, you see that old woman over there? You might want to remember<br/>her. She’s kind of important.</p><p>Well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. The kingdom was ruled by a beloved King and Queen.<br/>And the Queen, (well,) she was about to have a baby. She got sick. Really, sick.<br/>She was running out of time, and that’s when people usually start to look for a miracle. Or in this case, a magic golden flower.</p><p>Ah, I told you she’d be important. You see, instead of sharing the sun’s gift, this woman, Mother Gothel, hoarded its healing powe
# ...

# %%
script_test
# Out:
# '—_NEWLINE_F:_START This is the story of how I died.<br/>Don’t worry, this is actually a very fun story and the truth is, it isn’t even mine.<br/>This is the story of a girl named Rapunzel and it starts with the sun.</p><p>Now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. It had the ability to heal the sick and injured.<br/>Oh, you see that old woman over there? You might want to remember<br/>her. She’s kind of important.</p><p>Well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. The kingdom was ruled by a beloved King and Queen.<br/>And the Queen, (well,) she was about to have a baby. She got sick. Really, sick.<br/>She was running out of time, and that’s when people usually start to look for a miracle. Or in this case, a magic golden flower.</p><p>Ah, I told you she’d be important. You see, instead of sharing the sun’s gift, this woman, Mother Gothel, hoarded its healing 
# ...

# %%
script_only = script_test.replace("<br/>", ' ').replace("<p>", ' ').replace('</p>', ' ')

# %%
script_only
# Out:
# '—_NEWLINE_F:_START This is the story of how I died. Don’t worry, this is actually a very fun story and the truth is, it isn’t even mine. This is the story of a girl named Rapunzel and it starts with the sun.  Now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. It had the ability to heal the sick and injured. Oh, you see that old woman over there? You might want to remember her. She’s kind of important.  Well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. The kingdom was ruled by a beloved King and Queen. And the Queen, (well,) she was about to have a baby. She got sick. Really, sick. She was running out of time, and that’s when people usually start to look for a miracle. Or in this case, a magic golden flower.  Ah, I told you she’d be important. You see, instead of sharing the sun’s gift, this woman, Mother Gothel, hoarded its healing power and used it to keep herself young
# ...

# %%
script_lines = script_only.split('_NEWLINE_')

# %%
script_lines = script_lines[1:]

# %%
script_lines[:10]
# Out:
# ['F:_START This is the story of how I died. Don’t worry, this is actually a very fun story and the truth is, it isn’t even mine. This is the story of a girl named Rapunzel and it starts with the sun.  Now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. It had the ability to heal the sick and injured. Oh, you see that old woman over there? You might want to remember her. She’s kind of important.  Well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. The kingdom was ruled by a beloved King and Queen. And the Queen, (well,) she was about to have a baby. She got sick. Really, sick. She was running out of time, and that’s when people usually start to look for a miracle. Or in this case, a magic golden flower.  Ah, I told you she’d be important. You see, instead of sharing the sun’s gift, this woman, Mother Gothel, hoarded its healing power and used it to keep herself young for hund
# ...

# %%
script_line_tuple = []
for line in script_lines:
    script_line_tuple.append(tuple(line.split(":_START")))

# %%
script_line_tuple[:10]
# Out:
# [('F', ' This is the story of how I died. Don’t worry, this is actually a very fun story and the truth is, it isn’t even mine. This is the story of a girl named Rapunzel and it starts with the sun.  Now, once upon a time, a single drop of sunlight fell from the heavens and from this small drop of sun, grew a magic, golden flower. It had the ability to heal the sick and injured. Oh, you see that old woman over there? You might want to remember her. She’s kind of important.  Well, centuries passed, and a hop skip and a boat ride away there grew a kingdom. The kingdom was ruled by a beloved King and Queen. And the Queen, (well,) she was about to have a baby. She got sick. Really, sick. She was running out of time, and that’s when people usually start to look for a miracle. Or in this case, a magic golden flower.  Ah, I told you she’d be important. You see, instead of sharing the sun’s gift, this woman, Mother Gothel, hoarded its healing power and used it to keep herself young for hundre
# ...

# %%
#finally, let's strip any left over white space

# %%
import pandas as pd
import numpy as np

# %%
tangled = pd.DataFrame(script_line_tuple, columns=["Speaker", "Text"])

# %%
tangled.head()
# Out:
#   Speaker                                               Text
# 0       F   This is the story of how I died. Don’t worry,...
# 1       G   Flower, gleam and glow Let your power shine M...
# 2       F   All right, you get the gist. She sings to it,...
# 3  Guards                                   We’ve found it!
# 4       F   The magic of the golden flower healed the que...

# %% [markdown]
# ### Awesome!
# Just a couple more things to do: Replace abbreviations with full names of characters, lower/strip all the text, and add labels found in the other Disney Data.
