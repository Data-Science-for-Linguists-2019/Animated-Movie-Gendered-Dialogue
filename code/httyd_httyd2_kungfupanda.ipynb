# %% [markdown]
# # More Dreamworks Films:
# The last file was getting kind of long, so I'm restricting each file to 3 movies max. In this file, we will look at:
# * How to Train Your Dragon
# * How to Train Your Dragon 2
# * Kung Fu Panda

# %% [markdown]
# ## How To Train Your Dragon

# %%
import numpy as np
import pandas as pd
import re

# %%
import pickle

# %%
#importing the file
httyd = open(r'C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\imsdb_raw_nov_2015\Animation\howtotrainyourdragon.txt')
httyd_script = httyd.read()
httyd.close()

# %%
httyd_script[:1000]
# Out:
# "                            HOW TO TRAIN YOUR DRAGON\n\n                                   Written by\n\n                         Dean DeBlois & Chris Sanders\n\n                                                           Final Draft\n\n                                                     February 13, 2010\n\n                         FADE IN:\n\n          EXT. NORTH SEA/VILLAGE - NIGHT\n\n          We skim above a dark, wild ocean. The camera turns toward a\n\n          lone island, Berk. It is a gigantic shard of rock jutting\n\n          straight out of the water.\n\n          HICCUP (V.O.)\n\n          This, is Berk. It's twelve days\n\n          North of hopeless, and a few\n\n          degrees South of freezing to death.\n\n          It's located solidly on the\n\n          meridian of misery.\n\n          The camera drifts over rolling hills to reveal a small\n\n          village nestled on an outcropping of sea mounts.\n\n          HICCUP (V.O.) (CONT'D)\n\n          My villag
# ...

# %%
#Take away the beginning jargon
print(httyd_script[:298])
httyd_script = httyd_script[298:]
print('\n')
print(httyd_script[:100])
# Out:
#                             HOW TO TRAIN YOUR DRAGON
#
#                                    Written by
#
#                          Dean DeBlois & Chris Sanders
#
#                                                            Final Draft
#
#                                                      February 13, 2010
#
#
#
#
#                          FADE IN:
#
#           EXT. NORTH SEA/VILLAGE - NIGHT
#
#           We skim abo

# %%
#Analyzing Line spacing
white_space = re.findall(" {3,}", httyd_script)
print(len(white_space))
len_w_s = [len(x) for x in white_space]
print(len_w_s[:50])
print(set(len_w_s))
# Out:
# 4098
# [28, 35, 25, 59, 53, 25, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 25, 10, 10, 10, 10, 10, 25, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# {35, 10, 53, 25, 59, 28}

# %%
len_w_s.count(28) #only at beginning
# Out:
# 1

# %%
len_w_s.count(35) #only at beginning
# Out:
# 1

# %%
len_w_s.count(59) #only at beginning
# Out:
# 1

# %%
len_w_s.count(53) #only at beginning
# Out:
# 1

# %%
len_w_s.count(25) #throughout script
# Out:
# 669

# %%
len_w_s.count(10) #throughout script
# Out:
# 3425

# %%
httyd_script[:1600]
# Out:
# "\n\n                         FADE IN:\n\n          EXT. NORTH SEA/VILLAGE - NIGHT\n\n          We skim above a dark, wild ocean. The camera turns toward a\n\n          lone island, Berk. It is a gigantic shard of rock jutting\n\n          straight out of the water.\n\n          HICCUP (V.O.)\n\n          This, is Berk. It's twelve days\n\n          North of hopeless, and a few\n\n          degrees South of freezing to death.\n\n          It's located solidly on the\n\n          meridian of misery.\n\n          The camera drifts over rolling hills to reveal a small\n\n          village nestled on an outcropping of sea mounts.\n\n          HICCUP (V.O.) (CONT'D)\n\n          My village. In a word, sturdy.\n\n          And it's been here for seven\n\n          generations, but every single\n\n          building is new.\n\n          The camera drifts closer, circling.\n\n          HICCUP (V.O.) (CONT'D)\n\n          We have fishing, hunting, and a\n\n          charming view of the sunse
# ...

# %%
httyd_script[1500:2000]
# Out:
# '  HICCUP\n\n          ...dragons.\n\n          EXT. STOICK\'S HOUSE\n\n          He reopens the sizzling door, as leaps off of the front\n\n          porch. He weaves through the erupting mayhem as Vikings pour\n\n          out of the buildings, ready for a fight.\n\n          "Dragon" DeBlois/Sanders Final Draft (Rev.19) 02-13-2010 2.\n\n          More dragons swarm in, setting rooftops alight and hauling\n\n          off sheep.\n\n          HICCUP (V.O.)\n\n          Most people would leave. Not us.\n\n          We\''

# %%
all_caps = re.findall(r" {10}(\b[A-Z]['A-Z ]{2,}[0-9]?)+", httyd_script)

# %%
print(len(all_caps))
print(len(set(all_caps)))
print(set(all_caps))
# Out:
# 983
# 143
# ...

# %%
all_caps2 = re.findall(r" {25}(\b[A-Z]['A-Z ]{2,}[0-9]?)+", httyd_script)

# %%
print(len(all_caps2))
print(len(set(all_caps2)))
print(set(all_caps2))
# Out:
# 540
# 41
# {'ASTRID', 'VIKINGS', 'TERMS', 'TEENS', 'HICCUP STOICK', 'REPAIR VIKINGS', 'GOBBER', 'UNDERWATER', 'HICCUP', 'FISHLEGS ', 'SEE YOU', 'HOARK', 'ON STOICK', 'ON TOOTHLESS', 'STOICK ', 'BURNTHAIR', 'SNOTLOUT', 'HICCUP ', 'WOULD', 'CUT TO', 'FISHLEGS', 'SPITELOUT', 'AT HICCUP', 'A STICK', 'CLOSE ON', 'RUFFNUT', 'STOICK HICCUP', 'VIKING ', 'A BEAT', 'OTHER', 'TUFFNUT RUFFNUT', 'TUFFNUT', 'STOICK', 'NADDERS', 'DISSOLVE TO', 'CATAPULT OPERATOR', 'SHEET', 'GOBBER ', 'ON HICCUP', 'FADE IN', 'VIKING'}

# %%
diff = set(all_caps) - set(all_caps2)

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
diff
# Out:
# {'ON DECK ', 'A N', 'BUZZING ', 'SLAM', 'ON SNOTLOUT AND TUFFNUT', 'ON AN OPEN NOTEBOOK', 'GASPS ', 'THE RED DEATH ', 'A RUMBLE ', 'AAAAAGGGGHHHHH', 'ON STOICK ', 'ON FISHLEGS AND HICCUP ', 'A Z', 'ON THE GROUND', 'MATCH CUT TO', 'ON A DOUBLE', 'KABOOM', 'CHEERS ', 'NOW', 'AN EPIC FOG BANK', 'EXT', 'TUFFNUT ', 'CRUNCH', 'BLASTING ', 'SNOTLOUT ', 'I SAID STOP THE FIGHT', 'ON THE PLAIN BELOW', 'CLOSE ON ', "ON HICCUP'S HAND", 'KABLAM', 'BACK', 'A NIGHT FURY', 'CAN YOU STOP THAT', 'KERTHUNK', 'LAUGHTER AND APPLAUSE', 'PAN DOWN ', 'NIGHTMARE ', 'FIRE', 'DEAL', 'THROUGH ', 'BOOMS ', 'ON HICCUP AND ASTRID', 'THROWING PUNCHES ', 'ON HICCUP ', "GRONCKLE'S POV ", 'ISOLATED COVE ', 'INT', 'IN THE STALL', 'HERE', 'VIKING IN CROWD', 'A SLOW', 'BELLOWS ', 'HISSES ', 'GAS FLOWS ', 'MUNGE BUCKET', 'OPENING ', 'IN MID', 'HOOTING ', 'LARGE NAUTICAL MAP', 'ON SNOTLOUT AND FISHLEGS', 'PHLEGMA THE FIERCE', 'BLAST', 'BAM', 'A G', 'BECOMES ONE OF US', 'YEEAHHH', 'BOOM', 'FADE TO WHITE', 'ON THE BARE FLOOR
# ...

# %%
diff = list(diff)

# %%
diff_counts = 0
for x in diff:
    num = httyd_script.count(x)
    diff_counts += num

# %%
diff_counts
# Out:
# 270

# %%
983-270 #173 lines still unaccounted for
# Out:
# 713

# %%
all_caps3 = re.findall(r" {10}(\b[A-Z]['A-Z ]{2,}[^:]*\n)+", httyd_script)

# %%
len(all_caps3)
# Out:
# 21

# %%
all_caps3
# Out:
# ["EXT. NORTH SEA/VILLAGE - NIGHT\n\n          We skim above a dark, wild ocean. The camera turns toward a\n\n          lone island, Berk. It is a gigantic shard of rock jutting\n\n          straight out of the water.\n\n          HICCUP (V.O.)\n\n          This, is Berk. It's twelve days\n\n          North of hopeless, and a few\n\n          degrees South of freezing to death.\n\n          It's located solidly on the\n\n          meridian of misery.\n\n          The camera drifts over rolling hills to reveal a small\n\n          village nestled on an outcropping of sea mounts.\n\n          HICCUP (V.O.) (CONT'D)\n\n          My village. In a word, sturdy.\n\n          And it's been here for seven\n\n          generations, but every single\n\n          building is new.\n\n          The camera drifts closer, circling.\n\n          HICCUP (V.O.) (CONT'D)\n\n          We have fishing, hunting, and a\n\n          charming view of the sunsets. The\n\n          only problems are the pests. 
# ...

# %%
#I think for this script, I'll have to separate by newlines, then filter out by character name

# %% [markdown]
# ## How to Train Your Dragon 2

# %%
#importing the file
httyd2 = open(r'C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\imsdb_raw_nov_2015\Animation\howtotrainyourdragon2.txt')
httyd2_script = httyd2.read()
httyd2.close()

# %%
httyd2_script[:500]
# Out:
# '                     HOW TO TRAIN YOUR DRAGON 2\n\n                             Written by\n\n                            Dean DeBlois\n\n                      Inspired by the novels by\n\n                           Cressida Cowell\n\n                                                   Final Draft\n\n                                                 May 5th, 2014\n\n           EXT. OPEN SEA - DAY\n\n           Hiccup and Toothless BLUR PAST, leaving a wake that leads...                         \n\n           EXT. B'

# %%
#Analyzing Line spacing
white_space = re.findall(" {3,}", httyd2_script)
print(len(white_space))
len_w_s = [len(x) for x in white_space]
print(len_w_s[:50])
print(set(len_w_s))
# Out:
# 3787
# [21, 29, 28, 22, 27, 51, 49, 11, 11, 25, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 11, 11, 10, 10, 10, 10, 10, 10, 10, 11, 26, 11, 11, 26, 11]
# {10, 11, 49, 51, 21, 22, 25, 26, 27, 28, 29}

# %%
httyd2_script[:351]
# Out:
# '                     HOW TO TRAIN YOUR DRAGON 2\n\n                             Written by\n\n                            Dean DeBlois\n\n                      Inspired by the novels by\n\n                           Cressida Cowell\n\n                                                   Final Draft\n\n                                                 May 5th, 2014'

# %%
httyd2_script = httyd2_script[351:]

# %%
httyd2_script[:100]
# Out:
# '\n\n           EXT. OPEN SEA - DAY\n\n           Hiccup and Toothless BLUR PAST, leaving a wake that lea'

# %%
#Analyzing Line spacing
white_space = re.findall(" {3,}", httyd2_script)
print(len(white_space))
len_w_s = [len(x) for x in white_space]
print(len_w_s[:50])
print(set(len_w_s))
# Out:
# 3780
# [11, 11, 25, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 10, 10, 10, 10, 11, 11, 10, 10, 10, 10, 10, 10, 10, 11, 26, 11, 11, 26, 11, 10, 10, 26, 11, 10, 10, 26]
# {26, 25, 10, 11}

# %%
httyd2_script[:2500]
# Out:
# "\n\n           EXT. OPEN SEA - DAY\n\n           Hiccup and Toothless BLUR PAST, leaving a wake that leads...                         \n\n           EXT. BERK - DAY\n\n           (Sequence 0200 - New Berk)\n\n           To the island village of Berk, festively adorned with flags\n\n           and banners. Major new additions alter its familiar skyline.\n\n           HICCUP (V.O.)\n\n           This... is Berk. The best kept\n\n           secret this side of, well,\n\n           anywhere. Granted, it may not look\n\n           like much, but this wet heap of\n\n           rock packs more than a few\n\n           surprises.\n\n          ON A CLUSTER OF SHEEP, hiding nervously between buildings as\n\n          shadows of passing dragons race by. The group moves as one,\n\n          receding into a shadowy alley, pushing one sheep out into the\n\n          light. It's suddenly snatched and carried into the air!\n\n           HICCUP (V.O.)\n\n           Life here is amazing, just not for
# ...

# %%
len_w_s.count(25)
# Out:
# 9

# %%
#for the most part
#26 before a character name
#10 between scene headings/after lines
#11 between lines
#but again, hiccups at the beginning are messed up
