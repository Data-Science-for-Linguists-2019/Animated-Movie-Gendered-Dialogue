# %% [markdown]
# ## Total Token/Type Stats per Character
# Because lines are so short, and therefore not necessarily informative in terms of ttr and k-band, here I will group together a characters total token/type count (in terms of dialogue only)

# %%
#importing my pickle file
import pandas as pd

# %%
movie_df = pd.read_pickle(r"C:/Users/cassi/Desktop/Data_Science/Animated-Movie-Gendered-Dialogue/private/all_movies_toktype.pkl")

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14096 entries, 0 to 14095
# Data columns (total 14 columns):
# Disney_Period       14096 non-null object
# Gender              14096 non-null object
# Movie               14096 non-null object
# Role                14096 non-null object
# Song                14096 non-null object
# Speaker             14096 non-null object
# Speaker_Status      14096 non-null object
# Text                14096 non-null object
# UTTERANCE_NUMBER    14096 non-null int64
# Year                14096 non-null int64
# Tokens              14096 non-null object
# Types               14096 non-null object
# Token_Count         14096 non-null int64
# Type_Count          14096 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 991.2+ KB

# %%
movie_df = movie_df[movie_df.Song == 'D']

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13450 entries, 0 to 14095
# Data columns (total 14 columns):
# Disney_Period       13450 non-null object
# Gender              13450 non-null object
# Movie               13450 non-null object
# Role                13450 non-null object
# Song                13450 non-null object
# Speaker             13450 non-null object
# Speaker_Status      13450 non-null object
# Text                13450 non-null object
# UTTERANCE_NUMBER    13450 non-null int64
# Year                13450 non-null int64
# Tokens              13450 non-null object
# Types               13450 non-null object
# Token_Count         13450 non-null int64
# Type_Count          13450 non-null int64
# dtypes: int64(4), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# First, let's attempt this on a small scale

# %%
movie_sample = movie_df.sample(500)

# %%
movie_sample.Movie.unique()
# Out:
# array(['The Croods', 'How to Train Your Dragon 2', 'Antz',
#        'Rise of the Guardians', 'Shrek 3', 'Kung Fu Panda', 'Pocahontas',
#        'Shrek', 'Cinderella', 'Frozen', 'Mulan', 'Aladdin',
#        'How to Train Your Dragon', 'Megamind', 'The Little Mermaid',
#        'The Princess and the Frog', 'Sleeping Beauty', 'Snow White',
#        'Beauty and the Beast', 'Moana', 'Brave', 'Tangled'], dtype=object)

# %%
movie_sample.head()
# Out:
#       Disney_Period Gender                       Movie    Role Song  Speaker  \
# 13281    DREAMWORKS      m                  The Croods     PRO    D      guy
# 13824    DREAMWORKS      m  How to Train Your Dragon 2  HELPER    D   stoick
# 7825     DREAMWORKS      m                        Antz  HELPER    D  formica
# 12202    DREAMWORKS      m       Rise of the Guardians     PRO    D     jack
# 9365     DREAMWORKS      m                     Shrek 3  HELPER    D   donkey
#
#       Speaker_Status                                               Text  \
# 13281          NON-P          belt! emergency idea generator, activate!
# 13824          NON-P                the same way we're getting you out.
# 7825           NON-P  we know what makes an ant colony strong, don't...
# 12202          NON-P                               we gotta help sandy!
# 9365           NON-P                                              ahhh!
#
#        UTTERANCE_NUMBER  Year  \
# 13281               664  2013
# 13824               437  2014
# 7825                404  1998
# 12202               513  2012
# 9365                578  2007
#
#                                                   Tokens  \
# 13281  [belt, !, emergency, idea, generator, ,, activ...
# 13824    [the, same, way, we, 're, getting, you, out, .]
# 7825   [we, know, what, makes, an, ant, colony, stron...
# 12202                      [we, got, ta, help, sandy, !]
# 9365                                           [ahhh, !]
#
#                                                    Types  Token_Count  \
# 13281  {generator, idea, belt, ,, activate, emergency...            8
# 13824    {., same, we, getting, out, way, 're, you, the}            9
# 7825   {an, ?, single, colony, ant, we, strong, can, ...           30
# 12202                      {got, sandy, we, help, ta, !}            6
# 9365                                           {ahhh, !}            2
#
#        Type_Count
# 13281           7
# 13824           9
# 7825           21
# 12202           6
# 9365            2

# %%
for movie in movie_sample.Movie.unique():
    movie_data = movie_sample[movie_sample.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        print('\t'+char)
# Out:
# Movie:The Croods
# 	guy
# 	grug
# 	thunk
# 	belt
# 	ugga
# 	croods
# 	eep
# 	gran
# Movie:How to Train Your Dragon 2
# 	stoick
# 	hiccup
# 	valka
# 	eret
# 	tuffnut
# 	fishlegs
# 	gobber
# 	drago
# Movie:Antz
# 	formica
# 	colonel
# 	weaver
# 	male wasp
# 	foreman
# 	z
# 	bala
# 	barbatus
# 	queen
# 	motivational counsellor
# 	female wasp
# 	worker #2
# Movie:Rise of the Guardians
# 	jack
# 	kids
# 	claude
# 	tooth
# 	sophie
# 	north
# 	bunnymund
# 	pitch
# 	jamie
# 	yeti
# 	bunny
# Movie:Shrek 3
# 	donkey
# 	shrek
# 	wolf
# 	fiona
# 	artie
# 	prince charming
# 	puss
# 	jocks
# 	captain hook
# 	merlin
# 	gingerbread man
# 	king harold
# 	xavier
# 	nanny dwarf
# 	snow white
# 	pinocchio
# Movie:Kung Fu Panda
# 	tai lung
# 	shifu
# 	po
# 	crane
# 	commander
# 	oogway
# 	mantis
# 	po's dad
# 	monkey
# 	narrator
# 	tigress
# Movie:Pocahontas
# 	ratcliffe
# 	lon
# 	john smith
# 	powhatan
# 	grandmother willow
# 	thomas
# 	pocahontas
# 	wiggins
# 	ben
# Movie:Shrek
# 	fiona
# 	priest
# 	robin hood
# 	shrek
# 	head guard
# 	guard
# 	farquaad
# 	donkey
# 	gingerbread man
# Movie:Cinderella
# 	royal postman
# 	stepmother
# 	drizella
# 	jaq
# 	cinderella
# 	fairy godmother
# 	king
# 	birds chirping
# 	grand duke
# Movie:Frozen
# 	kristoff
# 	anna
# 	hans
# 	gerda
# 	olaf
# 	duke
# 	kai
# 	voice of woman
# 	oaken
# 	elsa
# Movie:Mulan
# 	hun archer
# 	mulan
# 	mushu
# 	fa li
# 	chi fu
# 	emperor
# 	shang
# 	granny fa
# 	matchmaker
# 	fa zhou
# Movie:Aladdin
# 	sultan
# 	abu
# 	aladdin
# 	jasmine
# 	genie
# 	iago
# 	jafar
# Movie:How to Train Your Dragon
# 	hiccup
# 	astrid
# 	fishlegs
# 	stoick
# 	tuffnut
# 	gobber
# 	snotlout
# Movie:Megamind
# 	megamind
# 	roxanne ritchie
# 	bernard
# 	metro man
# 	minion
# 	hal
# Movie:The Little Mermaid
# 	sebastian
# 	eric
# 	triton
# 	flounder
# 	ariel
# 	scuttle
# 	seahorse
# 	sailor 1
# 	grimsby
# Movie:The Princess and the Frog
# 	tiana
# 	prince naveen
# 	lawrence
# 	mr. fenner 2
# 	louis
# 	charlotte
# 	james
# 	ray
# 	mama odie
# 	mr. fenner
# 	hunter
# Movie:Sleeping Beauty
# 	merryweather
# 	hubert
# 	queen
# 	flora
# 	fauna
# 	briar rose
# 	maleficent
# 	stefan
# Movie:Snow White
# 	snow white
# 	sleepy
# 	doc
# 	grumpy
# 	bashful
# Movie:Beauty and the Beast
# 	gaston
# 	maurice
# 	belle
# 	cogsworth
# 	d'arque
# 	lumiere
# 	beast
# 	old man
# 	lefou
# 	crony 1
# Movie:Moana
# 	moana
# 	tui
# 	tamatoa
# 	maui
# 	male villager 7
# 	female villager 1
# Movie:Brave
# 	queen elinor
# 	merida
# 	king fergus
# 	lord macintosh
# 	the witch
# 	cook
# Movie:Tangled
# 	flynn
# 	rapunzel
# 	capt
# 	stabbington brothers
# 	young rapunzel
# 	gothel
# 	hook

# %%
for movie in movie_sample.Movie.unique():
    movie_data = movie_sample[movie_sample.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        all_toks = movie_data[movie_data.Speaker == char]['Tokens']
        all_toks_count = movie_data[movie_data.Speaker == char]['Token_Count']
        print('\t'+char)
        print(all_toks.sum())
        print(len(all_toks.sum())) #this returns a full list of all their lines! Sweet!
        print("DOUBLE CHECK:", all_toks_count.sum())
        print("TYPES:")
        print(len(set(all_toks.sum())))
        print(set(all_toks.sum()))
        #print(movie_data[movie_data.Speaker == char]['Types'].sum())
        #print(movie_data[movie_data.Speaker == char]['Type_Count'].sum())
        print(all_toks.map(len))
        print(all_toks)
# Out:
# Movie:The Croods
# 	guy
# ['belt', '!', 'emergency', 'idea', 'generator', ',', 'activate', '!', 'there', 'it', 'is', '.', 'the', 'sun', '.', 'we', 'can', 'do', 'it', '!', 'we', 'can', 'ride', 'it', 'to', 'tomorrow', '.', 'i', "'ll", 'take', 'that', 'chance', '.', 'a', 'place', 'not', 'like', 'today', ',', 'or', 'yesterday', ',', 'a', 'place', 'where', 'things', 'are', 'better', '.', 'you', 'know', ',', 'just', 'making', 'something', 'up', '...', 'to', 'make', 'you', 'laugh', '.']
# 62
# DOUBLE CHECK: 62
# TYPES:
# 44
# {'we', 'i', 'belt', 'today', 'activate', 'you', 'ride', 'emergency', 'can', '!', 'or', 'like', 'up', '.', 'not', '...', 'generator', 'tomorrow', 'it', ',', 'chance', 'the', 'take', 'is', 'sun', 'to', 'yesterday', 'know', 'just', 'do', 'better', 'are', 'a', 'something', 'that', 'make', "'ll", 'where', 'laugh', 'making', 'idea', 'things', 'there', 'place'}
# 13281     8
# 13302    19
# 13314     6
# 13077    16
# 13143    13
# Name: Tokens, dtype: int64
# 13281    [belt, !, emergency, idea, generator, ,, activ...
# 13302    [there, it, is, ., the, sun, ., we, can, do, i...
# 13314                      [i, 'll, take, that, chance, .]
# 13077    [a, place, not, like, today, ,, or, yesterday,...
# 13143    [you, know, ,, just, making, something, up, .....
# Name: Tokens, dtype: object
# 	grug
# ['no', '.', 'fine', '.', 'you', "'re", 'staying', 'with', 'us', 'till', 'we', 'find', 'a', 'cave', '.', 'i', 'call', 'it', 'a', '``', 'rug', '.', "''", 'rhymes', 'with', 'grug', '.', 'and', 'this', 'one', '.', 'i', 'call', 'it', 'a', '``', 'ride', '.', "''", 'rhymes', 'with', 'grug', '.', 'is', 'she', 'still', 'out', 'there', '?', 'is', "n't", 'this', 'fun', ',', 'eep', '?']
# 56
# DOUBLE CHECK: 56
# TYPES:
# 35
# {'?', 'fun', 'we', 'staying', 'i', 'one', 'eep', 'you', 'ride', "''", 'till', 'us', 'with', '.', 'it', ',', "n't", 'she', 'cave', 'is', 'rug', 'fine', '``', 'no', 'still', 'a', 'rhymes', "'re", 'find', 'grug', 'and', 'call', 'out', 'there', 'this'}
# 12977     2
# 12942    13
# 13217    28
# 12683     6
# 12900     7
# Name: Tokens, dtype: int64
# 12977                                              [no, .]
# 12942    [fine, ., you, 're, staying, with, us, till, w...
# 13217    [i, call, it, a, ``, rug, ., '', rhymes, with,...
# 12683                      [is, she, still, out, there, ?]
# 12900                      [is, n't, this, fun, ,, eep, ?]
# Name: Tokens, dtype: object
# 	thunk
# ['where', 'did', 'she', 'fly', '?', 'someone', 'get', 'a', 'stick', '!', 'get', 'her', 'off', '!', 'i', 'do', "n't", 'think', 'so', '.', 'yay', ',', 'breakfast', '!', '!', '!', '!', 'here', 'boy', ',', 'catch', '!', 'it', 'likes', 'me', '!', 'hey', '!', 'it', "'s", 'biting', 'me', '!', '!']
# 44
# DOUBLE CHECK: 44
# TYPES:
# 30
# {'?', 'i', 'hey', 'think', 'stick', 'catch', '!', 'yay', '.', 'likes', 'off', 'boy', 'so', 'it', ',', "'s", 'biting', "n't", 'breakfast', 'she', 'do', 'did', 'a', 'her', 'here', 'where', 'fly', 'someone', 'get', 'me'}
# 13072     5
# 13025     9
# 12970     6
# 12648     7
# 13169     5
# 12907    12
# Name: Tokens, dtype: int64
# 13072                            [where, did, she, fly, ?]
# 13025        [someone, get, a, stick, !, get, her, off, !]
# 12970                           [i, do, n't, think, so, .]
# 12648                      [yay, ,, breakfast, !, !, !, !]
# 13169                             [here, boy, ,, catch, !]
# 12907    [it, likes, me, !, hey, !, it, 's, biting, me,...
# Name: Tokens, dtype: object
# 	belt
# ['da', 'da', 'daaaaa', '.']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 3
# {'da', 'daaaaa', '.'}
# 12790    4
# Name: Tokens, dtype: int64
# 12790    [da, da, daaaaa, .]
# Name: Tokens, dtype: object
# 	ugga
# ['aww', ',', 'what', 'a', 'cute', 'little', 'guy', '.']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'aww', '.', 'a', ',', 'guy', 'little', 'cute', 'what'}
# 12904    8
# Name: Tokens, dtype: int64
# 12904    [aww, ,, what, a, cute, little, guy, .]
# Name: Tokens, dtype: object
# 	croods
# []
# 0
# DOUBLE CHECK: 0
# TYPES:
# 0
# set()
# 12708    0
# Name: Tokens, dtype: int64
# 12708    []
# Name: Tokens, dtype: object
# 	eep
# ['wait', '.', 'wait', '!', 'really', '?']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 5
# {'wait', '?', '.', 'really', '!'}
# 12814    4
# 13032    2
# Name: Tokens, dtype: int64
# 12814    [wait, ., wait, !]
# 13032           [really, ?]
# Name: Tokens, dtype: object
# 	gran
# ['well', ',', 'there', 'goes', 'our', 'chance', 'for', 'survival', '.']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 9
# {'for', '.', 'well', 'goes', 'our', ',', 'there', 'survival', 'chance'}
# 13099    9
# Name: Tokens, dtype: int64
# 13099    [well, ,, there, goes, our, chance, for, survi...
# Name: Tokens, dtype: object
# Movie:How to Train Your Dragon 2
# 	stoick
# ['the', 'same', 'way', 'we', "'re", 'getting', 'you', 'out', '.', 'any', 'sign', 'of', 'him', '?', 'what', '...', '?', 'thank', 'odin', 'you', 'did', "n't", 'listen', 'to', 'me', ',', 'son', '.', 'we', 'never', 'would', 'have', 'found', 'each', 'other', '.', 'this', 'way', '!', 'quickly', '!']
# 41
# DOUBLE CHECK: 41
# TYPES:
# 34
# {'?', 'we', 'getting', 'you', '!', 'same', '.', '...', 'listen', 'would', 'quickly', ',', 'thank', "n't", 'sign', 'the', 'what', 'to', 'other', 'did', 'each', 'of', "'re", 'odin', 'found', 'this', 'him', 'me', 'out', 'way', 'never', 'have', 'any', 'son'}
# 13824     9
# 13518     5
# 13958     3
# 13893    19
# 13577     5
# Name: Tokens, dtype: int64
# 13824      [the, same, way, we, 're, getting, you, out, .]
# 13518                              [any, sign, of, him, ?]
# 13958                                       [what, ..., ?]
# 13893    [thank, odin, you, did, n't, listen, to, me, ,...
# 13577                           [this, way, !, quickly, !]
# Name: Tokens, dtype: object
# 	hiccup
# ['toothless', '!', 'no', '!', 'toothless', '!', 'do', "n't", '!', 'could', 'we', 'just', 'talk', 'in', 'private', 'for', '--', 'that', 'really', 'came', 'out', 'of', 'nowhere', '.', 'because', 'i', "'m", 'going', 'to', 'change', 'his', 'mind', 'about', 'dragons', '.', 'dragons', 'used', 'to', 'be', 'a', 'bit', 'of', 'a', 'problem', 'here', '.', 'but', 'that', 'was', 'five', 'years', 'ago', '.', 'now', 'they', "'ve", 'all', 'moved', 'in', '.', 'and', ',', 'really', ',', 'why', 'would', "n't", 'they', '?', 'it', "'s", 'all', 'over', 'now', '.', 'what', '?', 'no', '.', 'i', 'do', "n't", 'know', '.', 'it', "'s", 'a', 'bit', 'much', 'to', 'get', 'my', 'head', 'around', ',', 'to', 'be', 'frank', '.', 'it', "'s", 'not', 'every', 'day', 'you', 'find', 'out', 'your', 'mother', 'is', 'some', 'kind', 'of', 'crazy', ',', 'feral', ',', 'vigilante', 'dragon', 'lady', '.', 'we', 'may', 'be', 'small', 'in', 'numbers', ',', 'but', 'we', 'stand', 'for', 'something', 'bigger', 'than', 'anything', 'the', 'world', 'can', 'pit', 'against', 'us', '.', "y'know", ',', 'skullcrusher', "'s", 'gon', 'na', 'need', 'somebody', 'to', 'look', 'after', 'him', 'now', '.', 'okay', '.', 'no', 'sudden', 'moves', '.', 'unbelievable', '.']
# 165
# DOUBLE CHECK: 165
# TYPES:
# 104
# {'day', 'private', "y'know", 'toothless', 'ago', 'much', 'us', 'every', '.', 'because', 'why', "n't", 'but', 'is', 'five', 'talk', "'ve", 'of', 'here', 'that', 'lady', 'problem', 'find', 'about', 'crazy', 'after', 'his', 'was', 'mother', 'dragons', 'okay', 'skullcrusher', 'your', 'used', 'came', "'m", 'need', 'you', 'around', 'than', 'would', "'s", 'nowhere', 'to', 'know', 'just', 'be', 'for', 'no', 'mind', 'over', 'dragon', 'really', 'pit', 'now', 'some', 'gon', 'vigilante', 'get', 'against', 'bigger', 'may', 'they', '?', 'bit', 'i', '!', 'years', 'can', 'not', 'anything', 'could', 'frank', ',', 'numbers', 'in', 'moves', 'do', 'going', 'my', 'a', 'feral', 'world', 'small', 'out', '--', 'kind', 'unbelievable', 'we', 'head', 'change', 'look', 'it', 'stand', 'the', 'what', 'na', 'something', 'all', 'and', 'him', 'somebody', 'moved', 'sudden'}
# 13968     9
# 13528     8
# 13441     7
# 13604    11
# 13404    34
# 14057     6
# 13682    46
# 14091    22
# 14079    14
# 13653     6
# 13680     2
# Name: Tokens, dtype: int64
# 13968      [toothless, !, no, !, toothless, !, do, n't, !]
# 13528        [could, we, just, talk, in, private, for, --]
# 13441            [that, really, came, out, of, nowhere, .]
# 13604    [because, i, 'm, going, to, change, his, mind,...
# 13404    [dragons, used, to, be, a, bit, of, a, problem...
# 14057                          [it, 's, all, over, now, .]
# 13682    [what, ?, no, ., i, do, n't, know, ., it, 's, ...
# 14091    [we, may, be, small, in, numbers, ,, but, we, ...
# 14079    [y'know, ,, skullcrusher, 's, gon, na, need, s...
# 13653                      [okay, ., no, sudden, moves, .]
# 13680                                    [unbelievable, .]
# Name: Tokens, dtype: object
# 	valka
# ['berk', 'was', 'a', 'land', 'of', 'kill', 'or', 'be', 'killed', ',', 'but', 'i', 'believed', 'peace', 'was', 'possible', '.', 'it', "'s", 'not', 'his', 'fault', '.', 'you', 'know', 'that', '.']
# 27
# DOUBLE CHECK: 27
# TYPES:
# 24
# {'i', 'you', 'fault', 'or', '.', 'not', 'it', ',', "'s", 'berk', 'but', 'know', 'be', 'possible', 'of', 'a', 'peace', 'that', 'believed', 'his', 'was', 'kill', 'killed', 'land'}
# 13701    17
# 13978    10
# Name: Tokens, dtype: int64
# 13701    [berk, was, a, land, of, kill, or, be, killed,...
# 13978     [it, 's, not, his, fault, ., you, know, that, .]
# Name: Tokens, dtype: object
# 	eret
# ['all', 'right', '!', 'okay', '!', 'i', "'ll", 'take', 'you', 'to', 'drago', '!', 'after', 'all', ',', 'it', "'s", 'not', 'just', 'anyone', 'who', 'can', 'capture', 'a', 'night', 'fury', '.']
# 27
# DOUBLE CHECK: 27
# TYPES:
# 24
# {'capture', 'who', 'i', 'you', 'drago', 'can', '!', '.', 'not', 'it', ',', "'s", 'take', 'to', 'just', 'right', 'fury', 'a', 'all', 'anyone', "'ll", 'after', 'okay', 'night'}
# 13749    12
# 13513    15
# Name: Tokens, dtype: int64
# 13749    [all, right, !, okay, !, i, 'll, take, you, to...
# 13513    [after, all, ,, it, 's, not, just, anyone, who...
# Name: Tokens, dtype: object
# 	tuffnut
# ['let', "'s", 'go', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'go', "'s", 'let', '!'}
# 13411    4
# Name: Tokens, dtype: int64
# 13411    [let, 's, go, !]
# Name: Tokens, dtype: object
# 	fishlegs
# ['any', 'new', 'dragons', '?']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'any', 'dragons', 'new', '?'}
# 13541    4
# Name: Tokens, dtype: int64
# 13541    [any, new, dragons, ?]
# Name: Tokens, dtype: object
# 	gobber
# ['the', 'chief', 'has', 'come', 'home', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'chief', 'home', 'the', '!', 'has', 'come'}
# 14088    6
# Name: Tokens, dtype: int64
# 14088    [the, chief, has, come, home, !]
# Name: Tokens, dtype: object
# 	drago
# ['move', 'out', '!']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'move', '!', 'out'}
# 13983    3
# Name: Tokens, dtype: int64
# 13983    [move, out, !]
# Name: Tokens, dtype: object
# Movie:Antz
# 	formica
# ['we', 'know', 'what', 'makes', 'an', 'ant', 'colony', 'strong', ',', 'do', "n't", 'we', '?', 'we', 'know', 'that', 'no', 'ant', 'can', 'be', 'an', 'individual', '.', 'no', 'single', 'ant', 'matters', ',', 'right', '?', 'what', 'do', 'we', 'have', 'on', 'this', '``', 'insectopia', "''", '?']
# 40
# DOUBLE CHECK: 40
# TYPES:
# 27
# {'an', '?', 'single', 'colony', 'ant', 'we', 'on', 'strong', 'insectopia', 'can', "''", '.', 'individual', 'matters', ',', "n't", 'what', 'know', 'be', 'do', 'right', 'no', '``', 'that', 'makes', 'have', 'this'}
# 7825    30
# 7833    10
# Name: Tokens, dtype: int64
# 7825    [we, know, what, makes, an, ant, colony, stron...
# 7833    [what, do, we, have, on, this, ``, insectopia,...
# Name: Tokens, dtype: object
# 	colonel
# ['they', "'re", 'here', '!', '!', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 4
# {'they', 'here', '!', "'re"}
# 7622    6
# Name: Tokens, dtype: int64
# 7622    [they, 're, here, !, !, !]
# Name: Tokens, dtype: object
# 	weaver
# ['no', ',', 'sir', '!']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {',', '!', 'no', 'sir'}
# 7828    4
# Name: Tokens, dtype: int64
# 7828    [no, ,, sir, !]
# Name: Tokens, dtype: object
# 	male wasp
# ['muffy', ',', 'look', ',', 'party-crashers', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 5
# {'.', 'muffy', 'party-crashers', 'look', ','}
# 7846    6
# Name: Tokens, dtype: int64
# 7846    [muffy, ,, look, ,, party-crashers, .]
# Name: Tokens, dtype: object
# 	foreman
# ['where', 'do', 'ya', 'think', 'you', "'re", 'going', '?', 'get', 'back', 'to', 'work', '!']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 13
# {'you', 'do', 'going', '?', 'back', 'work', 'get', 'think', "'re", 'ya', '!', 'to', 'where'}
# 7811    13
# Name: Tokens, dtype: int64
# 7811    [where, do, ya, think, you, 're, going, ?, get...
# Name: Tokens, dtype: object
# 	z
# ['i', 'sort', 'of', 'imagined', 'insectopia', 'a', 'little', 'differently', '--', 'oh', '...', 'oh', 'well', 'then', ',', 'one', 'more', 'wo', "n't", 'matter', '.', 'this', 'is', 'terrific', '!', 'let', "'s", 'exact', 'crippling', 'war', 'reparations', '!', 'let', "'s", 'set', 'up', 'a', 'puppet', 'government', '!', 'let', "'s", 'dig', 'in', '!', 'any', 'of', 'you', 'guys', 'know', 'when', 'the', 'princess', 'will', 'show', 'up', '?', 'she', "'s", 'kind', 'of', 'a', 'personal', 'friend', '.', 'i', "'m", 'going', 'back', '.', 'i', "'ve", 'got', 'to', 'get', 'her', '.', 'who', "'ll", 'come', 'with', 'me', '?', 'sorry', ',', 'it', "'s", 'been', 'through', 'a', 'war', ',', 'not', 'to', 'mention', 'everything', 'else', '...', 'we', "'ve", 'got', 'to', 'dig', 'a', 'trench', 'around', 'us', '!', 'no', 'i', "'m", 'not', '--', 'i', 'mean', '--', 'nobody', 'move', '!', 'or', 'the', 'princess', 'gets', 'it', '!']
# 125
# DOUBLE CHECK: 125
# TYPES:
# 81
# {'personal', 'oh', '?', 'kind', 'back', 'everything', 'differently', 'well', 'i', 'one', 'terrific', 'who', 'we', "'m", 'insectopia', 'you', 'around', '!', 'guys', 'friend', 'been', 'with', 'us', 'or', 'up', '...', '.', 'not', 'imagined', 'it', 'reparations', ',', "'s", 'crippling', 'puppet', 'dig', "n't", 'will', 'she', 'matter', 'when', 'is', 'the', 'know', 'to', 'in', 'come', 'through', 'going', 'no', 'nobody', 'government', 'gets', "'ve", 'of', 'a', 'wo', 'her', 'let', 'little', 'move', 'exact', "'ll", 'else', 'sort', 'any', 'got', 'mention', 'show', 'trench', 'sorry', 'get', 'then', 'set', 'more', 'princess', 'me', 'mean', 'war', '--', 'this'}
# 7861     9
# 7699    12
# 7636    19
# 7844     5
# 7580    20
# 7936    18
# 7914    15
# 8019    10
# 7725    17
# Name: Tokens, dtype: int64
# 7861    [i, sort, of, imagined, insectopia, a, little,...
# 7699    [oh, ..., oh, well, then, ,, one, more, wo, n'...
# 7636    [this, is, terrific, !, let, 's, exact, crippl...
# 7844                                [let, 's, dig, in, !]
# 7580    [any, of, you, guys, know, when, the, princess...
# 7936    [i, 'm, going, back, ., i, 've, got, to, get, ...
# 7914    [sorry, ,, it, 's, been, through, a, war, ,, n...
# 8019    [we, 've, got, to, dig, a, trench, around, us, !]
# 7725    [no, i, 'm, not, --, i, mean, --, nobody, move...
# Name: Tokens, dtype: object
# 	bala
# ['i', "'ve", 'been', 'kidnapped', 'by', 'the', 'village', 'idiot', '.', 'are', 'you', 'sure', 'this', 'is', 'a', 'real', 'dance', '?', 'z', '!', '!', '!', 'get', 'me', 'out', 'of', 'heeeeere', '!', 'z', '!', 'you', 'came', 'back', '!', 'i', 'swear', ',', 'we', "'ve", 'passed', 'this', 'blade', 'of', 'grass', 'three', 'times', '.', 'what', '?', 'water', '!', '!', '!']
# 53
# DOUBLE CHECK: 53
# TYPES:
# 37
# {'?', 'three', 'came', 'back', 'dance', 'i', 'we', 'grass', 'times', 'water', 'idiot', 'you', '!', 'real', 'been', '.', ',', 'the', 'what', 'is', 'swear', 'passed', 'are', "'ve", 'a', 'of', 'z', 'by', 'village', 'sure', 'get', 'blade', 'me', 'heeeeere', 'out', 'this', 'kidnapped'}
# 7738     9
# 7541     9
# 7869    10
# 7975     6
# 7837    13
# 7538     2
# 7789     4
# Name: Tokens, dtype: int64
# 7738    [i, 've, been, kidnapped, by, the, village, id...
# 7541        [are, you, sure, this, is, a, real, dance, ?]
# 7869          [z, !, !, !, get, me, out, of, heeeeere, !]
# 7975                           [z, !, you, came, back, !]
# 7837    [i, swear, ,, we, 've, passed, this, blade, of...
# 7538                                            [what, ?]
# 7789                                     [water, !, !, !]
# Name: Tokens, dtype: object
# 	barbatus
# ['z', '!', 'over', 'here', '!']
# 5
# DOUBLE CHECK: 5
# TYPES:
# 4
# {'here', '!', 'z', 'over'}
# 7639    5
# Name: Tokens, dtype: int64
# 7639    [z, !, over, here, !]
# Name: Tokens, dtype: object
# 	queen
# ['darling', ',', 'you', 'must', 'encourage', 'the', 'troops', '--', 'wave', '!']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 10
# {'wave', 'must', 'encourage', '--', ',', 'troops', 'darling', 'you', 'the', '!'}
# 7595    10
# Name: Tokens, dtype: int64
# 7595    [darling, ,, you, must, encourage, the, troops...
# Name: Tokens, dtype: object
# 	motivational counsellor
# ['i', "'m", 'glad', 'you', 'asked', 'me', 'that', 'question', '!']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 9
# {'question', 'asked', 'i', 'me', "'m", 'that', 'you', '!', 'glad'}
# 7431    9
# Name: Tokens, dtype: int64
# 7431    [i, 'm, glad, you, asked, me, that, question, !]
# Name: Tokens, dtype: object
# 	female wasp
# ['they', "'re", 'simply', 'too', 'much', ',', 'chip', '!']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'they', 'too', 'chip', 'simply', ',', 'much', "'re", '!'}
# 7847    8
# Name: Tokens, dtype: int64
# 7847    [they, 're, simply, too, much, ,, chip, !]
# Name: Tokens, dtype: object
# 	worker #2
# ['i', 'heard', 'about', 'this', 'guy', '.', 'he', 'crashed', 'a', 'party', 'at', 'the', 'palace', '.', 'then', 'he', 'took', 'a', 'hike', 'with', 'one', 'of', 'the', 'royal', 'babes', '!', 'and', 'when', 'they', 'tried', 'to', 'stop', 'him', ',', 'he', 'just', 'looked', 'at', 'a', "couple'a", 'guards', ',', 'and', 'they', 'burst', 'into', 'flames', '!']
# 48
# DOUBLE CHECK: 48
# TYPES:
# 37
# {'they', 'crashed', 'took', 'i', 'one', 'guy', 'palace', 'hike', 'party', 'he', '!', 'with', 'babes', 'royal', 'stop', 'into', '.', ',', 'burst', 'the', 'when', 'guards', 'to', 'tried', 'just', "couple'a", 'flames', 'a', 'of', 'at', 'heard', 'about', 'and', 'then', 'him', 'looked', 'this'}
# 7765    48
# Name: Tokens, dtype: int64
# 7765    [i, heard, about, this, guy, ., he, crashed, a...
# Name: Tokens, dtype: object
# Movie:Rise of the Guardians
# 	jack
# ['we', 'got', 'ta', 'help', 'sandy', '!', 'oh', ',', 'yeah', '.', 'i', 'love', 'being', 'shoved', 'in', 'a', 'sack', 'and', 'tossed', 'through', 'a', 'magic', 'portal', '.', 'aaaaaaaah', '!', 'i', 'will', '.', 'okay', ',', 'one', 'ride', ',', 'but', 'that', "'s", 'it', '.', 'wait', ',', 'but', ',', 'where', "'s", 'bunny', '?', 'huh', ',', 'that', 'looks', 'interesting', '.', 'good', 'book', '?']
# 56
# DOUBLE CHECK: 56
# TYPES:
# 40
# {'oh', '?', 'interesting', 'book', 'we', 'i', 'one', 'ta', 'ride', '!', 'wait', '.', 'sack', 'it', ',', "'s", 'tossed', 'will', 'but', 'good', 'through', 'aaaaaaaah', 'in', 'huh', 'sandy', 'a', 'portal', 'yeah', 'that', 'bunny', 'where', 'being', 'got', 'and', 'magic', 'okay', 'love', 'help', 'shoved', 'looks'}
# 12202     6
# 11897    18
# 12200     2
# 12586     3
# 11986    10
# 12467     8
# 11775     9
# Name: Tokens, dtype: int64
# 12202                        [we, got, ta, help, sandy, !]
# 11897    [oh, ,, yeah, ., i, love, being, shoved, in, a...
# 12200                                       [aaaaaaaah, !]
# 12586                                         [i, will, .]
# 11986        [okay, ,, one, ride, ,, but, that, 's, it, .]
# 12467               [wait, ,, but, ,, where, 's, bunny, ?]
# 11775    [huh, ,, that, looks, interesting, ., good, bo...
# Name: Tokens, dtype: object
# 	kids
# ['easter', "'s", 'over', '.', 'forget', 'this', '.', 'whoa', '!', 'the', 'sandman', '!']
# 12
# DOUBLE CHECK: 12
# TYPES:
# 10
# {'.', 'over', 'sandman', 'whoa', 'the', "'s", 'this', '!', 'easter', 'forget'}
# 12325    7
# 12551    5
# Name: Tokens, dtype: int64
# 12325    [easter, 's, over, ., forget, this, .]
# 12551                [whoa, !, the, sandman, !]
# Name: Tokens, dtype: object
# 	claude
# ['cupcake', '?']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'cupcake', '?'}
# 12508    2
# Name: Tokens, dtype: int64
# 12508    [cupcake, ?]
# Name: Tokens, dtype: object
# 	tooth
# ['pitch', ',', 'you', 'have', 'got', 'thirty', 'seconds', 'to', 'return', 'my', 'fairies', '!', 'believed', 'in', '.', 'oh', ',', 'sorry', '.', 'they', "'re", 'beautiful', '.']
# 23
# DOUBLE CHECK: 23
# TYPES:
# 20
# {'pitch', 'seconds', 'in', 'got', 'fairies', 'thirty', 'my', 'believed', '.', 'oh', 'sorry', 'they', 'return', ',', 'beautiful', "'re", 'have', 'you', '!', 'to'}
# 12030    12
# 12142     3
# 11925     8
# Name: Tokens, dtype: int64
# 12030    [pitch, ,, you, have, got, thirty, seconds, to...
# 12142                                    [believed, in, .]
# 11925           [oh, ,, sorry, ., they, 're, beautiful, .]
# Name: Tokens, dtype: object
# 	sophie
# ['bye', ',', 'bye', ',', 'bunny', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 4
# {',', '.', 'bye', 'bunny'}
# 12605    6
# Name: Tokens, dtype: int64
# 12605    [bye, ,, bye, ,, bunny, .]
# Name: Tokens, dtype: object
# 	north
# ['twins', 'yipa', '!', '!', 'this', 'wonder', 'is', 'what', 'i', 'put', 'into', 'the', 'world', ',', 'and', 'what', 'i', 'protect', 'in', 'children', '.', 'oh', ',', 'what', 'gives', 'slowpokes', '!', '?']
# 28
# DOUBLE CHECK: 28
# TYPES:
# 22
# {'oh', '?', 'i', '!', 'into', '.', 'protect', ',', 'wonder', 'the', 'what', 'is', 'in', 'gives', 'world', 'put', 'children', 'yipa', 'twins', 'and', 'slowpokes', 'this'}
# 12113     4
# 11977    17
# 12140     7
# Name: Tokens, dtype: int64
# 12113                                  [twins, yipa, !, !]
# 11977    [this, wonder, is, what, i, put, into, the, wo...
# 12140                [oh, ,, what, gives, slowpokes, !, ?]
# Name: Tokens, dtype: object
# 	bunnymund
# ['slow', 'down', ',', 'slow', 'down', '!', 'look', ',', 'mate', ',', 'i', "'m", 'dealing', 'with', 'perishables', '.', 'right', '.', 'you', "'ve", 'got', 'all', 'year', 'to', 'prepare', '.', 'that', "'s", 'my', 'boy', '!', 'woo', '!', 'oh', ',', 'you', 'do', "n't", 'wan', 'na', 'race', 'a', 'rabbit', ',', 'mate', '.', 'i', 'know', '.', 'you', 'wan', 'na', 'paint', 'some', 'eggs', '?', 'yeah', '?']
# 58
# DOUBLE CHECK: 58
# TYPES:
# 39
# {'oh', '?', 'i', "'m", 'you', 'dealing', '!', 'with', 'eggs', '.', 'look', 'boy', ',', "'s", "n't", 'to', 'know', 'do', 'right', 'my', 'na', "'ve", 'wan', 'a', 'yeah', 'that', 'paint', 'all', 'prepare', 'some', 'mate', 'got', 'year', 'rabbit', 'perishables', 'slow', 'race', 'down', 'woo'}
# 11998     6
# 11739    20
# 12593     7
# 12101    13
# 12322     3
# 12252     9
# Name: Tokens, dtype: int64
# 11998                       [slow, down, ,, slow, down, !]
# 11739    [look, ,, mate, ,, i, 'm, dealing, with, peris...
# 12593                       [that, 's, my, boy, !, woo, !]
# 12101    [oh, ,, you, do, n't, wan, na, race, a, rabbit...
# 12322                                         [i, know, .]
# 12252        [you, wan, na, paint, some, eggs, ?, yeah, ?]
# Name: Tokens, dtype: object
# 	pitch
# ['aww', ',', 'you', "'ll", 'protect', 'them', '.', 'but', 'who', 'will', 'protect', 'you', '?', 'really', '?', 'then', 'what', 'are', 'they', 'doing', 'here', '?', 'maybe', 'i', 'want', 'what', 'you', 'have', '.', 'to', 'be', 'believed', 'in', '.']
# 34
# DOUBLE CHECK: 34
# TYPES:
# 26
# {'they', '?', 'who', 'i', 'them', 'you', '.', 'protect', ',', 'will', 'but', 'want', 'what', 'to', 'in', 'be', 'aww', 'are', 'maybe', 'here', 'really', 'believed', "'ll", 'then', 'doing', 'have'}
# 12519    13
# 12577     9
# 12034    12
# Name: Tokens, dtype: int64
# 12519    [aww, ,, you, 'll, protect, them, ., but, who,...
# 12577    [really, ?, then, what, are, they, doing, here...
# 12034    [maybe, i, want, what, you, have, ., to, be, b...
# Name: Tokens, dtype: object
# 	jamie
# ['stop', '!', 'sit', '!', 'you', "'re", 'leaving', '?', 'but', ',', 'what', 'if', 'pitch', 'comes', 'back', '?', 'you', 'saw', 'the', 'video', 'too', 'claude', ',', 'he', "'s", 'out', 'there', '!', 'mom', '!', 'sophie', 'fell', 'again', '!', 'i', 'got', 'ta', 'put', 'this', 'under', 'my', 'pillow', '!', 'that', 'was', 'you', '?', 'i', 'know', 'what', 'we', 'have', 'to', 'do', '!', 'guys', ',', 'come', 'on', '!']
# 60
# DOUBLE CHECK: 60
# TYPES:
# 45
# {'?', 'sophie', 'back', 'we', 'i', 'if', 'on', 'pillow', 'video', 'ta', 'you', 'he', '!', 'guys', 'mom', 'pitch', 'comes', 'stop', 'leaving', ',', "'s", 'again', 'sit', 'fell', 'but', 'the', 'what', 'to', 'know', 'come', 'do', 'my', 'that', 'claude', "'re", 'saw', 'put', 'under', 'too', 'got', 'was', 'out', 'there', 'have', 'this'}
# 12166     4
# 12606    12
# 11785    12
# 11792     6
# 11848     9
# 12445     4
# 12548    13
# Name: Tokens, dtype: int64
# 12166                                    [stop, !, sit, !]
# 12606    [you, 're, leaving, ?, but, ,, what, if, pitch...
# 11785    [you, saw, the, video, too, claude, ,, he, 's,...
# 11792                     [mom, !, sophie, fell, again, !]
# 11848        [i, got, ta, put, this, under, my, pillow, !]
# 12445                                  [that, was, you, ?]
# 12548    [i, know, what, we, have, to, do, !, guys, ,, ...
# Name: Tokens, dtype: object
# 	yeti
# ['wardle', 'bawddrel', '.']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'bawddrel', 'wardle', '.'}
# 11708    3
# Name: Tokens, dtype: int64
# 11708    [wardle, bawddrel, .]
# Name: Tokens, dtype: object
# 	bunny
# ['ohh', 'no', ',', 'mate', '.', 'my', 'warren', 'my', 'rules', '.', 'buckle', 'up', '.']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 10
# {'mate', 'no', '.', 'my', 'rules', 'up', 'warren', ',', 'buckle', 'ohh'}
# 12232    13
# Name: Tokens, dtype: int64
# 12232    [ohh, no, ,, mate, ., my, warren, my, rules, ....
# Name: Tokens, dtype: object
# Movie:Shrek 3
# 	donkey
# ['ahhh', '!', 'high', 'school', '?', '!', 'ow', '!', '!', 'my', 'eye', '!', 'my', 'eye', '!', 'artie', '!']
# 17
# DOUBLE CHECK: 17
# TYPES:
# 9
# {'ow', '?', 'my', 'school', 'high', 'eye', 'ahhh', '!', 'artie'}
# 9365    2
# 9019    4
# 8852    9
# 9549    2
# Name: Tokens, dtype: int64
# 9365                             [ahhh, !]
# 9019                  [high, school, ?, !]
# 8852    [ow, !, !, my, eye, !, my, eye, !]
# 9549                            [artie, !]
# Name: Tokens, dtype: object
# 	shrek
# ['you', 'catch', 'on', 'real', 'fast', 'kid', '...', 'maybe', 'you', "'re", 'not', 'as', 'big', 'of', 'a', 'loser', 'as', 'i', 'thought', '.', 'pardon', 'me', '...', 'fiona', '!', 'uh', ',', 'artie', '?', 'thanks', 'artie', '.']
# 32
# DOUBLE CHECK: 32
# TYPES:
# 27
# {'?', 'as', 'pardon', 'i', 'on', 'catch', 'you', '!', 'real', 'uh', 'fast', '...', 'not', '.', ',', 'thanks', 'thought', 'kid', 'artie', 'maybe', 'of', 'a', "'re", 'loser', 'fiona', 'me', 'big'}
# 9479    20
# 9028     3
# 9600     2
# 9225     4
# 9323     3
# Name: Tokens, dtype: int64
# 9479    [you, catch, on, real, fast, kid, ..., maybe, ...
# 9028                                    [pardon, me, ...]
# 9600                                           [fiona, !]
# 9225                                    [uh, ,, artie, ?]
# 9323                                   [thanks, artie, .]
# Name: Tokens, dtype: object
# 	wolf
# ['i', 'voted', 'for', '``', 'team', 'alpha', 'wolf', 'squadron', '.', "''"]
# 10
# DOUBLE CHECK: 10
# TYPES:
# 10
# {'for', '``', 'team', 'wolf', '.', 'i', 'alpha', 'squadron', 'voted', "''"}
# 9547    10
# Name: Tokens, dtype: int64
# 9547    [i, voted, for, ``, team, alpha, wolf, squadro...
# Name: Tokens, dtype: object
# 	fiona
# ['i', "'m", 'sorry', 'shrek', ',', 'but', 'can', 'you', 'please', 'just', 'try', 'to', 'grin', 'and', 'bear', 'it', '?', 'it', "'s", 'just', 'until', 'dad', 'gets', 'better', '.', 'uh', 'shrek', '?']
# 28
# DOUBLE CHECK: 28
# TYPES:
# 24
# {'?', 'i', 'try', 'until', "'m", 'you', 'shrek', 'can', 'uh', '.', 'it', ',', "'s", 'but', 'to', 'just', 'gets', 'better', 'and', 'bear', 'dad', 'sorry', 'please', 'grin'}
# 8835    25
# 8847     3
# Name: Tokens, dtype: int64
# 8835    [i, 'm, sorry, shrek, ,, but, can, you, please...
# 8847                                       [uh, shrek, ?]
# Name: Tokens, dtype: object
# 	artie
# ['you', 'were', 'playing', 'me', 'the', 'whole', 'time', '.', 'oh', ',', 'so', 'now', 'it', "'s", '``', 'your', 'highness', '?', "''", 'what', 'happened', 'to', '``', 'loser', '?', "''", 'huh', '?']
# 28
# DOUBLE CHECK: 28
# TYPES:
# 24
# {'oh', '?', 'time', 'highness', 'were', 'playing', 'you', "''", '.', 'so', 'it', ',', "'s", 'the', 'what', 'to', '``', 'huh', 'whole', 'now', 'loser', 'happened', 'me', 'your'}
# 9478     8
# 9243    20
# Name: Tokens, dtype: int64
# 9478        [you, were, playing, me, the, whole, time, .]
# 9243    [oh, ,, so, now, it, 's, ``, your, highness, ?...
# Name: Tokens, dtype: object
# 	prince charming
# ['a', 'new', 'era', 'finally', 'begins', '!', 'once', 'upon', 'a', 'time', ',', 'someone', 'decided', 'that', 'we', 'were', 'the', 'losers', '.', 'but', 'there', 'are', 'two', 'sides', 'to', 'every', 'story', '.', 'and', 'our', 'side', 'has', 'not', 'been', 'told', '.', 'and', 'you', '!', 'frumpypigskin', '.']
# 41
# DOUBLE CHECK: 41
# TYPES:
# 35
# {'time', 'we', 'were', 'our', 'once', 'side', 'you', '!', 'frumpypigskin', 'been', 'every', '.', 'not', ',', 'decided', 'story', 'finally', 'but', 'the', 'to', 'has', 'losers', 'upon', 'are', 'told', 'a', 'that', 'two', 'begins', 'and', 'someone', 'era', 'sides', 'there', 'new'}
# 9625     6
# 8939    30
# 8934     5
# Name: Tokens, dtype: int64
# 9625                    [a, new, era, finally, begins, !]
# 8939    [once, upon, a, time, ,, someone, decided, tha...
# 8934                      [and, you, !, frumpypigskin, .]
# Name: Tokens, dtype: object
# 	puss
# ['do', "n't", 'worry', ',', 'jefe', '.', 'i', 'got', 'this', '.', 'we', "'ve", 'got', 'to', 'save', 'her', '!']
# 17
# DOUBLE CHECK: 17
# TYPES:
# 15
# {'worry', 'do', 'got', '.', "'ve", 'we', 'i', 'her', ',', 'save', 'jefe', "n't", 'this', '!', 'to'}
# 9442    10
# 9375     7
# Name: Tokens, dtype: int64
# 9442    [do, n't, worry, ,, jefe, ., i, got, this, .]
# 9375                 [we, 've, got, to, save, her, !]
# Name: Tokens, dtype: object
# 	jocks
# ['oy', '!', 'right', '!', 'ooo', '!', 'ooo', '!', 'ooo', '!']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 4
# {'ooo', 'oy', '!', 'right'}
# 9038    10
# Name: Tokens, dtype: int64
# 9038    [oy, !, right, !, ooo, !, ooo, !, ooo, !]
# Name: Tokens, dtype: object
# 	captain hook
# ['but', 'we', 'are', 'villains', '.', 'it', "'s", 'the', 'only', 'thing', 'we', 'know', '.']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 11
# {'thing', 'only', '.', 'are', 'we', 'it', "'s", 'but', 'villains', 'the', 'know'}
# 9608    13
# Name: Tokens, dtype: int64
# 9608    [but, we, are, villains, ., it, 's, the, only,...
# Name: Tokens, dtype: object
# 	merlin
# ['oh', '.']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'oh', '.'}
# 9392    2
# Name: Tokens, dtype: int64
# 9392    [oh, .]
# Name: Tokens, dtype: object
# 	gingerbread man
# ['this', 'is', 'worse', 'than', 'love', 'letters', '!', 'i', 'hate', 'dinner', 'theatre', '.']
# 12
# DOUBLE CHECK: 12
# TYPES:
# 12
# {'letters', 'dinner', 'worse', 'hate', '!', '.', 'love', 'i', 'this', 'is', 'theatre', 'than'}
# 8789    12
# Name: Tokens, dtype: int64
# 8789    [this, is, worse, than, love, letters, !, i, h...
# Name: Tokens, dtype: object
# 	king harold
# ['his', 'name', 'is', '...', 'is', '...', 'is', '...']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 4
# {'name', 'is', 'his', '...'}
# 8903    8
# Name: Tokens, dtype: int64
# 8903    [his, name, is, ..., is, ..., is, ...]
# Name: Tokens, dtype: object
# 	xavier
# ['ha', '!', 'ha', '!', 'ah', '!']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 3
# {'ah', 'ha', '!'}
# 9034    6
# Name: Tokens, dtype: int64
# 9034    [ha, !, ha, !, ah, !]
# Name: Tokens, dtype: object
# 	nanny dwarf
# ['the', 'burping', '.']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'burping', 'the', '.'}
# 9137    3
# Name: Tokens, dtype: int64
# 9137    [the, burping, .]
# Name: Tokens, dtype: object
# 	snow white
# ['ahhaha', '!', '!', 'ahhaha', '!', '!', '!', '``', 'all', 'because', 'i', 'sing', '.', 'ahh', 'ha', 'ha', 'ha', 'ha', 'haaa', '.', "''"]
# 21
# DOUBLE CHECK: 21
# TYPES:
# 12
# {'``', 'ha', 'because', '.', 'i', "''", 'sing', 'ahh', 'ahhaha', 'all', 'haaa', '!'}
# 9537     7
# 9534    14
# Name: Tokens, dtype: int64
# 9537                      [ahhaha, !, !, ahhaha, !, !, !]
# 9534    [``, all, because, i, sing, ., ahh, ha, ha, ha...
# Name: Tokens, dtype: object
# 	pinocchio
# ['help', 'me', '!']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'help', 'me', '!'}
# 9425    3
# Name: Tokens, dtype: int64
# 9425    [help, me, !]
# Name: Tokens, dtype: object
# Movie:Kung Fu Panda
# 	tai lung
# ['but', 'when', 'oogway', 'said', 'otherwise', ',', 'what', 'did', 'you', 'do', '?', 'what', 'did', 'you', 'do', '?', '!']
# 17
# DOUBLE CHECK: 17
# TYPES:
# 12
# {'?', 'do', 'did', ',', 'otherwise', 'but', 'oogway', 'you', 'when', 'what', '!', 'said'}
# 10290    17
# Name: Tokens, dtype: int64
# 10290    [but, when, oogway, said, otherwise, ,, what, ...
# Name: Tokens, dtype: object
# 	shifu
# ['but', 'yes', '...', 'you', 'have', 'done', 'awesome', '.', 'and', 'finally', '...', 'master', 'tigress', '!', '--', 'until', 'he', 'finally', 'falls', ',', 'or', 'quits', '.', 'read', 'it', ',', 'po', ',', 'and', 'fulfill', 'your', 'destiny', '.', 'read', 'it', 'and', 'become', '...', 'the', 'dragon', 'warrior', '!', 'i', 'said', 'you', 'are', 'free', 'to', 'eat', '.', 'have', 'a', 'dumpling', '.']
# 54
# DOUBLE CHECK: 54
# TYPES:
# 38
# {'dumpling', 'quits', 'i', 'until', 'destiny', 'you', 'he', 'become', '!', 'said', 'yes', 'eat', 'or', '...', '.', 'master', 'falls', 'it', ',', 'read', 'free', 'finally', 'but', 'the', 'to', 'fulfill', 'warrior', 'are', 'a', 'dragon', 'and', 'done', 'awesome', 'po', 'tigress', '--', 'have', 'your'}
# 10208     8
# 9785      6
# 10019     9
# 10234    19
# 10185    12
# Name: Tokens, dtype: int64
# 10208         [but, yes, ..., you, have, done, awesome, .]
# 9785               [and, finally, ..., master, tigress, !]
# 10019     [--, until, he, finally, falls, ,, or, quits, .]
# 10234    [read, it, ,, po, ,, and, fulfill, your, desti...
# 10185    [i, said, you, are, free, to, eat, ., have, a,...
# Name: Tokens, dtype: object
# 	po
# ['i', 'was', 'just', 'uh', '...', 'some', 'day', 'huh', '?', 'that', 'kung', 'fu', 'stuff', 'is', 'hard', 'work', ',', 'right', '?', 'your', 'biceps', 'sore', '?', 'hey', ',', 'how', "'s", 'it', 'going', '?', 'just', 'like', 'that', '?', 'no', 'situps', '?', 'no', 'ten', 'mile', 'hike', '?', 'i', "'m", 'not', 'a', 'big', ',', 'fat', 'panda', '.', 'i', "'m", 'the', 'big', ',', 'fat', 'panda', '.', 'hey', ',', 'dad', '.', 'stairs', '...', 'sorry', ',', 'dad', '.', 'yeah', '!']
# 71
# DOUBLE CHECK: 71
# TYPES:
# 45
# {'?', 'day', 'work', 'i', 'stuff', 'hey', "'m", 'biceps', 'hike', 'panda', '!', 'like', 'fat', 'uh', '...', 'not', 'kung', '.', 'it', ',', "'s", 'how', 'sore', 'the', 'is', 'fu', 'just', 'right', 'going', 'no', 'situps', 'huh', 'a', 'yeah', 'that', 'hard', 'some', 'mile', 'was', 'dad', 'sorry', 'ten', 'big', 'stairs', 'your'}
# 9936     23
# 9864      7
# 10181    12
# 10323    17
# 10262     4
# 10305     2
# 9686      4
# 9772      2
# Name: Tokens, dtype: int64
# 9936     [i, was, just, uh, ..., some, day, huh, ?, tha...
# 9864                       [hey, ,, how, 's, it, going, ?]
# 10181    [just, like, that, ?, no, situps, ?, no, ten, ...
# 10323    [i, 'm, not, a, big, ,, fat, panda, ., i, 'm, ...
# 10262                                     [hey, ,, dad, .]
# 10305                                        [stairs, ...]
# 9686                                    [sorry, ,, dad, .]
# 9772                                             [yeah, !]
# Name: Tokens, dtype: object
# 	crane
# ['oh', 'dear', '.']
# 3
# DOUBLE CHECK: 3
# TYPES:
# 3
# {'dear', 'oh', '.'}
# 9998    3
# Name: Tokens, dtype: int64
# 9998    [oh, dear, .]
# Name: Tokens, dtype: object
# 	commander
# ['no', ',', 'he', 'does', "n't", '.', 'you', "'re", 'not', 'going', 'anywhere', '.', 'and', 'neither', 'is', 'he', '.']
# 17
# DOUBLE CHECK: 17
# TYPES:
# 14
# {'and', 'going', 'no', '.', 'not', 'does', 'is', ',', "n't", "'re", 'you', 'he', 'neither', 'anywhere'}
# 9847     6
# 9974    11
# Name: Tokens, dtype: int64
# 9847                            [no, ,, he, does, n't, .]
# 9974    [you, 're, not, going, anywhere, ., and, neith...
# Name: Tokens, dtype: object
# 	oogway
# ['good', '.', 'my', 'time', 'has', 'come', '.', 'you', 'must', 'continue', 'your', 'journey', 'without', 'me', '.', 'one', 'often', 'meets', 'his', 'destiny', 'on', 'the', 'road', 'he', 'takes', 'to', 'avoid', 'it', '.']
# 29
# DOUBLE CHECK: 29
# TYPES:
# 26
# {'time', 'road', 'often', 'one', 'on', 'destiny', 'you', 'he', 'meets', '.', 'it', 'journey', 'good', 'the', 'has', 'to', 'come', 'must', 'my', 'continue', 'his', 'without', 'me', 'takes', 'avoid', 'your'}
# 10094    15
# 9732     14
# Name: Tokens, dtype: int64
# 10094    [good, ., my, time, has, come, ., you, must, c...
# 9732     [one, often, meets, his, destiny, on, the, roa...
# Name: Tokens, dtype: object
# 	mantis
# ['but', ',', 'ya', 'know', ',', 'he', 'was', "n't", 'always', 'like', 'that', '.']
# 12
# DOUBLE CHECK: 12
# TYPES:
# 11
# {'like', '.', 'was', ',', 'that', "n't", 'but', 'ya', 'he', 'know', 'always'}
# 10037    12
# Name: Tokens, dtype: int64
# 10037    [but, ,, ya, know, ,, he, was, n't, always, li...
# Name: Tokens, dtype: object
# 	po's dad
# ['this', 'is', 'a', 'sign', ',', 'po', '!', 'oh', ',', 'happy', 'day', '!', 'my', 'son', ',', 'finally', 'having', 'the', 'noodle', 'dream', '!']
# 21
# DOUBLE CHECK: 21
# TYPES:
# 17
# {'oh', 'day', '!', 'my', 'noodle', 'dream', 'happy', 'a', 'po', 'having', ',', 'the', 'finally', 'son', 'sign', 'this', 'is'}
# 9700     7
# 9698    14
# Name: Tokens, dtype: int64
# 9700                        [this, is, a, sign, ,, po, !]
# 9698    [oh, ,, happy, day, !, my, son, ,, finally, ha...
# Name: Tokens, dtype: object
# 	monkey
# ['tigress', ',', 'you', 'got', 'ta', 'try', 'this', '.']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'got', '.', 'try', ',', 'tigress', 'ta', 'you', 'this'}
# 10111    8
# Name: Tokens, dtype: int64
# 10111    [tigress, ,, you, got, ta, try, this, .]
# Name: Tokens, dtype: object
# 	narrator
# ['never', 'before', 'had', 'a', 'panda', 'been', 'so', 'feared', '...', 'and', 'so', 'loved', '.']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 12
# {'and', '...', '.', 'a', 'so', 'feared', 'before', 'never', 'had', 'panda', 'loved', 'been'}
# 9672    13
# Name: Tokens, dtype: int64
# 9672    [never, before, had, a, panda, been, so, feare...
# Name: Tokens, dtype: object
# 	tigress
# ['master', ',', 'please', '.', 'let', 'us', 'stop', 'tai', 'lung', '.', 'this', 'is', 'what', 'you', "'ve", 'trained', 'us', 'for', '.']
# 19
# DOUBLE CHECK: 19
# TYPES:
# 16
# {'trained', 'for', 'stop', '.', 'master', 'this', "'ve", ',', 'tai', 'let', 'you', 'lung', 'what', 'is', 'please', 'us'}
# 10132    19
# Name: Tokens, dtype: int64
# 10132    [master, ,, please, ., let, us, stop, tai, lun...
# Name: Tokens, dtype: object
# Movie:Pocahontas
# 	ratcliffe
# ['this', 'is', 'my', 'land', '!', 'i', 'make', 'the', 'laws', 'here', '.', 'and', 'i', 'say', 'anyone', 'so', 'much', 'as', 'looks', 'at', 'an', 'indian', 'without', 'killing', 'him', 'on', 'sight', ',', 'will', 'be', 'tried', 'for', 'treason', 'and', 'hanged', '.', 'we', 'will', 'eliminate', 'these', 'savages', 'once', 'and', 'for', 'all', '.', 'smith', '!', 'where', 'have', 'you', 'been', '?', 'you', 'there', '!', 'where', "'s", 'captain', 'smith', '?']
# 61
# DOUBLE CHECK: 61
# TYPES:
# 48
# {'an', '?', 'as', 'indian', 'hanged', 'i', 'we', 'on', 'once', 'much', 'you', '!', 'been', '.', 'so', ',', 'say', "'s", 'captain', 'will', 'laws', 'the', 'is', 'killing', 'tried', 'be', 'for', 'my', 'here', 'at', 'have', 'make', 'all', 'sight', 'anyone', 'these', 'savages', 'where', 'and', 'him', 'without', 'eliminate', 'there', 'smith', 'this', 'treason', 'land', 'looks'}
# 3776    36
# 3757    10
# 3753     7
# 3642     8
# Name: Tokens, dtype: int64
# 3776    [this, is, my, land, !, i, make, the, laws, he...
# 3757    [we, will, eliminate, these, savages, once, an...
# 3753                [smith, !, where, have, you, been, ?]
# 3642        [you, there, !, where, 's, captain, smith, ?]
# Name: Tokens, dtype: object
# 	lon
# ['if', 'they', 'do', 'have', 'the', 'gold', ',', 'i', 'reckon', 'we', "'ll", 'have', 'to', 'fight', 'them', '.']
# 16
# DOUBLE CHECK: 16
# TYPES:
# 15
# {'they', 'do', 'fight', '.', 'reckon', 'we', 'i', 'if', 'them', ',', 'have', 'gold', 'the', 'to', "'ll"}
# 3792    16
# Name: Tokens, dtype: int64
# 3792    [if, they, do, have, the, gold, ,, i, reckon, ...
# Name: Tokens, dtype: object
# 	john smith
# ['like', 'all', 'the', 'others', ',', 'i', 'suppose', '.', 'i', "'ve", 'seen', 'hundreds', 'of', 'new', 'worlds', ',', 'thomas', '.', 'what', 'could', 'possibly', 'be', 'different', 'about', 'this', 'one', '?', 'i', "'m", 'glad', 'you', "'re", 'on', 'our', 'side', '.', 'not', 'aiming', 'like', 'that', ',', 'you', 'could', "n't", '.', 'keep', 'both', 'eyes', 'open', 'when', 'you', 'shoot', '.', 'you', "'ll", 'see', 'twice', 'as', 'well', '.', 'we', "'re", 'going', 'to', 'build', 'them', 'here', '.', 'we', "'ll", 'show', 'your', 'people', 'how', 'to', 'use', 'this', 'land', 'properly', '.', 'how', 'to', 'make', 'the', 'most', 'of', 'it', '.', 'thomasfell', 'overboard', ',', 'sir', '.', 'for', 'what', ',', 'this', '?', 'i', "'ve", 'gotten', 'out', 'of', 'worse', 'scrapes', 'than', 'this', '.', 'ca', "n't", 'think', 'of', 'any', 'right', 'now', ',', 'but', '.', '.', '.', 'pocahontas', ',', 'it', 'wo', "n't", 'help', '!', 'he', 'was', 'only—', 'well', ',', 'that', 'was', 'refreshing', '.', 'i', 'was', 'out', 'scouting', 'the', 'terrain', ',', 'sir', '.']
# 145
# DOUBLE CHECK: 145
# TYPES:
# 87
# {'on', 'only—', '.', "n't", 'but', 'how', 'open', 'worse', "'ve", 'of', 'here', 'that', "'re", 'about', 'was', 'scouting', 'hundreds', 'this', 'worlds', 'your', 'one', 'them', "'m", 'think', 'sir', 'you', 'he', 'than', 'seen', 'terrain', 'use', 'both', 'to', 'gotten', 'be', 'for', 'keep', 'wo', 'properly', 'now', 'see', 'show', 'thomas', 'twice', '?', 'i', 'our', 'different', 'pocahontas', 'side', '!', 'like', 'not', 'could', ',', 'overboard', 'thomasfell', 'going', 'right', 'ca', 'make', 'glad', 'refreshing', 'out', 'people', 'land', 'scrapes', 'as', 'well', 'we', 'suppose', 'aiming', 'possibly', 'eyes', 'it', 'shoot', 'the', 'what', 'when', 'most', 'others', 'all', "'ll", 'help', 'build', 'any', 'new'}
# 3390    27
# 3721     9
# 3750    24
# 3601    28
# 3374     5
# 3850    27
# 3834    10
# 3366     6
# 3754     9
# Name: Tokens, dtype: int64
# 3390    [like, all, the, others, ,, i, suppose, ., i, ...
# 3721            [i, 'm, glad, you, 're, on, our, side, .]
# 3750    [not, aiming, like, that, ,, you, could, n't, ...
# 3601    [we, 're, going, to, build, them, here, ., we,...
# 3374                   [thomasfell, overboard, ,, sir, .]
# 3850    [for, what, ,, this, ?, i, 've, gotten, out, o...
# 3834    [pocahontas, ,, it, wo, n't, help, !, he, was,...
# 3366                  [well, ,, that, was, refreshing, .]
# 3754     [i, was, out, scouting, the, terrain, ,, sir, .]
# Name: Tokens, dtype: object
# 	powhatan
# ['yes', ',', 'something', 'exciting', 'is', 'about', 'to', 'happen', '.', 'pocahontas', ',', 'come', 'with', 'me', '.', 'you', 'are', 'the', 'daughter', 'of', 'the', 'chief', '.', 'it', 'is', 'time', 'to', 'take', 'your', 'place', 'among', 'our', 'people', '.', 'even', 'the', 'wild', 'mountain', 'stream', 'must', 'someday', 'join', 'the', 'big', 'river', '.', 'as', 'the', 'river', 'cuts', 'his', 'path', 'though', 'the', 'river', "'s", 'proud', 'and', 'strong', 'he', 'will', 'choose', 'the', 'smoothest', 'course', 'that', "'s", 'why', 'rivers', 'live', 'so', 'long', 'they', "'re", 'steady', 'as', 'the', 'steady', 'beating', 'drum', 'your', 'mother', 'wore', 'this', 'for', 'our', 'wedding', '.', 'it', 'was', 'her', 'dream', 'to', 'see', 'you', 'wear', 'it', 'at', 'your', 'own', '.', 'it', 'suits', 'you', '.']
# 105
# DOUBLE CHECK: 105
# TYPES:
# 74
# {'they', 'someday', 'time', 'river', 'as', 'path', 'our', 'mountain', 'drum', 'pocahontas', 'even', 'strong', 'you', 'he', 'own', 'stream', 'wild', 'yes', 'though', 'with', 'suits', '.', 'smoothest', 'wore', 'it', 'so', ',', "'s", 'people', 'why', 'will', 'proud', 'daughter', 'the', 'take', 'is', 'to', 'join', 'come', 'choose', 'steady', 'beating', 'must', 'for', 'wedding', 'are', 'something', 'of', 'her', 'long', 'at', 'that', "'re", 'happen', 'among', 'cuts', 'about', 'and', 'his', 'see', 'was', 'wear', 'mother', 'live', 'chief', 'exciting', 'course', 'me', 'rivers', 'big', 'place', 'dream', 'this', 'your'}
# 3420     9
# 3430    96
# Name: Tokens, dtype: int64
# 3420    [yes, ,, something, exciting, is, about, to, h...
# 3430    [pocahontas, ,, come, with, me, ., you, are, t...
# Name: Tokens, dtype: object
# 	grandmother willow
# ['the', 'earth', 'is', 'trembling', ',', 'child', '.', 'what', "'s", 'happened', '?', 'is', 'that', 'my', 'pocahontas', '?']
# 16
# DOUBLE CHECK: 16
# TYPES:
# 14
# {'?', 'earth', '.', 'my', 'trembling', 'child', ',', "'s", 'pocahontas', 'that', 'the', 'what', 'is', 'happened'}
# 3803    11
# 3432     5
# Name: Tokens, dtype: int64
# 3803    [the, earth, is, trembling, ,, child, ., what,...
# 3432                        [is, that, my, pocahontas, ?]
# Name: Tokens, dtype: object
# 	thomas
# ['no', '!', 'john', '!', 'you', 'better', 'get', 'down', 'here', '!', 'the', 'governor', "'s", 'coming', 'ashore', '!', 'ah', ',', 'do', "n't", 'worry', ',', 'john', '.', 'you', "'ll", 'get', 'your', 'chance', 'to', 'deal', 'with', 'the', 'indians', '.', 'they', 'headed', 'north', '!']
# 39
# DOUBLE CHECK: 39
# TYPES:
# 29
# {'they', 'north', 'you', 'deal', '!', 'with', 'john', 'governor', '.', ',', "'s", 'ashore', "n't", 'chance', 'the', 'to', 'do', 'worry', 'no', 'coming', 'better', 'here', "'ll", 'ah', 'headed', 'get', 'indians', 'your', 'down'}
# 3924     2
# 3484    14
# 3631    19
# 3875     4
# Name: Tokens, dtype: int64
# 3924                                              [no, !]
# 3484    [john, !, you, better, get, down, here, !, the...
# 3631    [ah, ,, do, n't, worry, ,, john, ., you, 'll, ...
# 3875                             [they, headed, north, !]
# Name: Tokens, dtype: object
# 	pocahontas
# ['yes', '!', 'it', 'spins', 'faster', 'and', 'faster', 'and', 'faster', 'until', 'suddenly', 'it', 'stops', '.', 'no', ',', 'you', 'have', 'to', 'go', 'back', '.', 'wingapo', ',', 'father', '.']
# 26
# DOUBLE CHECK: 26
# TYPES:
# 19
# {'stops', 'and', 'you', 'faster', '.', 'no', 'back', 'wingapo', 'father', 'it', ',', 'until', 'go', 'have', 'spins', 'suddenly', '!', 'to', 'yes'}
# 3443    14
# 3960     8
# 3415     4
# Name: Tokens, dtype: int64
# 3443    [yes, !, it, spins, faster, and, faster, and, ...
# 3960                  [no, ,, you, have, to, go, back, .]
# 3415                              [wingapo, ,, father, .]
# Name: Tokens, dtype: object
# 	wiggins
# ['i', 'like', 'gruel', '.']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'gruel', 'like', 'i', '.'}
# 3768    4
# Name: Tokens, dtype: int64
# 3768    [i, like, gruel, .]
# Name: Tokens, dtype: object
# 	ben
# ['.', '.', '.', 'ratcliffe', 'would', "n't", 'take', 'us', 'halfway', 'around', 'the', 'world', 'for', 'nothing', '.', 'is', 'he', 'going', 'to', 'make', 'it', ',', 'thomas', '?']
# 24
# DOUBLE CHECK: 24
# TYPES:
# 21
# {'?', 'nothing', 'he', 'halfway', 'around', 'us', 'ratcliffe', 'would', '.', 'it', ',', "n't", 'the', 'take', 'is', 'to', 'for', 'going', 'world', 'make', 'thomas'}
# 3788    15
# 3939     9
# Name: Tokens, dtype: int64
# 3788    [., ., ., ratcliffe, would, n't, take, us, hal...
# 3939          [is, he, going, to, make, it, ,, thomas, ?]
# Name: Tokens, dtype: object
# Movie:Shrek
# 	fiona
# ['it', "'s", 'me', ',', 'in', 'this', 'body', '.', 'mmm', '.', 'this', 'is', 'good', '.', 'this', 'is', 'really', 'good', '.', 'what', 'is', 'this', '?', 'shrek', '?', 'no', '!']
# 27
# DOUBLE CHECK: 27
# TYPES:
# 17
# {'in', '?', 'no', '.', '!', 'mmm', 'it', ',', "'s", 'me', 'body', 'really', 'good', 'this', 'what', 'is', 'shrek'}
# 8603     8
# 8564    15
# 8737     2
# 8607     2
# Name: Tokens, dtype: int64
# 8603                   [it, 's, me, ,, in, this, body, .]
# 8564    [mmm, ., this, is, good, ., this, is, really, ...
# 8737                                           [shrek, ?]
# 8607                                              [no, !]
# Name: Tokens, dtype: object
# 	priest
# ['and', 'so', ',', 'by', 'the', 'power', 'vested', 'in', 'me', '...']
# 10
# DOUBLE CHECK: 10
# TYPES:
# 10
# {'in', 'and', 'power', '...', 'so', ',', 'me', 'vested', 'the', 'by'}
# 8728    10
# Name: Tokens, dtype: int64
# 8728    [and, so, ,, by, the, power, vested, in, me, ...]
# Name: Tokens, dtype: object
# 	robin hood
# ['break', 'it', 'down', '.', 'i', 'like', 'an', 'honest', 'fight', 'and', 'a', 'saucy', 'little', 'maid', '...']
# 15
# DOUBLE CHECK: 15
# TYPES:
# 15
# {'like', 'an', 'and', 'fight', '.', '...', 'honest', 'i', 'a', 'it', 'saucy', 'down', 'little', 'maid', 'break'}
# 8501    15
# Name: Tokens, dtype: int64
# 8501    [break, it, down, ., i, like, an, honest, figh...
# Name: Tokens, dtype: object
# 	shrek
# ['there', 'it', 'is', ',', 'princess', '.', 'your', 'future', 'awaits', 'you', '.', 'i', '-', '-', 'i', 'love', 'you', '.', 'got', 'ya', '.', 'donkey', '?', 'what', 'are', 'you', 'doing', '?', 'oh', ',', 'yeah', '.', 'you', "'re", 'right', ',', 'donkey', '.', 'i', 'forgive', 'you', '...', 'for', 'stabbin', "'", 'me', 'in', 'the', 'back', '!']
# 50
# DOUBLE CHECK: 50
# TYPES:
# 34
# ...
# 2955    12
# 2713    11
# 3322    11
# Name: Tokens, dtype: int64
# 2955    [your, grace, !, your, eminence, !, let, 's, n...
# 2713    [sir, ,, close, that, at, once, ,, do, you, mi...
# 3322    [you, most, certainly, did, not, ,, you, pompo...
# Name: Tokens, dtype: object
# 	d'arque
# ['aah', ',', 'i', "'m", 'listening', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'.', 'aah', 'i', ',', 'listening', "'m"}
# 3090    6
# Name: Tokens, dtype: int64
# 3090    [aah, ,, i, 'm, listening, .]
# Name: Tokens, dtype: object
# 	lumiere
# ['tonight', 'is', 'the', 'night', '!', 'cascades', '...']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 7
# {'...', 'night', 'is', 'tonight', 'cascades', 'the', '!'}
# 3143    5
# 3064    2
# Name: Tokens, dtype: int64
# 3143    [tonight, is, the, night, !]
# 3064                 [cascades, ...]
# Name: Tokens, dtype: object
# 	beast
# ['well', 'if', 'you', 'had', "n't", 'run', 'away', ',', 'this', 'would', "n't", 'have', 'happened', '!', 'yes', '.']
# 16
# DOUBLE CHECK: 16
# TYPES:
# 15
# {'run', 'would', '.', 'away', 'well', 'if', ',', "n't", 'had', 'have', 'you', 'this', '!', 'happened', 'yes'}
# 3082    14
# 3171     2
# Name: Tokens, dtype: int64
# 3082    [well, if, you, had, n't, run, away, ,, this, ...
# 3171                                             [yes, .]
# Name: Tokens, dtype: object
# 	old man
# ['maurice', '?']
# 2
# DOUBLE CHECK: 2
# TYPES:
# 2
# {'?', 'maurice'}
# 2877    2
# Name: Tokens, dtype: int64
# 2877    [maurice, ?]
# Name: Tokens, dtype: object
# 	lefou
# ['oh', 'i', 'know', ',', 'i', 'know', '!', 'i', 'know']
# 9
# DOUBLE CHECK: 9
# TYPES:
# 5
# {'oh', 'i', ',', '!', 'know'}
# 2745    7
# 2612    2
# Name: Tokens, dtype: int64
# 2745    [oh, i, know, ,, i, know, !]
# 2612                       [i, know]
# Name: Tokens, dtype: object
# 	crony 1
# ['is', 'it', 'a', 'big', 'beast', '?']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'?', 'a', 'it', 'big', 'is', 'beast'}
# 2883    6
# Name: Tokens, dtype: int64
# 2883    [is, it, a, big, beast, ?]
# Name: Tokens, dtype: object
# Movie:Moana
# 	moana
# ['oh', '.', 'then', ',', 'we', "'ll", 'fish', 'the', 'far', 'side', 'of', 'the', 'island', '.', 'not', 'now', '.', 'i', 'ca', "n't", '.', 'my', 'job', 'is', 'to', 'deliver', 'maui', 'across', 'the', 'great', 'ocean', '.', 'i', 'should…i', 'should', 'be', 'sailing', '.', 'i', "'m", 'sorry', 'about', 'your', 'hook', '.', 'why', 'are', "n't", 'you', 'trying', 'to', 'talk', 'me', 'out', 'of', 'it', '?', 'if', 'there', "'s", 'something', 'you', 'want', 'to', 'tell', 'me', ',', 'just', 'tell', 'me', '!', '...', 'is', 'there', 'something', 'you', 'want', 'to', 'tell', 'me', '?']
# 81
# DOUBLE CHECK: 81
# TYPES:
# 53
# {'oh', '?', 'sailing', 'we', 'i', 'if', "'m", 'side', 'you', 'job', '!', '.', 'island', 'not', 'maui', '...', 'it', ',', 'great', "'s", 'why', "n't", 'want', 'the', 'is', 'to', 'just', 'be', 'fish', 'my', 'deliver', 'should', 'are', 'talk', 'of', 'something', 'ca', 'trying', 'now', 'hook', 'about', "'ll", 'sorry', 'far', 'ocean', 'then', 'tell', 'me', 'should…i', 'across', 'out', 'there', 'your'}
# 5662    14
# 5726     7
# 5808    17
# 5970     7
# 5691    12
# 5697    24
# Name: Tokens, dtype: int64
# 5662    [oh, ., then, ,, we, 'll, fish, the, far, side...
# 5726                         [not, now, ., i, ca, n't, .]
# 5808    [my, job, is, to, deliver, maui, across, the, ...
# 5970                 [i, 'm, sorry, about, your, hook, .]
# 5691    [why, are, n't, you, trying, to, talk, me, out...
# 5697    [if, there, 's, something, you, want, to, tell...
# Name: Tokens, dtype: object
# 	tui
# ['no', 'one', 'goes', 'beyond', 'the', 'reef', '.', 'no', ',', 'there', 'is', 'nothing', 'beyond', 'our', 'reef', 'but', 'storms', 'and', 'rough', 'seas', '.', 'come', 'on', '.', 'there', "'s", 'something', 'i', 'need', 'to', 'show', 'you', '.', 'i', "'ve", 'wanted', 'to', 'bring', 'you', 'here', 'from', 'the', 'moment', 'you', 'opened', 'your', 'eyes', '.', 'this', 'is', 'a', 'sacred', 'place', ',', 'a', 'place', 'of', 'chiefs', '.', 'there', 'will', 'come', 'a', 'time', 'when', 'you', 'will', 'stand', 'on', 'this', 'peak', 'and', 'place', 'a', 'stone', 'on', 'this', 'mountain', '.', 'like', 'i', 'did', '.', 'like', 'my', 'father', 'did', '.', 'and', 'his', 'father', ',', 'and', 'every', 'chief', 'that', 'has', 'even', 'been', '.', 'and', 'on', 'that', 'day', ',', 'when', 'you', 'add', 'your', 'stone', ',', 'you', 'will', 'raise', 'this', 'whole', 'island', 'higher', '.', 'you', 'are', 'the', 'future', 'of', 'our', 'people', ',', 'moana', '.', 'and', 'they', 'are', 'not', 'out', 'there', '.', 'they', 'are', 'right', 'here', '.', 'it', "'s", 'time', 'to', 'be', 'who', 'they', 'need', 'you', 'to', 'be', '.']
# 153
# DOUBLE CHECK: 153
# TYPES:
# 76
# {'they', 'day', 'time', 'sacred', 'nothing', 'who', 'our', 'one', 'i', 'on', 'mountain', 'even', 'higher', 'need', 'you', 'wanted', 'seas', 'been', 'reef', 'like', 'every', '.', 'island', 'eyes', 'stone', 'not', 'rough', 'it', ',', 'beyond', "'s", 'stand', 'add', 'will', 'people', 'but', 'the', 'when', 'is', 'to', 'has', 'come', 'be', 'right', 'no', 'my', 'did', "'ve", 'are', 'goes', 'something', 'here', 'a', 'of', 'that', 'whole', 'opened', 'and', 'his', 'this', 'show', 'from', 'chiefs', 'peak', 'moment', 'chief', 'future', 'out', 'there', 'place', 'bring', 'raise', 'storms', 'your', 'father', 'moana'}
# 5670      7
# 5613     14
# 5641    132
# Name: Tokens, dtype: int64
# 5670                [no, one, goes, beyond, the, reef, .]
# 5613    [no, ,, there, is, nothing, beyond, our, reef,...
# 5641    [come, on, ., there, 's, something, i, need, t...
# Name: Tokens, dtype: object
# 	tamatoa
# ['are', 'you', 'just', 'trying', 'to', 'get', 'me', 'to', 'talk', 'about', 'myself', '?', 'because', 'if', 'you', 'are', ',', 'i', 'will', 'gladly', 'do', 'so', '!']
# 23
# DOUBLE CHECK: 23
# TYPES:
# 20
# {'?', 'do', 'because', 'talk', 'myself', 'are', 'get', 'i', 'if', 'so', 'trying', ',', 'me', 'gladly', 'will', 'you', '!', 'to', 'about', 'just'}
# 5861    23
# Name: Tokens, dtype: int64
# 5861    [are, you, just, trying, to, get, me, to, talk...
# Name: Tokens, dtype: object
# 	maui
# ['what', '--', 'what', 'are', 'you', 'doing', '?', 'te', 'ka', "'s", 'got', 'ta', 'catch', 'me', 'first', '.', 'i', "'ve", 'got', 'your', 'back', ',', 'chosen', 'one', '.', 'go', 'save', 'the', 'world', '.', 'no', '!', 'no', '.', 'i', "'m", 'not', 'afraid', 'of', 'that', 'thing', '.', 'stay', 'out', 'of', 'it', ',', 'or', 'you', "'re", 'sleeping', 'in', 'my', 'armpit', '.', 'you', ',', 'stop', 'it', '.', 'that', 'is', 'not', 'a', 'heart', '.', 'it', 'is', 'a', 'curse', '.', 'the', 'second', 'i', 'took', 'it', ',', 'i', 'got', 'blasted', 'out', 'of', 'the', 'sky', 'and', 'lost', 'my', 'hook', '--', 'get', 'it', 'away', 'from', 'me', '.', 'i', "'m", 'not', 'killing', 'myself', 'so', 'you', 'can', 'prove', 'you', "'re", 'something', 'you', "'re", 'not', '--']
# 111
# DOUBLE CHECK: 111
# TYPES:
# 64
# {'thing', '?', 'heart', 'back', 'armpit', 'took', 'i', 'one', 'first', "'m", 'blasted', 'ta', 'catch', 'you', 'sky', '!', 'can', 'or', 'second', 'stop', '.', 'not', 'chosen', 'it', 'so', ',', "'s", 'stay', 'myself', 'the', 'what', 'is', 'killing', 'in', 'afraid', 'curse', 'no', 'my', 'are', "'ve", 'sleeping', 'of', 'a', 'something', 'world', 'that', "'re", 'hook', 'save', 'got', 'and', 'from', 'away', 'get', 'lost', 'te', 'doing', 'prove', 'me', 'go', 'out', '--', 'ka', 'your'}
# 5918     7
# 5960    23
# 5769    65
# 5945    16
# Name: Tokens, dtype: int64
# 5918                 [what, --, what, are, you, doing, ?]
# 5960    [te, ka, 's, got, ta, catch, me, first, ., i, ...
# 5769    [no, !, no, ., i, 'm, not, afraid, of, that, t...
# 5945    [i, 'm, not, killing, myself, so, you, can, pr...
# Name: Tokens, dtype: object
# 	male villager 7
# ['chief', '!', 'it', "'s", 'your', 'mother', '.']
# 7
# DOUBLE CHECK: 7
# TYPES:
# 7
# {'.', 'mother', 'chief', 'it', "'s", 'your', '!'}
# 5721    7
# Name: Tokens, dtype: int64
# 5721    [chief, !, it, 's, your, mother, .]
# Name: Tokens, dtype: object
# 	female villager 1
# ['it', "'s", 'the', 'harvest', '.', 'this', 'morning', ',', 'i', 'was', 'husking', 'the', 'coconuts', 'and…']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 13
# {'morning', '.', 'this', 'was', 'harvest', 'i', 'coconuts', 'it', ',', "'s", 'husking', 'and…', 'the'}
# 5655    14
# Name: Tokens, dtype: int64
# 5655    [it, 's, the, harvest, ., this, morning, ,, i,...
# Name: Tokens, dtype: object
# Movie:Brave
# 	queen elinor
# ['what', 'was', 'in', 'that', 'cake', '?', 'i', 'do', "n't", 'know', 'what', 'to', 'do', '.', 'do', "n't", 'you', 'dare', 'release', 'another', 'arrow', '!', 'i', 'understand', 'this', 'must', 'all', 'seem', 'unfair', ',', 'even', 'i', 'have', 'reservations', 'when', 'i', 'faced', 'betrothal', '.', 'hey', '!', 'i', 'think', 'you', "'d", 'see', ',', 'if', 'you', 'could', 'just', '.', '.', '.', 'what', "'s", 'this', '?', 'a', 'wisp', '?', 'you', 'know', ',', 'child', ',', 'they', ',', 'the', "willo'thewisps", ',', 'lead', 'you', 'to', 'your', 'fate', '.', 'merida', ',', 'a', 'princess', 'does', 'not', 'place', 'her', 'weapons', 'on', 'the', 'table', '.']
# 90
# DOUBLE CHECK: 90
# TYPES:
# 57
# {'they', '?', 'lead', 'unfair', 'does', 'i', 'cake', 'if', 'on', 'weapons', 'hey', 'even', 'think', 'understand', 'you', 'seem', '!', 'dare', 'merida', '.', 'not', 'could', 'arrow', "willo'thewisps", ',', "'s", 'another', 'betrothal', "n't", 'release', 'when', 'what', 'the', 'to', 'know', 'just', 'in', 'table', 'do', 'must', 'faced', 'a', 'her', 'that', 'fate', 'all', 'reservations', "'d", 'see', 'was', 'child', 'princess', 'wisp', 'place', 'have', 'this', 'your'}
# 5477     6
# 5292     8
# 5373     8
# 5302    19
# 5309    13
# 5456     4
# 5212    19
# 5244    13
# Name: Tokens, dtype: int64
# 5477                       [what, was, in, that, cake, ?]
# 5292                  [i, do, n't, know, what, to, do, .]
# 5373     [do, n't, you, dare, release, another, arrow, !]
# 5302    [i, understand, this, must, all, seem, unfair,...
# 5309    [i, think, you, 'd, see, ,, if, you, could, ju...
# 5456                                  [what, 's, this, ?]
# 5212    [a, wisp, ?, you, know, ,, child, ,, they, ,, ...
# 5244    [merida, ,, a, princess, does, not, place, her...
# Name: Tokens, dtype: object
# 	merida
# ['uh', '.', '.', '.who', 'are', 'you', '?', 'that', "'s", 'a', 'nice', 'story', '.', 'i', 'followed', 'the', 'rules', '!', 'how', 'do', 'you', 'feel', '?']
# 23
# DOUBLE CHECK: 23
# TYPES:
# 19
# {'?', 'do', 'uh', '.who', '.', 'followed', 'are', 'rules', 'feel', 'a', 'i', "'s", 'story', 'that', 'how', 'you', 'the', 'nice', '!'}
# 5398    7
# 5281    6
# 5379    5
# 5460    5
# Name: Tokens, dtype: int64
# 5398    [uh, ., ., .who, are, you, ?]
# 5281    [that, 's, a, nice, story, .]
# 5379     [i, followed, the, rules, !]
# 5460          [how, do, you, feel, ?]
# Name: Tokens, dtype: object
# 	king fergus
# ['let', 'her', 'be', '!', 'princess', 'or', 'not', ',', 'learning', 'to', 'fight', 'is', 'essential', '.']
# 14
# DOUBLE CHECK: 14
# TYPES:
# 14
# {'or', 'be', 'fight', '.', 'not', 'learning', 'her', 'is', 'princess', ',', 'let', 'essential', '!', 'to'}
# 5247    14
# Name: Tokens, dtype: int64
# 5247    [let, her, be, !, princess, or, not, ,, learni...
# Name: Tokens, dtype: object
# 	lord macintosh
# ['sorry', ',', 'me', 'queen', '.', 'i', 'feel', 'terrible', '.', 'my', 'humblest', 'apologies', '.']
# 13
# DOUBLE CHECK: 13
# TYPES:
# 11
# {'terrible', '.', 'my', 'feel', 'sorry', 'humblest', 'i', ',', 'me', 'apologies', 'queen'}
# 5340    13
# Name: Tokens, dtype: int64
# 5340    [sorry, ,, me, queen, ., i, feel, terrible, .,...
# Name: Tokens, dtype: object
# 	the witch
# ['he', 'demanded', 'i', 'give', 'him', 'the', 'strength', 'of', 'ten', 'men', ',', 'and', 'he', 'gave', 'me', 'this', '.', 'that', "'s", 'ridiculous', '!', 'wood', 'can', 'not', 'be', 'imbued', 'with', 'magical', 'property', '.', 'i', 'should', 'know', ',', 'i', "'m", 'a', 'wi', '.', '.', '.whistler', '.', '.', '.of', 'wood', '!']
# 46
# DOUBLE CHECK: 46
# TYPES:
# 35
# {'.of', 'i', "'m", 'gave', 'he', '!', 'can', 'demanded', 'with', '.', 'not', 'wi', ',', "'s", '.whistler', 'men', 'the', 'property', 'know', 'be', 'should', 'magical', 'of', 'a', 'give', 'imbued', 'that', 'and', 'ten', 'ridiculous', 'him', 'strength', 'me', 'this', 'wood'}
# 5434    17
# 5403    29
# Name: Tokens, dtype: int64
# 5434    [he, demanded, i, give, him, the, strength, of...
# 5403    [that, 's, ridiculous, !, wood, can, not, be, ...
# Name: Tokens, dtype: object
# 	cook
# ['morning', ',', 'princess', '.']
# 4
# DOUBLE CHECK: 4
# TYPES:
# 4
# {'morning', ',', 'princess', '.'}
# 5238    4
# Name: Tokens, dtype: int64
# 5238    [morning, ,, princess, .]
# Name: Tokens, dtype: object
# Movie:Tangled
# 	flynn
# ['…', 'then', 'you…', 'i', '’', 'm', 'sorry', ',', 'me', '?', 'rapunzel', '?', 'rapunzel', ',', 'let', 'down', 'your', 'hair', '!', 'rapunzel', ',', 'i', 'thought', 'i', '’', 'd', 'never', 'see', 'you', 'again', '.', 'huh', '?', 'it', 'will', 'be', '.', 'zzz', '.', 'thank', 'you', '.']
# 42
# DOUBLE CHECK: 42
# TYPES:
# 29
# {'?', '’', 'i', 'you', '!', 'you…', '…', '.', 'd', 'it', ',', 'again', 'thank', 'will', 'thought', 'be', 'huh', 'let', 'zzz', 'see', 'sorry', 'hair', 'rapunzel', 'then', 'me', 'm', 'never', 'your', 'down'}
# 6536     3
# 6236     7
# 6511    23
# 6417     4
# 6381     2
# 6506     3
# Name: Tokens, dtype: int64
# 6536                                      […, then, you…]
# 6236                           [i, ’, m, sorry, ,, me, ?]
# 6511    [rapunzel, ?, rapunzel, ,, let, down, your, ha...
# 6417                                    [it, will, be, .]
# 6381                                             [zzz, .]
# 6506                                      [thank, you, .]
# Name: Tokens, dtype: object
# 	rapunzel
# ['i', '’', 'm', 'the', 'lost', 'princess', '.', 'but', 'trust', 'me', 'when', 'i', 'tell', 'you', 'this', '.', 'ngth', '!', 'please', ',', 'leave', 'him', 'alone', '!', 'yi', '.', 'wait', '.', 'you', 'don', '’', 't', 'want', 'my', 'hair', '?', 'well', 'mother', ',', 'there', '’', 's', 'something', 'i', 'want', 'to', 'tell', 'you', '.', 'hmm', '.']
# 51
# DOUBLE CHECK: 51
# TYPES:
# 36
# {'?', '’', 'well', 's', 'i', 'trust', 'you', '!', 'wait', 'leave', '.', ',', 'but', 'want', 't', 'when', 'the', 'hmm', 'to', 'my', 'something', 'yi', 'mother', 'lost', 'ngth', 'hair', 'tell', 'princess', 'him', 'me', 'alone', 'don', 'there', 'this', 'm', 'please'}
# 6467     7
# 6162     9
# 6300     2
# 6220     6
# 6144    12
# 6096    13
# 6345     2
# Name: Tokens, dtype: int64
# 6467                    [i, ’, m, the, lost, princess, .]
# 6162        [but, trust, me, when, i, tell, you, this, .]
# 6300                                            [ngth, !]
# 6220                    [please, ,, leave, him, alone, !]
# 6144    [yi, ., wait, ., you, don, ’, t, want, my, hai...
# 6096    [well, mother, ,, there, ’, s, something, i, w...
# 6345                                             [hmm, .]
# Name: Tokens, dtype: object
# 	capt
# ['two…']
# 1
# DOUBLE CHECK: 1
# TYPES:
# 1
# {'two…'}
# 6493    1
# Name: Tokens, dtype: int64
# 6493    [two…]
# Name: Tokens, dtype: object
# 	stabbington brothers
# ['fair', 'trade', ',', 'a', 'crown', 'for', 'the', 'girl', 'with', 'the', 'magic', 'hair', '?', 'it', 'wasn', '’', 't', 'us', '.', 'it', 'was', 'the', 'old', 'lady', '.']
# 25
# DOUBLE CHECK: 25
# TYPES:
# 21
# {'?', '’', 'wasn', 'us', 'with', '.', 'trade', 'it', ',', 't', 'the', 'for', 'a', 'girl', 'lady', 'was', 'old', 'magic', 'hair', 'fair', 'crown'}
# 6441    13
# 6463    12
# Name: Tokens, dtype: int64
# 6441    [fair, trade, ,, a, crown, for, the, girl, wit...
# 6463    [it, wasn, ’, t, us, ., it, was, the, old, lad...
# Name: Tokens, dtype: object
# 	young rapunzel
# ['why', 'can', '’', 't', 'i', 'go', 'outside', '?']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'?', '’', 'i', 'outside', 'why', 'go', 't', 'can'}
# 5997    8
# Name: Tokens, dtype: int64
# 5997    [why, can, ’, t, i, go, outside, ?]
# Name: Tokens, dtype: object
# 	gothel
# ['–wait', '!', '–', 'and', 'what', 'is', 'that', '?']
# 8
# DOUBLE CHECK: 8
# TYPES:
# 8
# {'?', 'and', 'is', '–wait', '–', 'that', 'what', '!'}
# 6029    3
# 6114    5
# Name: Tokens, dtype: int64
# 6029               [–wait, !, –]
# 6114    [and, what, is, that, ?]
# Name: Tokens, dtype: object
# 	hook
# ['i', 'had', 'a', 'dream…', 'once', '.']
# 6
# DOUBLE CHECK: 6
# TYPES:
# 6
# {'.', 'dream…', 'i', 'a', 'once', 'had'}
# 6226    6
# Name: Tokens, dtype: int64
# 6226    [i, had, a, dream…, once, .]
# Name: Tokens, dtype: object

# %%
char_toks_df = pd.DataFrame(columns=["Disney_Period", "Gender", "Movie", "Role", "Speaker", "Speaker_Status", "Year"])
for movie in movie_df.Movie.unique():
    movie_data = movie_df[movie_df.Movie == movie]
    print("Movie:"+movie)
    for char in movie_data.Speaker.unique():
        char_data = movie_data[movie_data.Speaker == char]#['Tokens']
        #print('|{}|'.format(char))
        #if isinstance(char_data,str):
        #    print(char_data)
        #print(type(char_data))
        all_toks = char_data['Tokens']
        print('\n')
        all_toks_count = char_data['Token_Count'].sum()
        print('\n')
        total_toks_list = all_toks.sum()
        print(type(total_toks_list))
        print('\n')
       # print(char_data)
        char_movie_data = pd.DataFrame([char_data.iloc[0]])
       # print(char_movie_data)
        print('\n')
        char_movie_data['Total_Toks'] = [total_toks_list]
        char_movie_data['Total_Tok_Count'] = all_toks_count
        print('\n')
        #Now for Types--just create a set of the big list instead of combining all sets
        char_movie_data['Total_Types'] = [set(total_toks_list)]
        print('\n')
        char_movie_data['Total_Type_Count'] = len(set(total_toks_list))
        print('\n')
        char_movie_data.drop(labels=['Song', 'Text', 'UTTERANCE_NUMBER', 'Tokens', 'Token_Count', 'Types', 'Type_Count'],
                             axis=1, inplace=True)
        char_toks_df = pd.concat([char_toks_df, char_movie_data], axis=0, sort=True, ignore_index = True)
        
    break

char_movie_data
# Out:
# Movie:Snow White
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <class 'list'>
#     Disney_Period Gender       Movie    Role          Speaker Speaker_Status  \
# 173         EARLY      m  Snow White  HELPER  grumpy & sneezy          NON-P
#
#      Year             Total_Toks  Total_Tok_Count            Total_Types  \
# 173  1937  [apple, dumplings, !]                3  {!, dumplings, apple}
#
#      Total_Type_Count
# 173                 3

# %%
char_toks_df.shape
# Out:
# (15, 11)

# %%
len(movie_df[movie_df.Movie == "Snow White"].Speaker.unique())
# Out:
# 15

# %%
char_toks_df
# Out:
#    Disney_Period Gender       Movie    Role          Speaker Speaker_Status  \
# 0          EARLY      f  Snow White     ANT            queen          NON-P
# 1          EARLY      m  Snow White     ANT           mirror          NON-P
# 2          EARLY      m  Snow White     PRO           prince         PRINCE
# 3          EARLY      f  Snow White     PRO       snow white       PRINCESS
# 4          EARLY      m  Snow White     ANT            guard          NON-P
# 5          EARLY      m  Snow White  HELPER              doc          NON-P
# 6          EARLY      m  Snow White  HELPER       all dwarfs          NON-P
# 7          EARLY      m  Snow White  HELPER            happy          NON-P
# 8          EARLY      m  Snow White  HELPER          bashful          NON-P
# 9          EARLY      m  Snow White  HELPER            dopey          NON-P
# 10         EARLY      m  Snow White  HELPER           grumpy          NON-P
# 11         EARLY      m  Snow White  HELPER           sneezy          NON-P
# 12         EARLY      m  Snow White  HELPER   various dwarfs          NON-P
# 13         EARLY      m  Snow White  HELPER           sleepy          NON-P
# 14         EARLY      m  Snow White  HELPER  grumpy & sneezy          NON-P
#
#     Total_Tok_Count                                         Total_Toks  \
# 0             940.0  [slave, in, the, magic, mirror, come, from, th...
# 1              81.0  [what, wouldst, thou, know, ,, my, queen, ?, f...
# 2               5.0                       [today, hello, ., one, song]
# 3            1231.0  [oh, !, oh, ., hello, there, ., what, 's, the,...
# 4              95.0  [yes, ,, your, majesty, ., but, ,, your, majes...
# 5             903.0  [look, !, our, house, !, the, lit, 's, lightuh...
# 6             224.0  [jiminy, crickets, ., the, door, is, open, ., ...
# 7             178.0  [gosh, ., our, window, 's, been, washed, ., th...
# 8              92.0  [that, 's, a, bad, sign, ., gosh, ,, our, cobw...
# 9               2.0                                           [shh, !]
# 10            411.0  [hah, !, chair, 's, been, dusted, ., there, 's...
# 11            183.0  [sink, 's, empty, ., hey, ,, someone, stole, o...
# 12            195.0  [do, n't, let, go, ., hold, him, tight, ., i, ...
# 13             36.0  [how, 'd, you, guess, ?, it, 's, cold, too, !,...
# 14              3.0                              [apple, dumplings, !]
#
#     Total_Type_Count                                        Total_Types  Year
# 0              314.0  {'til, bones, penalty, words, tender, on, when...  1937
# 1               57.0  {?, heart, as, 't, hide, i, you, beauty, hold,...  1937
# 2                5.0                       {., one, song, today, hello}  1937
# 3              311.0  {shame, gooseberry, day, fun, insist, believe,...  1937
# 4               43.0  {forgive, back, highness, nothing, hide, i, je...  1937
# 5              288.0  {goats, search, fun, squeak, hide, stuff, on, ...  1937
# 6              107.0  {gooseberry, day, bones, words, on, us, or, wi...  1937
# 7               93.0  {day, hid, cookin, wet, ., window, forever, st...  1937
# 8               59.0  {?, oh, does, we, our, flowers, he, !, been, l...  1937
# 9                2.0                                           {shh, !}  1937
# 10             165.0  {on, even, inch, ta, kettle, pig, us, or, ., ....  1937
# 11              86.0  {ahchahch, wawatch, ta, ., n't, fever, mighty,...  1937
# 12              80.0  {pesky, ?, three, git, who, i, our, on, soap, ...  1937
# 13              31.0  {?, cold, you, he, scrub, !, us, ., it, 's, st...  1937
# 14               3.0                              {!, dumplings, apple}  1937

# %%
#Some speakers only have a few lines, or one! makes things tricky....

# %%
char_toks_df = pd.DataFrame(columns=["Disney_Period", "Gender", "Movie", "Role", "Speaker", "Speaker_Status", "Year"])
counter = 0
for movie in movie_df.Movie.unique():
    movie_data = movie_df[movie_df.Movie == movie]
    print("Movie:"+movie)
    char_count = 0
    for char in movie_data.Speaker.unique():
        char_data = movie_data[movie_data.Speaker == char]
        all_toks = char_data['Tokens']
        all_toks_count = char_data['Token_Count'].sum()
        total_toks_list = all_toks.sum()
        char_movie_data = pd.DataFrame([char_data.iloc[0]])
        char_movie_data['Total_Toks'] = [total_toks_list]
        char_movie_data['Total_Tok_Count'] = all_toks_count
        #Now for Types--just create a set of the big list instead of combining all sets
        char_movie_data['Total_Types'] = [set(total_toks_list)]
        char_movie_data['Total_Type_Count'] = len(set(total_toks_list))
        char_movie_data.drop(labels=['Song', 'Text', 'UTTERANCE_NUMBER', 'Tokens', 'Token_Count', 'Types', 'Type_Count'],
                             axis=1, inplace=True)
        char_toks_df = pd.concat([char_toks_df, char_movie_data], axis=0, sort=True, ignore_index = True)
        char_count+=1
    counter +=1    
    print(movie, 'complete!')
    print("This many characters captured!", char_count)
    print(counter)
# Out:
# Movie:Snow White
# Snow White complete!
# This many characters captured! 15
# 1
# Movie:Cinderella
# Cinderella complete!
# This many characters captured! 24
# 2
# Movie:Sleeping Beauty
# Sleeping Beauty complete!
# This many characters captured! 16
# 3
# Movie:The Little Mermaid
# The Little Mermaid complete!
# This many characters captured! 24
# 4
# Movie:Aladdin
# Aladdin complete!
# This many characters captured! 28
# 5
# Movie:Beauty and the Beast
# Beauty and the Beast complete!
# This many characters captured! 28
# 6
# Movie:Pocahontas
# Pocahontas complete!
# This many characters captured! 17
# 7
# Movie:Mulan
# Mulan complete!
# This many characters captured! 42
# 8
# Movie:The Princess and the Frog
# The Princess and the Frog complete!
# This many characters captured! 39
# 9
# Movie:Brave
# Brave complete!
# This many characters captured! 12
# 10
# Movie:Moana
# Moana complete!
# This many characters captured! 19
# 11
# Movie:Tangled
# Tangled complete!
# This many characters captured! 16
# 12
# Movie:Frozen
# Frozen complete!
# This many characters captured! 60
# 13
# Movie:Antz
# Antz complete!
# This many characters captured! 56
# 14
# Movie:Shrek
# Shrek complete!
# This many characters captured! 36
# 15
# Movie:Shrek 3
# Shrek 3 complete!
# This many characters captured! 70
# 16
# Movie:Kung Fu Panda
# Kung Fu Panda complete!
# This many characters captured! 30
# 17
# Movie:How to Train Your Dragon
# How to Train Your Dragon complete!
# This many characters captured! 27
# 18
# Movie:Megamind
# Megamind complete!
# This many characters captured! 14
# 19
# Movie:Rise of the Guardians
# Rise of the Guardians complete!
# This many characters captured! 28
# 20
# Movie:The Croods
# The Croods complete!
# This many characters captured! 12
# 21
# Movie:How to Train Your Dragon 2
# How to Train Your Dragon 2 complete!
# This many characters captured! 19
# 22

# %%
len(movie_df.Movie.unique()) #all movies done!
# Out:
# 22

# %%
#did we get all the characters?
movie_df.groupby('Movie', sort=False)['Speaker'].unique().map(len)
#number match up!!!
# Out:
# Movie
# Snow White                    15
# Cinderella                    24
# Sleeping Beauty               16
# The Little Mermaid            24
# Aladdin                       28
# Beauty and the Beast          28
# Pocahontas                    17
# Mulan                         42
# The Princess and the Frog     39
# Brave                         12
# Moana                         19
# Tangled                       16
# Frozen                        60
# Antz                          56
# Shrek                         36
# Shrek 3                       70
# Kung Fu Panda                 30
# How to Train Your Dragon      27
# Megamind                      14
# Rise of the Guardians         28
# The Croods                    12
# How to Train Your Dragon 2    19
# Name: Speaker, dtype: int64

# %% [markdown]
# Now that we have this info by character, let's save it!

# %%
char_toks_df.shape #total number of unique characters = 632
# Out:
# (632, 11)

# %%
movie_df.groupby('Movie', sort=False)['Speaker'].unique().map(len).sum() #lol, double-double check!
# Out:
# 632

# %%
char_toks_df.to_pickle(r"C:\Users\cassi\Desktop\Data_Science\Animated-Movie-Gendered-Dialogue\private\char_toks.pkl")
